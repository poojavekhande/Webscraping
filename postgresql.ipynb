# %%
import requests

# %%
html_data = requests.get('https://github.com/topics/postgresql').text

# %%
html_data
# Out:
# '\n\n<!DOCTYPE html>\n<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark" data-a11y-animated-images="system">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-UXiu4O52iBFkqt6Kx5t+pqHYP2/LWWIw9+l5ia74TWw+xPzpH44BFfAQp7yzCe0XFGZa72Xiqyml6tox1KkUjw==" rel="stylesheet" href="https://github.githubassets.com/assets/light-5178aee0ee76.css" /><link crossorigin="anonymous" media="all" integrity="sha512-IX1PnI5wWBz8Kgb1JI0f2QFa/WuRQQHJHe0vkKinQzsxRlNb4b8NgODX5htSZVAAkA1O6Vch+RRlDTI8j96slA==" rel="stylesheet" href="https://github.githubassets.com/assets/dark-217d4f9c8e70.css" /><link data-color-theme="dark_dimmed" crossorigin="anonymous" media="all" integrity="sha512-Ct+ijw5ofrvpiRNwv+EhmU4CBCIgm7ApMfRCT8IQK4luRFZf8tLg0CC0VLyTPVLgMbQ9+74znLAZwi1RSzjpiA==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_dimmed-0adfa28f0e68.css" /><link data-color-theme="dark_high_contrast" crossorigin="anonymous" media="all" integrity="sha512-HIV1s2ZEVz1WLyBRua8znQozNKaQ0LM5AHRX9sMlitm5TNY3QMJzKsRD5FPCF9oluzIXNO9JxRK4bBjxGhcctA==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_high_contrast-1c8575b36644.css" /><link data-color-theme="dark_colorblind" crossorigin="anonymous" media="all" integrity="sha512-URPSviCw4m4n71IKn4qyu7MEDpGbCiTfsMTNrUjPwcg38KtEKDt12vzjlNzoy3YDFiQ8D0TCCYKCtrZpqX097g==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_colorblind-5113d2be20b0.css" /><link data-color-theme="light_colorblind" crossorigin="anonymous" media="all" integrity="sha512-yWrddCSE7sqLZ4iqcSOoAsVnCbxs4IgN+oDKgxarp3O6V9dQ8XKyE+ffedHQa55VkB1tY0iNI3QqACG8p1k8IA==" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_colorblind-c96add742484.css" /><link data-color-theme="light_high_contrast" crossorigin="anonymous" media="all" integrity="sha512-KQ+S9ehnvP9vzfiaBA1FbrSWS1RuJBo/ez+bKUm+XKGEMR22w7Oyc712UyVcpYIqpTCTvaaJ3MfeU0x4xPeI+A==" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_high_contrast-290f92f5e867.css" /><link data-color-theme="light_tritanopia" crossorigin="anonymous" media="all" integrity="sha512-zdiPFGv3QFuv1X24wK9Sa7DM3W/It82kehdMBrepjoJJyJyBISVFUJLvMMkvr4uu8j11Rn35dXZiVrN1FNWzGA==" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_tritanopia-cdd88f146bf7.css" /><link data-color-theme="dark_tritanopia" crossorigin="anonymous" media="all" integrity="sha512-IXHqDweLGMT47BTl4v+0woPqFAAtkFBeVqg9U/AliukeUyVREIssCu32RfWmXNdMjwmdVBcS+q9SMQMYuYF5dQ==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_tritanopia-2171ea0f078b.css" />\n  \n    <link crossorigin="anonymous" media="all" integrity="sha512-9YAvnDJUZGjQrAJgbeO8aI4AY45TmwrtMhCMguip+sKV4KVCdxFEGTWI6Lq/tV7bUgeIKL26SSsQEPVJco1Xag==" rel="stylesheet" href="https://github.githubassets.com/assets/primer-f5802f9c3254.css" />\n    <link crossorigin="anonymous" media="all" integrity="sha512-QYwQx1Lni/sSc2dLr2elXRPzOo9udnroJD4iebtuczyT61Ms1Gwl5mRDpWjFNCTwh+AGG7/sEOTWWC6zcpkQYQ==" rel="stylesheet" href="https://github.githubassets.com/assets/global-418c10c752e7.css" />\n    <link crossorigin="anonymous" media="all" integrity="sha512-grUkdIYCk+1YO7R2PF4y8lM1J/u5YqOiulWqSU3sDX3e+srs7rZ78EdnNVMpSe4C40CA176PTE16LWKhJqdOUQ==" rel="stylesheet" href="https://github.githubassets.com/assets/github-82b524748602.css" />\n  <link crossorigin="anonymous" media="all" integrity="sha512-ktc9bCvTFyxpeOWKIn4I8lBnBTZpo8Cpsywlv4nZga4fYZpo7dhVtMBbok0 ...

# %%
print(type(html_data))
# Out:
# <class 'str'>

# %%
from bs4 import BeautifulSoup

# %%
converted_data = BeautifulSoup(html_data,'lxml')

# %%
print(converted_data)
# Out:
# <!DOCTYPE html>
# <html data-a11y-animated-images="system" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/light-5178aee0ee76.css" integrity="sha512-UXiu4O52iBFkqt6Kx5t+pqHYP2/LWWIw9+l5ia74TWw+xPzpH44BFfAQp7yzCe0XFGZa72Xiqyml6tox1KkUjw==" media="all" rel="stylesheet"/><link crossorigin="anonymous" href="https://github.githubassets.com/assets/dark-217d4f9c8e70.css" integrity="sha512-IX1PnI5wWBz8Kgb1JI0f2QFa/WuRQQHJHe0vkKinQzsxRlNb4b8NgODX5htSZVAAkA1O6Vch+RRlDTI8j96slA==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_dimmed" data-href="https://github.githubassets.com/assets/dark_dimmed-0adfa28f0e68.css" integrity="sha512-Ct+ijw5ofrvpiRNwv+EhmU4CBCIgm7ApMfRCT8IQK4luRFZf8tLg0CC0VLyTPVLgMbQ9+74znLAZwi1RSzjpiA==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_high_contrast" data-href="https://github.githubassets.com/assets/dark_high_contrast-1c8575b36644.css" integrity="sha512-HIV1s2ZEVz1WLyBRua8znQozNKaQ0LM5AHRX9sMlitm5TNY3QMJzKsRD5FPCF9oluzIXNO9JxRK4bBjxGhcctA==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_colorblind" data-href="https://github.githubassets.com/assets/dark_colorblind-5113d2be20b0.css" integrity="sha512-URPSviCw4m4n71IKn4qyu7MEDpGbCiTfsMTNrUjPwcg38KtEKDt12vzjlNzoy3YDFiQ8D0TCCYKCtrZpqX097g==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="light_colorblind" data-href="https://github.githubassets.com/assets/light_colorblind-c96add742484.css" integrity="sha512-yWrddCSE7sqLZ4iqcSOoAsVnCbxs4IgN+oDKgxarp3O6V9dQ8XKyE+ffedHQa55VkB1tY0iNI3QqACG8p1k8IA==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="light_high_contrast" data-href="https://github.githubassets.com/assets/light_high_contrast-290f92f5e867.css" integrity="sha512-KQ+S9ehnvP9vzfiaBA1FbrSWS1RuJBo/ez+bKUm+XKGEMR22w7Oyc712UyVcpYIqpTCTvaaJ3MfeU0x4xPeI+A==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="light_tritanopia" data-href="https://github.githubassets.com/assets/light_tritanopia-cdd88f146bf7.css" integrity="sha512-zdiPFGv3QFuv1X24wK9Sa7DM3W/It82kehdMBrepjoJJyJyBISVFUJLvMMkvr4uu8j11Rn35dXZiVrN1FNWzGA==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_tritanopia" data-href="https://github.githubassets.com/assets/dark_tritanopia-2171ea0f078b.css" integrity="sha512-IXHqDweLGMT47BTl4v+0woPqFAAtkFBeVqg9U/AliukeUyVREIssCu32RfWmXNdMjwmdVBcS+q9SMQMYuYF5dQ==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/primer-f5802f9c3254.css" integrity="sha512-9YAvnDJUZGjQrAJgbeO8aI4AY45TmwrtMhCMguip+sKV4KVCdxFEGTWI6Lq/tV7bUgeIKL26SSsQEPVJco1Xag==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/global-418c10c752e7.css" integrity="sha512-QYwQx1Lni/sSc2dLr2elXRPzOo9udnroJD4iebtuczyT61Ms1Gwl5mRDpWjFNCTwh+AGG7/sEOTWWC6zcpkQYQ==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/github-82b524748602.css" integrity="sha512-grUkdIYCk+1YO7R2PF4y8lM1J/u5YqOiulWqSU3sDX3e+srs7rZ78EdnNVMpSe4C40CA176PTE16LWKhJqdOUQ==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/site-92d73d6c2bd3.css" integrity="sha512-ktc9bCvTFyxpeOWKIn4I8lBnBTZpo8Cpsywlv4nZga4fYZpo7dhVtMBbok0nS/yKPpbUp1ML6/yoGi/v7qRy8Q==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/explore-91bd47378abc.css" integrity="sha512-kb1HN4q8/AYgCEDRBJjoppyNOFO0ZKNJCPB7KNEEVlR6e4OLAZ4K3B0+0Z7Nns+WyRmXQLhf2Ub12ZQ+wUQn+w==" media="all" rel="stylesheet"/>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-Zc9Uj7x2fY6Kf5CK+Ry0aDxEDo+G9ne1EMS+9Kus4EHSwOhQQNDYyE7K0IPEUFGgf7YDDm6iFKYZ/ipFVk1u8w==" src="https://github.githubassets.com/assets/runtime-65cf548fbc76.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-ivm676uepRn1vQvL/mShZVrbNfsUUZRp0a2RCZNYrFJYFlYhdDU2P+UC8axgVT17oqv1BVQLngSsGoiBN2MJpw==" src="https://github.githubassets.com/assets/vendors-node_modules_manuelpuyol_turbo_dist_turbo_es2017-esm_js-8af9baefab9e.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-GB4jwt8fni2MoE1wzROiGvrgScSHotjr1A9c1FQKUTsfuFn9W2y5/knx+uD8eOAC1rVSA3UPi3h+PTwAuaDZYQ==" src="https://github.githubassets.com/assets/vendors-node_modules_stacktrace-parser_dist_stack-trace-parser_esm_js-node_modules_github_bro-a4c183-181e23c2df1f.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-KdAZEmCLv7zagCUgOzlv10WgxL0DXtMZzeIO4MJGgQ7tpw9dqCPBqyHsrfio0JM1NFKnF3OrTZ7LbLLFWeGrWw==" src="https://github.githubassets.com/assets/environment-29d01912608b.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-ZQM3kW293O7WR1cDuHZ02wendjejLzwVD0wy4L1eCNr34RHXiY05wmHUx4hnV9WELD/OEZRGrzK+M8uwiZ/WEw==" src="https://github.githubassets.com/assets/vendors-node_modules_selector-observer_dist_index_esm_js-650337916dbd.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-Si8390GeCVPslYj8WomaMCyj33Jutd8vZ+Sdi6WXLSbdZRyC4wwijhTNyLy0zpHhfYnrynP6qArdz1PXti1sOg==" src="https://github.githubassets.com/assets/vendors-node_modules_delegated-events_dist_index_js-node_modules_github_details-dialog-elemen-63debe-4a2f37f7419e.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-y4q/Q8lPgxuYzQJwVhhMWYDJ60RPVbL9xHfxCeMKJHsarrBRFjYA/AEe8wtPw1PLhox5HqxIgqIfFNW+gXYTSQ==" src="https://github.githubassets.com/assets/vendors-node_modules_fzy_js_index_js-node_modules_github_catalyst_lib_index_js-cb8abf43c94f.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-JE0pLsqAg/D/QS77l4fZ88pjAfu9w4A4lzGUQjWix2h3W24+DOJ98Kq3jcDW5tFwTglIxZU43Qksg8C72W9E0g==" src="https://github.githubassets.com/assets/vendors-node_modules_github_filter-input-element_dist_index_js-node_modules_github_remote-inp-73b750-244d292eca80.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-dLTsUc4gGkg08fxQZXA6geV1V+spetoVjY4I5PF5JMBMZsuP0NqkBqAsHRpHwHaNTrxTs7CmW0yPyq1d8SXPsQ==" src="https://github.githubassets.com/assets/vendors-node_modules_github_time-elements_dist_index_js-74b4ec51ce20.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-Rh8gmnXkUHxZz6gYM0gapLCxVlAePcQEFYCfJCnydATStJech3+gN7XUdXj8Q+xihasvvbMzkETh8ZzAZKT8ww==" src="https://github.githubassets.com/assets/vendors-node_modules_github_file-attachment-element_dist_index_js-node_modules_primer_view-co-54af05-461f209a75e4.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-7RXbCviIvfrHb9HwQmHNSrWlMzQzT8jcqwnDobRawcVUNAqJnZmPkJSjRtOMJ8uq5kQHoC3l5wrPIlvd5AqOnA==" src="https://github.githubassets.com/assets/github-elements-ed15db0af888.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-KGOlPJM9Ch3al54rAXARRCbJTSe18kKVnIjGHtnB6ze4f0uTg0/IVEG2oYXLIpvilhIv0uwR+bXgJBepPL9s5A==" src="https://github.githubassets.com/assets/element-registry-2863a53c933d.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-6VTowByTC7C1Ae4nuESJ5iT76vchmVCzjuit7IR83B/TPkwjSserSlr83SYhLvIfNLvJfB2zH0bHBr8+fzIa+w==" src="https://github.githubassets.com/assets/vendors-node_modules_lit-html_lit-html_js-e954e8c01c93.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-3YkTrGWwrb2whIVWEwKEhghL4yI2UAHnLW/QtnYMQFLkfQUYD3gtJ2WqDJg8wzzSm0rP05KFDOsKKx4a1wQRdA==" src="https://github.githubassets.com/assets/vendors-node_modules_github_mini-throttle_dist_index_js-node_modules_github_hotkey_dist_index-9f48bd-dd8913ac65b0.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-/5zfcpKrnUxXsz8HKbUml3aosH3Bdz7hsB21H9gldcjjqyR+2rIU6vwTtQ9WDyCjfvhCPZImF5Ug8DbXiHpI3w==" src="https://github.githubassets.com/assets/vendors-node_modules_github_remote-form_dist_index_js-node_modules_scroll-anchoring_dist_scro-5881a7-ff9cdf7292ab.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-uTutt7Awpa28F3aOmQs6QXoPMcEuNWc1zL+NVVKud8YHsbTe4Wug4ECBI9e9xhkirjezymEOichy0MgdPfWDMw==" src="https://github.githubassets.com/assets/vendors-node_modules_github_paste-markdown_dist_index_esm_js-node_modules_github_quote-select-b114cf-b93badb7b030.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-iv5zc66CDnM+oVHCDv7cko+Bee6Q895DqJ52+TvMOtDYiEWLpTjQheRSbAygXr1SdVa7CSDLpnj3ze+dv1eIaw==" src="https://github.githubassets.com/assets/app_assets_modules_github_soft-nav_navigate_ts-8afe7373ae82.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-MUqllU1zWScJrG44uhPiK8irir0nw6SepGvp+rwjRQRnLnKTlIgaCO1N7OEZ3XSqHIJyNnZR1UlA29lBZrqxSw==" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_keyboard-shortcuts-helper_ts-app_assets_modules_github_di-9b8a64-314aa5954d73.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-sFfyQjq1ObFkfG0l+z9HzzoSicV7DnX6adtbhmwkcwapEIZkJef1OWQl3cYK14uRj/DZcMBTf9630E9xIyxDeA==" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_task-list_ts-app_assets_modules_github_has-interactions_t-0091d6-b057f2423ab5.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-iZTEUA76AQY6oHo8SRucuITxoL9oIEp+kjkLt14bWgeaZhs5CuXGkF8LbcBP4SJXmy0WkwisrWLzdykrDuLzHA==" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_details_ts-app_assets_modules_github_behaviors_include-fr-a78de3-8994c4500efa.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-Z4gbcllweVT5ctPeic5SY6g0R9iV4iTsWMeRBFGXhvBBjGk86edzEqVf8j1aruDJrtSWuHgrNLw6VmQyROCY5g==" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_commenting_edit_ts-app_assets_modules_github_behaviors_ht-83c235-67881b725970.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-ar6L8fw6Nc1UrQYBG5b6ALiOEcrdH8mOzlweJ29cWYgZ48lPxKO2ZBk6+r5P442RDNjgq3RXyXBY6wKEAW7zMw==" src="https://github.githubassets.com/assets/behaviors-6abe8bf1fc3a.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-d4hUbfQ2iadFUIZEYzWtw7J3+rUei1LoCrq3TAisyHMoW6ERm28NawvaJpppfMvroppQJc1HXteqjyRWmugzdA==" src="https://github.githubassets.com/assets/vendors-node_modules_delegated-events_dist_index_js-node_modules_github_catalyst_lib_index_js-57c13e1-7788546df436.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-O73Mm2+i15d5+OJHBJqEGJ7yINcBZotEHst9GPxgdFdVaI+nI9MDzrDJ50ZJUHzZxZytebBKxUc4mR+qNQuTtA==" src="https://github.githubassets.com/assets/notifications-global-3bbdcc9b6fa2.js" type="application/javascript"></script>
# <title>postgresql · GitHub Topics · GitHub</title>
# <meta content="12E4:5841:108463A:12C2018:62E392A7" data-pjax-transient="true" name="request-id"/><meta content="53b46839365cacc2f7623ab0f89a9668f51418d5ad545b21950663336277e228" data-pjax-transient="true" name="html-safe-nonce"/><meta content="eyJyZWZlcnJlciI6IiIsInJlcXVlc3RfaWQiOiIxMkU0OjU4NDE6MTA4NDYzQToxMkMyMDE4OjYyRTM5MkE3IiwidmlzaXRvcl9pZCI6IjYxOTQ2MzkwMjkyNjEyNzU4MTUiLCJyZWdpb25fZWRnZSI6ImFwLXNvdXRoLTEiLCJyZWdpb25fcmVuZGVyIjoiYXAtc291dGgtMSJ9" data-pjax-transient="true" name="visitor-payload"/><meta content="b83f6906226448301a9433090c36c75877c646cb13f58d42638fa26c05787040" data-pjax-transient="true" name="visitor-hmac"/>
# <meta content="" data-pjax-transient="true" name="github-keyboard-shortcuts"/>
# <meta data-pjax-transient="" name="selected-link" value="/topics/postgresql"/>
# <meta content="c1kuD-K2HIVF635lypcsWPoD4kilo5-jA_wBFyT4uMY" name="google-site-verification"/>
# <meta content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU" name="google-site-verification"/>
# <meta content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA" name="google-site-verification"/>
# <meta content="GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc" name="google-site-verification"/>
# <meta content="https://collector.github.com/github/collect" name="octolytics-url"/>
# <meta content="" name="user-login"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="GitHub is where people build software. More than 83 million people use GitHub to discover, fork, and contribute to over 200 million projects." name="description"/>
# <link href="/opensearch.xml" rel="search" title="GitHub" type="application/opensearchdescription+xml"/>
# <link href="https://github.com/fluidicon.png" rel="fluid-icon" title="GitHub"/>
# <meta content="1401488693436528" property="fb:app_id"/>
# <meta content="app-id=1477376905" name="apple-itunes-app"/>
# <meta content="https://github.com" property="og:url"/>
# <meta content="GitHub" property="og:site_name"/>
# <meta content="Build software better, together" property="og:title"/>
# <meta content="GitHub is where people build software. More than 83 million people use GitHub to discover, fork, and contribute to over 200 million projects." property="og:description"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="1200" property="og:image:height"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-mark.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-octocat.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="github" property="twitter:site"/>
# <meta content="13334762" property="twitter:site:id"/>
# <meta content="github" property="twitter:creator"/>
# <meta content="13334762" property="twitter:creator:id"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="GitHub" property="twitter:title"/>
# <meta content="GitHub is where people build software. More than 83 million people use GitHub to discover, fork, and contribute to over 200 million projects." property="twitter:description"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="twitter:image:src"/>
# <meta content="1200" property="twitter:image:width"/>
# <meta content="1200" property="twitter:image:height"/>
# <link href="https://github.githubassets.com/" rel="assets"/>
# <meta content="github.com" name="hostname"/>
# <meta content="github.com" name="expected-hostname"/>
# <meta content="IMAGE_METRIC_TRACKING,GEOJSON_AZURE_MAPS" name="enabled-features"/>
# <meta content="520d45dec4fb83e1d88e09359b36f6782804e9338d717481f439df680789738e" data-turbo-track="reload" http-equiv="x-pjax-version"/>
# <meta content="e57a38ba9764942de7ff1395084aaa39ddfacb66d7b15981d9cb04a189ecca04" data-turbo-track="reload" http-equiv="x-pjax-csp-version"/>
# <meta content="c03f89a0e672697b2ed8e884b041d3c49939b15a72b3452292cd2bfe52ebb4c9" data-turbo-track="reload" http-equiv="x-pjax-css-version"/>
# <meta content="5ec450717393cf5464e3c7657c2f115027fa3a2974e6cd961c8005d66400b29a" data-turbo-track="reload" http-equiv="x-pjax-js-version"/>
# <meta content="no-preview" data-pjax-transient="" name="turbo-cache-control"/>
# <meta content="logged-out env-production page-responsive" name="turbo-body-classes"/>
# <meta content="https://api.github.com/_private/browser/stats" name="browser-stats-url"/>
# <meta content="https://api.github.com/_private/browser/errors" name="browser-errors-url"/>
# <meta content="https://api.github.com/_private/browser/optimizely_client/errors" name="browser-optimizely-client-errors-url"/>
# <link color="#000000" href="https://github.githubassets.com/pinned-octocat.svg" rel="mask-icon"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.png" rel="alternate icon" type="image/png"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.svg" rel="icon" type="image/svg+xml"/>
# <meta content="#1e2327" name="theme-color"/>
# <meta content="light dark" name="color-scheme"/>
# <link crossorigin="use-credentials" href="/manifest.json" rel="manifest"/>
# </head>
# <body class="logged-out env-production page-responsive" style="word-wrap: break-word;">
# <div class="position-relative js-header-wrapper">
# <a class="px-2 py-4 color-bg-accent-emphasis color-fg-on-emphasis show-on-focus js-skip-to-content" href="#start-of-content">Skip to content</a>
# <span class="progress-pjax-loader js-pjax-loader-bar Progress position-fixed width-full" data-view-component="true">
# <span class="Progress-item progress-pjax-loader-bar left-0 top-0 color-bg-accent-emphasis" data-view-component="true" style="width: 0%;"></span>
# </span>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-QXIxqYUlWaXrcdN4cHQlC5KXn2kLBmHHRGsR9I8V663O/bmVvt+hQVH2G6R2rttQ9EshUvuGIDdGQkVH4OA/8w==" src="https://github.githubassets.com/assets/vendors-node_modules_github_remote-form_dist_index_js-node_modules_delegated-events_dist_inde-94fd67-417231a98525.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-CejWN1w/QjbOG5EH1fhNyPkPpg4nInnprTALGEaox9Elu1bcW2zEoX+fELCZABRe4/cmv+6Tna/5OIpxsXd6+A==" src="https://github.githubassets.com/assets/sessions-09e8d6375c3f.js" type="application/javascript"></script>
# <header class="Header-old header-logged-out js-details-container Details position-relative f4 py-2" role="banner">
# <div class="container-lg d-lg-flex flex-items-center p-responsive">
# <div class="d-flex flex-justify-between flex-items-center">
# <a aria-label="Homepage" class="mr-4 color-fg-inherit" data-ga-click="(Logged out) Header, go to homepage, icon:logo-wordmark" href="https://github.com/">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="32" version="1.1" viewbox="0 0 16 16" width="32">
# <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
# </svg>
# </a>
# <div class="d-lg-none css-truncate css-truncate-target width-fit p-2">
# </div>
# <div class="d-flex flex-items-center">
# <a class="d-inline-block d-lg-none f5 no-underline border color-border-default rounded-2 px-2 py-1 mr-3 mr-sm-5 color-fg-inherit" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="33c2d34c9fa51786d8436810cca2bb9cee18d919dc2ea9489202d74626840bf8" href="/signup?ref_cta=Sign+up&amp;ref_loc=header+logged+out&amp;ref_page=%2Ftopics%2Fpostgresql&amp;source=header">
#               Sign up
#             </a>
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target btn-link d-lg-none mt-1 color-fg-inherit" data-view-component="true" type="button"> <svg aria-hidden="true" class="octicon octicon-three-bars" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M1 2.75A.75.75 0 011.75 2h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 2.75zm0 5A.75.75 0 011.75 7h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 7.75zM1.75 12a.75.75 0 100 1.5h12.5a.75.75 0 100-1.5H1.75z" fill-rule="evenodd"></path>
# </svg>
# </button> </div>
# </div>
# <div class="HeaderMenu HeaderMenu--logged-out position-fixed top-0 right-0 bottom-0 height-fit position-lg-relative d-lg-flex flex-justify-between flex-items-center flex-auto">
# <div class="d-flex d-lg-none flex-justify-end border-bottom color-bg-subtle p-3">
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target btn-link" data-view-component="true" type="button"> <svg aria-hidden="true" class="octicon octicon-x color-fg-muted" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M5.72 5.72a.75.75 0 011.06 0L12 10.94l5.22-5.22a.75.75 0 111.06 1.06L13.06 12l5.22 5.22a.75.75 0 11-1.06 1.06L12 13.06l-5.22 5.22a.75.75 0 01-1.06-1.06L10.94 12 5.72 6.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button> </div>
# <nav aria-label="Global" class="mt-0 px-3 px-lg-0 mb-5 mb-lg-0">
# <ul class="d-lg-flex list-style-none">
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Product
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Features","label":"ref_page:/topics/postgresql;ref_cta:Features;"}' href="/features">
#       Features
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Mobile","label":"ref_page:/topics/postgresql;ref_cta:Mobile;"}' href="/mobile">
#       Mobile
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Actions","label":"ref_page:/topics/postgresql;ref_cta:Actions;"}' href="/features/actions">
#       Actions
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Codespaces","label":"ref_page:/topics/postgresql;ref_cta:Codespaces;"}' href="/features/codespaces">
#       Codespaces
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Copilot","label":"ref_page:/topics/postgresql;ref_cta:Copilot;"}' href="/features/copilot">
#       Copilot
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Packages","label":"ref_page:/topics/postgresql;ref_cta:Packages;"}' href="/features/packages">
#       Packages
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Security","label":"ref_page:/topics/postgresql;ref_cta:Security;"}' href="/features/security">
#       Security
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Code review","label":"ref_page:/topics/postgresql;ref_cta:Code review;"}' href="/features/code-review">
#       Code review
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Issues","label":"ref_page:/topics/postgresql;ref_cta:Issues;"}' href="/features/issues">
#       Issues
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Discussions","label":"ref_page:/topics/postgresql;ref_cta:Discussions;"}' href="/features/discussions">
#       Discussions
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Integrations","label":"ref_page:/topics/postgresql;ref_cta:Integrations;"}' href="/features/integrations">
#       Integrations
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold border-top pt-4 pb-2 mt-3" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to GitHub Sponsors","label":"ref_page:/topics/postgresql;ref_cta:GitHub Sponsors;"}' href="/sponsors">
#       GitHub Sponsors
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Customer stories","label":"ref_page:/topics/postgresql;ref_cta:Customer stories;"}' href="/customer-stories">
#       Customer stories
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Team","label":"ref_page:/topics/postgresql;ref_cta:Team;"}' href="/team">Team</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Enterprise","label":"ref_page:/topics/postgresql;ref_cta:Enterprise;"}' href="/enterprise">Enterprise</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Explore
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Explore GitHub","label":"ref_page:/topics/postgresql;ref_cta:Explore GitHub;"}' href="/explore">
#       Explore GitHub
# </a> </li>
# <li class="color-fg-muted text-normal f6 text-mono mb-1 border-top pt-3 mt-3 mb-1">Learn and contribute</li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Topics","label":"ref_page:/topics/postgresql;ref_cta:Topics;"}' href="/topics">
#       Topics
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Collections","label":"ref_page:/topics/postgresql;ref_cta:Collections;"}' href="/collections">
#       Collections
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Trending","label":"ref_page:/topics/postgresql;ref_cta:Trending;"}' href="/trending">
#       Trending
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Skills","label":"ref_page:/topics/postgresql;ref_cta:Skills;"}' href="https://skills.github.com/">
#       Skills
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Sponsors","label":"ref_page:/topics/postgresql;ref_cta:GitHub Sponsors;"}' href="/sponsors/explore">
#       GitHub Sponsors
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Open source guides","label":"ref_page:/topics/postgresql;ref_cta:Open source guides;"}' href="https://opensource.guide">
#       Open source guides
# </a> </li>
# <li class="color-fg-muted text-normal f6 text-mono mb-1 border-top pt-3 mt-3 mb-1">Connect with others</li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to The ReadME Project","label":"ref_page:/topics/postgresql;ref_cta:The ReadME Project;"}' href="/readme">
#       The ReadME Project
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Events","label":"ref_page:/topics/postgresql;ref_cta:Events;"}' href="/events">
#       Events
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Community forum","label":"ref_page:/topics/postgresql;ref_cta:Community forum;"}' href="https://github.community">
#       Community forum
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Education","label":"ref_page:/topics/postgresql;ref_cta:GitHub Education;"}' href="https://education.github.com">
#       GitHub Education
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Stars program","label":"ref_page:/topics/postgresql;ref_cta:GitHub Stars program;"}' href="https://stars.github.com">
#       GitHub Stars program
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Marketplace","label":"ref_page:/topics/postgresql;ref_cta:Marketplace;"}' href="/marketplace">Marketplace</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Pricing
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Plans","label":"ref_page:/topics/postgresql;ref_cta:Plans;"}' href="/pricing">
#       Plans
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Compare plans","label":"ref_page:/topics/postgresql;ref_cta:Compare plans;"}' href="/pricing#compare-features">
#       Compare plans
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Contact Sales","label":"ref_page:/topics/postgresql;ref_cta:Contact Sales;"}' href="https://github.com/enterprise/contact">
#       Contact Sales
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold border-top pt-4 pb-2 mt-3" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Education","label":"ref_page:/topics/postgresql;ref_cta:Education;"}' href="https://education.github.com">
#       Education
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# </ul>
# </nav>
# <div class="d-lg-flex flex-items-center px-3 px-lg-0 text-center text-lg-left">
# <div class="d-lg-flex min-width-0 mb-3 mb-lg-0">
# <div class="header-search flex-auto js-site-search position-relative flex-self-stretch flex-md-self-auto mb-3 mb-md-0 mr-0 mr-md-3 scoped-search site-scoped-search js-jump-to">
# <div class="position-relative">
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="/topics/postgresql" aria-label="Site" class="js-site-search-form" data-scope-id="17184" data-scope-type="Topic" data-scoped-search-url="/topics/postgresql" data-turbo="false" data-unscoped-search-url="/search" method="get" role="search">
# <label class="form-control input-sm header-search-wrapper p-0 js-chromeless-input-container header-search-wrapper-jump-to position-relative d-flex flex-justify-between flex-items-center">
# <input aria-autocomplete="list" aria-controls="jump-to-results" aria-expanded="false" aria-haspopup="listbox" aria-label="Search" autocapitalize="off" autocomplete="off" class="form-control input-sm header-search-input jump-to-field js-jump-to-field js-site-search-focus js-site-search-field is-clearable" data-hotkey="s,/" data-jump-to-suggestions-path="/_graphql/GetSuggestedNavigationDestinations" data-scoped-placeholder="Search" data-test-selector="nav-search-input" data-unscoped-placeholder="Search GitHub" name="q" placeholder="Search" role="combobox" spellcheck="false" type="text" value=""/>
# <input class="js-data-jump-to-suggestions-path-csrf" data-csrf="true" type="hidden" value="v+DhcIjXEouoJGK9q+zhbdL31ZJF80R0axPUHkyWwgpqCg6fFNgXDx92qxEMLaoJ8cH/0XcEN0jVUQC2pdTxuw=="/>
# <input class="js-site-search-type-field" name="type" type="hidden"/>
# <svg aria-hidden="true" class="mr-1 header-search-key-slash" height="20" width="22" xmlns="http://www.w3.org/2000/svg"><path d="M3.5.5h12c1.7 0 3 1.3 3 3v13c0 1.7-1.3 3-3 3h-12c-1.7 0-3-1.3-3-3v-13c0-1.7 1.3-3 3-3z" fill="none" opacity=".4" stroke="#979A9C"></path><path d="M11.8 6L8 15.1h-.9L10.8 6h1z" fill="#979A9C"></path></svg>
# <div class="Box position-absolute overflow-hidden d-none jump-to-suggestions js-jump-to-suggestions-container">
# <ul class="d-none js-jump-to-suggestions-template-container">
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-suggestion" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="suggestion" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this topic" class="js-jump-to-badge-search-text-default d-none">
#         In this topic
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# </ul>
# <ul class="d-none js-jump-to-no-results-template-container">
# <li class="d-flex flex-justify-center flex-items-center f5 d-none js-jump-to-suggestion p-2">
# <span class="color-fg-muted">No suggested jump to results</span>
# </li>
# </ul>
# <ul class="p-0 m-0 js-navigation-container jump-to-suggestions-results-container js-jump-to-suggestions-results-container" id="jump-to-results" role="listbox">
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-scoped-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="scoped_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this topic" class="js-jump-to-badge-search-text-default d-none">
#         In this topic
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-owner-scoped-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="owner_scoped_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#         Search
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-global-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="global_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# ...
#                     postgres
# </a>
# </div>
# </div>
# </div>
# </div>
# </article>
# <div class="px-3 pb-3">
# <article class="d-flex flex-justify-between mb-2">
# <div class="d-flex flex-items-center">
# <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
# <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
# </svg> Open
# </span>
# <h4 class="d-inline flex-auto h5 ml-1 wb-break-word">
# <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:small;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"LITTLE_GOOD_FIRST_ISSUE","actor_id":null,"record_id":899103564,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="d7e1e699ea8ea764ac4aefaedf81516b29f1c0c95241717c552025c532b5a7c1" data-turbo="false" data-view-component="true" href="https://github.com/diesel-rs/diesel/issues/2793">
#                     AsChangeset and Insertable produce unhelpful error messages
# </a> </h4>
# </div>
# <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
# <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
# </svg>
#                   5
#                 </div>
# </article>
# <article class="d-flex flex-justify-between mb-2">
# <div class="d-flex flex-items-center">
# <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
# <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
# </svg> Open
# </span>
# <h4 class="d-inline flex-auto h5 ml-1 wb-break-word">
# <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:small;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"LITTLE_GOOD_FIRST_ISSUE","actor_id":null,"record_id":737168691,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="331ed7be4697a0550e61f3f65ae8e2e2efca9cad6db2b39b9fb503914424143e" data-turbo="false" data-view-component="true" href="https://github.com/diesel-rs/diesel/issues/2555">
#                     Experiment with generate `allow_columns_to_appear_in_same_group_by_clause!` via `diesel print-schema`
# </a> </h4>
# </div>
# </article>
# <div class="mt-3">
# <a class="btn btn-outline btn-sm" data-ga-click="Explore, go to repository contribute, location:good first issues; text:more good first issues;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_CONTRIBUTE_PAGE","click_visual_representation":"CLICK_VISUAL_REPRESENTATION_UNKNOWN","actor_id":null,"record_id":41609775,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="8193470eaf04e595ef879ab08a4eada48f94b81abded09c1208f21b121c6b435" data-turbo="false" data-view-component="true" href="/diesel-rs/diesel/contribute">
#                 Find more good first issues
# </a> </div>
# </div>
# </div>
# </article>
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="https://github.com/topics/postgresql" class="ajax-pagination-form js-ajax-pagination" data-turbo="false" method="get">
# <input name="page" type="hidden" value="2"/>
# <button class="ajax-pagination-btn btn btn-outline color-border-default f6 mt-0 width-full" data-disable-with="Loading more…" type="submit">
#       Load more…
#     </button>
# </form>
# </div>
# <div class="col-md-4 col-lg-3">
# <p class="mb-1">
# <span class="color-fg-muted">Created by</span> Michael Stonebraker
#     </p>
# <p class="mb-1">
# <span class="color-fg-muted">Released</span> July 8, 1996
#     </p>
# <dl class="my-4">
# <dt class="d-none">
#         Repository
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <a data-ga-click="Explore, go to postgres/postgres, location:topic page" href="https://github.com/postgres/postgres">
# <span class="css-truncate css-truncate-target" title="postgres/postgres">
#           postgres/postgres
#         </span>
# </a>
# </dd>
# <dt class="d-none">
#       Website
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-link color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M7.775 3.275a.75.75 0 001.06 1.06l1.25-1.25a2 2 0 112.83 2.83l-2.5 2.5a2 2 0 01-2.83 0 .75.75 0 00-1.06 1.06 3.5 3.5 0 004.95 0l2.5-2.5a3.5 3.5 0 00-4.95-4.95l-1.25 1.25zm-4.69 9.64a2 2 0 010-2.83l2.5-2.5a2 2 0 012.83 0 .75.75 0 001.06-1.06 3.5 3.5 0 00-4.95 0l-2.5 2.5a3.5 3.5 0 004.95 4.95l1.25-1.25a.75.75 0 00-1.06-1.06l-1.25 1.25a2 2 0 01-2.83 0z" fill-rule="evenodd"></path>
# </svg>
# <a data-ga-click="Explore, go to external url, location:topic page" href="https://www.postgresql.org/">
# <span class="css-truncate css-truncate-target" title="www.postgresql.org">
#           www.postgresql.org
#         </span>
# </a>
# </dd>
# <dt class="d-none">
#       Wikipedia
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-link color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M7.775 3.275a.75.75 0 001.06 1.06l1.25-1.25a2 2 0 112.83 2.83l-2.5 2.5a2 2 0 01-2.83 0 .75.75 0 00-1.06 1.06 3.5 3.5 0 004.95 0l2.5-2.5a3.5 3.5 0 00-4.95-4.95l-1.25 1.25zm-4.69 9.64a2 2 0 010-2.83l2.5-2.5a2 2 0 012.83 0 .75.75 0 001.06-1.06 3.5 3.5 0 00-4.95 0l-2.5 2.5a3.5 3.5 0 004.95 4.95l1.25-1.25a.75.75 0 00-1.06-1.06l-1.25 1.25a2 2 0 01-2.83 0z" fill-rule="evenodd"></path>
# </svg>
# <a data-ga-click="Explore, go to Wikipedia entry, location:topic page" href="https://en.wikipedia.org/wiki/PostgreSQL">
# <span class="css-truncate css-truncate-target" title="en.wikipedia.org/wiki/PostgreSQL">
#           Wikipedia
#         </span>
# </a>
# </dd>
# </dl>
# </div>
# </div>
# </div>
# </div>
# </main>
# </div>
# <footer class="footer width-full container-lg p-responsive">
# <h2 class="sr-only">Footer</h2>
# <div class="position-relative d-flex flex-items-center pb-2 f6 color-fg-muted border-top color-border-muted flex-column-reverse flex-lg-row flex-wrap flex-lg-nowrap mt-6 pt-6">
# <div class="list-style-none d-flex flex-wrap col-0 col-lg-2 flex-justify-start flex-lg-justify-between mb-2 mb-lg-0">
# <div class="mt-2 mt-lg-0 d-flex flex-items-center">
# <a aria-label="Homepage" class="footer-octicon mr-2" href="https://github.com" title="GitHub">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
# </svg>
# </a> <span>
#         © 2022 GitHub, Inc.
#         </span>
# </div>
# </div>
# <nav aria-label="footer" class="col-12 col-lg-8">
# <h3 class="sr-only" id="sr-footer-heading">Footer navigation</h3>
# <ul aria-labelledby="sr-footer-heading" class="list-style-none d-flex flex-wrap col-12 flex-justify-center flex-lg-justify-between mb-2 mb-lg-0">
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to terms","label":"text:terms"}' href="https://docs.github.com/en/github/site-policy/github-terms-of-service">Terms</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to privacy","label":"text:privacy"}' href="https://docs.github.com/en/github/site-policy/github-privacy-statement">Privacy</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to security","label":"text:security"}' href="https://github.com/security">Security</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to status","label":"text:status"}' href="https://www.githubstatus.com/">Status</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to help, text:Docs" href="https://docs.github.com">Docs</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to contact","label":"text:contact"}' href="https://support.github.com?tags=dotcom-footer">Contact GitHub</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to Pricing","label":"text:Pricing"}' href="https://github.com/pricing">Pricing</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to api","label":"text:api"}' href="https://docs.github.com">API</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to training","label":"text:training"}' href="https://services.github.com">Training</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to blog","label":"text:blog"}' href="https://github.blog">Blog</a></li>
# <li><a data-ga-click="Footer, go to about, text:about" href="https://github.com/about">About</a></li>
# </ul>
# </nav>
# </div>
# <div class="d-flex flex-justify-center pb-6">
# <span class="f6 color-fg-muted"></span>
# </div>
# </footer>
# <div class="ajax-error-message flash flash-error" hidden="" id="ajax-error-message">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <button aria-label="Dismiss error" class="flash-close js-ajax-error-dismiss" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button>
#     You can’t perform that action at this time.
#   </div>
# <div class="js-stale-session-flash flash flash-warn flash-banner" hidden="">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <span class="js-stale-session-flash-signed-in" hidden="">You signed in with another tab or window. <a href="">Reload</a> to refresh your session.</span>
# <span class="js-stale-session-flash-signed-out" hidden="">You signed out in another tab or window. <a href="">Reload</a> to refresh your session.</span>
# </div>
# <template id="site-details-dialog">
# <details class="details-reset details-overlay details-overlay-dark lh-default color-fg-default hx_rsm" open="">
# <summary aria-label="Close dialog" role="button"></summary>
# <details-dialog class="Box Box--overlay d-flex flex-column anim-fade-in fast hx_rsm-dialog hx_rsm-modal">
# <button aria-label="Close dialog" class="Box-btn-octicon m-0 btn-octicon position-absolute right-0 top-0" data-close-dialog="" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button>
# <div class="octocat-spinner my-6 js-details-dialog-spinner"></div>
# </details-dialog>
# </details>
# </template>
# <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;" tabindex="0">
# <div class="Popover-message Popover-message--bottom-left Popover-message--large Box color-shadow-large" style="width:360px;">
# </div>
# </div>
# <template id="snippet-clipboard-copy-button">
# <div class="zeroclipboard-container position-absolute right-0 top-0">
# <clipboard-copy aria-label="Copy" class="ClipboardButton btn js-clipboard-copy m-2 p-0 tooltipped-no-delay" data-copy-feedback="Copied!" data-tooltip-direction="w">
# <svg aria-hidden="true" class="octicon octicon-copy js-clipboard-copy-icon m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M0 6.75C0 5.784.784 5 1.75 5h1.5a.75.75 0 010 1.5h-1.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-1.5a.75.75 0 011.5 0v1.5A1.75 1.75 0 019.25 16h-7.5A1.75 1.75 0 010 14.25v-7.5z" fill-rule="evenodd"></path><path d="M5 1.75C5 .784 5.784 0 6.75 0h7.5C15.216 0 16 .784 16 1.75v7.5A1.75 1.75 0 0114.25 11h-7.5A1.75 1.75 0 015 9.25v-7.5zm1.75-.25a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25h-7.5z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-hidden="true" class="octicon octicon-check js-clipboard-check-icon color-fg-success d-none m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M13.78 4.22a.75.75 0 010 1.06l-7.25 7.25a.75.75 0 01-1.06 0L2.22 9.28a.75.75 0 011.06-1.06L6 10.94l6.72-6.72a.75.75 0 011.06 0z" fill-rule="evenodd"></path>
# </svg>
# </clipboard-copy>
# </div>
# </template>
# </body>
# </html>

# %%
first_article = converted_data.find('article',class_='border rounded color-shadow-small color-bg-subtle my-4')

# %%
first_article
# Out:
# <article class="border rounded color-shadow-small color-bg-subtle my-4">
# <div class="px-3">
# <div class="d-flex flex-justify-between my-3">
# <div class="d-flex flex-auto">
# <span style="margin-top:2px">
# <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# </span>
# <h3 class="f3 color-fg-muted text-normal lh-condensed">
# <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":3220138,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="049f521217c0288d7d7c412b422a0ac6e9c7e41ae95ae779939c4eab08a3ac42" data-turbo="false" data-view-component="true" href="/discourse">
#             discourse
# </a>          /
#           <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":7569578,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="1902bbf2a538e7a1e539968d6d76716b54da24f0b11f1f6af77d5364e6c2e2a6" data-turbo="false" data-view-component="true" href="/discourse/discourse">
#             discourse
# </a> </h3>
# </div>
# <div class="d-flex flex-items-center ml-3">
# <div class="BtnGroup d-flex" data-view-component="true">
# <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":7569578,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="4646ed4871db6a5065c3f42584e87f39c9cde736e0d77fb27ba00010e26f5ae5" data-view-component="true" href="/login?return_to=%2Fdiscourse%2Fdiscourse" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
# </svg><span class="d-inline" data-view-component="true">
#           Star
# </span> <span aria-label="36091 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="36,091">36.1k</span>
# </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
# </svg>
# </button></div>
# </div>
# </div>
# </div>
# <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
# <ul class="tabnav-tabs" data-view-component="true">
# <li class="d-inline-flex" data-view-component="true">
# <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":7569578,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="57c15247795e8997472c976d5a7a7b68433693e16d277d12d7395d7bfd970b73" data-turbo="false" data-view-component="true" href="/discourse/discourse" id="code-tab-7569578">
# <svg aria-hidden="true" class="octicon octicon-code color-fg-default" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
# </svg> Code
#
#
# </a></li>
# <li class="d-inline-flex" data-view-component="true">
# <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":7569578,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="b3c7282b0a2eaa688cd8afa012bca7f0c044d0ebe95493f1acf0ce08bdc08ebc" data-turbo="false" data-view-component="true" href="/discourse/discourse/issues" id="issues-tab-7569578">
# <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-light" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
# </a></li>
# <li class="d-inline-flex" data-view-component="true">
# <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":7569578,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="8ef07809546ccf3f2c011e790dba5018734ae8949e6caf112beb28f83cb0c75d" data-turbo="false" data-view-component="true" href="/discourse/discourse/pulls" id="pull-requests-tab-7569578">
# <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
# </svg> Pull requests
#
#
# </a></li>
# </ul>
# </nav>
# <div class="color-bg-default rounded-bottom-2">
# <div class="px-3 pt-3">
# <p class="color-fg-muted mb-0"></p><div>A platform for community discussion. Free, open, simple.</div>
# </div>
# <div class="d-flex flex-wrap border-bottom color-border-muted px-3 pt-2 pb-2">
# <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":40,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="ebff047b7437bce70ff33431a19cb4cfe3b52b7e20f0cfe999b2ab074100332f" data-view-component="true" href="/topics/javascript" title="Topic: javascript">
#               javascript
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":45,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="d7f5a46389b0af8a9e4e116e4e7f8946e1fcfca64ada0a4f1631d05adf22f8a9" data-view-component="true" href="/topics/ruby" title="Topic: ruby">
#               ruby
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":118,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="9cf0c94c65c1516a42d9eb65a87cac316acfa222a2dfa17ea2ba0f60d2eff2ce" data-view-component="true" href="/topics/rails" title="Topic: rails">
#               rails
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":188,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="068de9e10365a8b00d4cd2808e4bdd3c9cf3c91eb0ac61f57b4cf68363fb77cc" data-view-component="true" href="/topics/ember" title="Topic: ember">
#               ember
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":17184,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="491dafda42dc5c75aefde60b32e9debe78805ad6397f26c5eed62d8f92a3c420" data-view-component="true" href="/topics/postgresql" title="Topic: postgresql">
#               postgresql
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":20883,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="180c6b3d38f07f3d933d93e342601dbe9798391bd8bc99ff2b0aa688c2be7d2f" data-view-component="true" href="/topics/forum" title="Topic: forum">
#               forum
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":22248,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="ff06889c55ef7ec1d37b3f6d535ac53154db0d84dce296d69d184f515382fa9c" data-view-component="true" href="/topics/discourse" title="Topic: discourse">
#               discourse
# </a> </div>
# <div class="p-3">
# <ul class="d-flex f6 list-style-none color-fg-muted">
# <li class="mr-4">
#               Updated
#               <relative-time class="no-wrap" datetime="2022-07-29T07:31:56Z">Jul 29, 2022</relative-time>
# </li>
# <li class="mr-4">
# <span class="f6 my-1 ml-0">
# <span class="repo-language-color" style="background-color: #701516"></span>
# <span itemprop="programmingLanguage">Ruby</span>
# </span>
# </li>
# </ul>
# </div>
# </div>
# </article>

# %%
Repository_name = first_article.find('a',class_='text-bold wb-break-word').text

# %%
Repository_name.strip()
# Out:
# 'discourse'

# %%
User_name = first_article.find('a',class_='').text

# %%
User_name.strip()
# Out:
# 'discourse'

# %%
Stars = first_article.find('span',class_='Counter js-social-count').text

# %%
Stars.strip()
# Out:
# '36.1k'

# %%
Url = first_article.find('a',class_='text-bold wb-break-word')['href']

# %%
base_Url = 'https://github.com/'

# %%
print(base_Url + Url)
# Out:
# https://github.com//discourse/discourse

# %%
first_article_info={
    'Repository_name': Repository_name.strip(),
    'User_name': User_name.strip(),
    'Stars': Stars,
    'URL': base_Url+Url
}

# %%
first_article_info
# Out:
# {'Repository_name': 'discourse',
#  'User_name': 'discourse',
#  'Stars': '36.1k',
#  'URL': 'https://github.com//discourse/discourse'}

# %%
all_article = converted_data.find_all('article',class_='border rounded color-shadow-small color-bg-subtle my-4')

# %%
all_article
# Out:
# [<article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":3220138,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="049f521217c0288d7d7c412b422a0ac6e9c7e41ae95ae779939c4eab08a3ac42" data-turbo="false" data-view-component="true" href="/discourse">
#              discourse
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":7569578,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="1902bbf2a538e7a1e539968d6d76716b54da24f0b11f1f6af77d5364e6c2e2a6" data-turbo="false" data-view-component="true" href="/discourse/discourse">
#              discourse
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":7569578,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="4646ed4871db6a5065c3f42584e87f39c9cde736e0d77fb27ba00010e26f5ae5" data-view-component="true" href="/login?return_to=%2Fdiscourse%2Fdiscourse" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="36091 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="36,091">36.1k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":7569578,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="57c15247795e8997472c976d5a7a7b68433693e16d277d12d7395d7bfd970b73" data-turbo="false" data-view-component="true" href="/discourse/discourse" id="code-tab-7569578">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-default" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":7569578,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="b3c7282b0a2eaa688cd8afa012bca7f0c044d0ebe95493f1acf0ce08bdc08ebc" data-turbo="false" data-view-component="true" href="/discourse/discourse/issues" id="issues-tab-7569578">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-light" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":7569578,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="8ef07809546ccf3f2c011e790dba5018734ae8949e6caf112beb28f83cb0c75d" data-turbo="false" data-view-component="true" href="/discourse/discourse/pulls" id="pull-requests-tab-7569578">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <div class="px-3 pt-3">
#  <p class="color-fg-muted mb-0"></p><div>A platform for community discussion. Free, open, simple.</div>
#  </div>
#  <div class="d-flex flex-wrap border-bottom color-border-muted px-3 pt-2 pb-2">
#  <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":40,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="ebff047b7437bce70ff33431a19cb4cfe3b52b7e20f0cfe999b2ab074100332f" data-view-component="true" href="/topics/javascript" title="Topic: javascript">
#                javascript
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":45,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="d7f5a46389b0af8a9e4e116e4e7f8946e1fcfca64ada0a4f1631d05adf22f8a9" data-view-component="true" href="/topics/ruby" title="Topic: ruby">
#                ruby
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":118,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="9cf0c94c65c1516a42d9eb65a87cac316acfa222a2dfa17ea2ba0f60d2eff2ce" data-view-component="true" href="/topics/rails" title="Topic: rails">
#                rails
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":188,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="068de9e10365a8b00d4cd2808e4bdd3c9cf3c91eb0ac61f57b4cf68363fb77cc" data-view-component="true" href="/topics/ember" title="Topic: ember">
#                ember
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":17184,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="491dafda42dc5c75aefde60b32e9debe78805ad6397f26c5eed62d8f92a3c420" data-view-component="true" href="/topics/postgresql" title="Topic: postgresql">
#                postgresql
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":20883,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="180c6b3d38f07f3d933d93e342601dbe9798391bd8bc99ff2b0aa688c2be7d2f" data-view-component="true" href="/topics/forum" title="Topic: forum">
#                forum
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":22248,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="ff06889c55ef7ec1d37b3f6d535ac53154db0d84dce296d69d184f515382fa9c" data-view-component="true" href="/topics/discourse" title="Topic: discourse">
#                discourse
#  </a> </div>
#  <div class="p-3">
#  <ul class="d-flex f6 list-style-none color-fg-muted">
#  <li class="mr-4">
#                Updated
#                <relative-time class="no-wrap" datetime="2022-07-29T07:31:56Z">Jul 29, 2022</relative-time>
#  </li>
#  <li class="mr-4">
#  <span class="f6 my-1 ml-0">
#  <span class="repo-language-color" style="background-color: #701516"></span>
#  <span itemprop="programmingLanguage">Ruby</span>
#  </span>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </article>,
#  <article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <a class="overflow-hidden flex-items-center rounded-top-2 color-border-muted border-bottom d-flex position-relative" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_IMAGE","actor_id":null,"record_id":214587193,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="a056ccac950a4c5fea5770cda5fd617afa1656fc6a1c1d0f7208e324d5e572c3" data-turbo="false" data-view-component="true" href="/supabase/supabase" style="max-height:275px">
#  <img alt="supabase" class="d-block width-full" loading="lazy" src="https://repository-images.githubusercontent.com/214587193/00f59f00-90a6-11eb-8764-f49e3f731458"/>
#  </a>
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":54469796,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="059bc94a2e3a7526f6f7b61cad29ecc2f7da7b0f991fab9859284b7864504dc6" data-turbo="false" data-view-component="true" href="/supabase">
#              supabase
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":214587193,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="4996f4e54abd06ab2a65970a1a189cb6c98e05e43241806f06fe8096fe8aaf81" data-turbo="false" data-view-component="true" href="/supabase/supabase">
#              supabase
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <a aria-label="Sponsor @supabase" class="btn btn-sm mr-2" data-hydro-click='{"event_type":"sponsors.button_click","payload":{"button":"TOPIC_PAGE_SPONSOR","sponsorable_login":"supabase","originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="15c08dbb7cebdb21cb59b0fdd319e728c55732c5637282db984bb5dff02069ff" data-view-component="true" href="/sponsors/supabase">
#  <svg aria-hidden="true" class="octicon octicon-heart icon-sponsor mr-1 v-align-middle color-fg-sponsors anim-pulse-in" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.25 2.5c-1.336 0-2.75 1.164-2.75 3 0 2.15 1.58 4.144 3.365 5.682A20.565 20.565 0 008 13.393a20.561 20.561 0 003.135-2.211C12.92 9.644 14.5 7.65 14.5 5.5c0-1.836-1.414-3-2.75-3-1.373 0-2.609.986-3.029 2.456a.75.75 0 01-1.442 0C6.859 3.486 5.623 2.5 4.25 2.5zM8 14.25l-.345.666-.002-.001-.006-.003-.018-.01a7.643 7.643 0 01-.31-.17 22.075 22.075 0 01-3.434-2.414C2.045 10.731 0 8.35 0 5.5 0 2.836 2.086 1 4.25 1 5.797 1 7.153 1.802 8 3.02 8.847 1.802 10.203 1 11.75 1 13.914 1 16 2.836 16 5.5c0 2.85-2.045 5.231-3.885 6.818a22.08 22.08 0 01-3.744 2.584l-.018.01-.006.003h-.002L8 14.25zm0 0l.345.666a.752.752 0 01-.69 0L8 14.25z" fill-rule="evenodd"></path>
#  </svg>
#  <span class="v-align-middle">Sponsor</span>
#  </a>
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":214587193,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="a03e8030caaad473e685e237c9b362043dc8eb699346ac4c54dd6bf239e02584" data-view-component="true" href="/login?return_to=%2Fsupabase%2Fsupabase" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="36029 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="36,029">36k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":214587193,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="301765909bf754b6ae03bf721624f7905445c202ebe6062d65265e38feab6422" data-turbo="false" data-view-component="true" href="/supabase/supabase" id="code-tab-214587193">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":214587193,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="5fc5a86802734966d28910ae4d2b7b22775a66c95e1d398efe0add8313341614" data-turbo="false" data-view-component="true" href="/supabase/supabase/issues" id="issues-tab-214587193">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-dark" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":214587193,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="6200fb24e9512052ced80cff54a9538b8e458a76ecb403b95a4dfc2989f928b8" data-turbo="false" data-view-component="true" href="/supabase/supabase/pulls" id="pull-requests-tab-214587193">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository discussions, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_DISCUSSIONS","click_visual_representation":"DISCUSSIONS_TAB","actor_id":null,"record_id":214587193,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="16d8009fd418892127a736dadf4b48e3210e9203b7a6003cc72f2055e96284fa" data-turbo="false" data-view-component="true" href="/supabase/supabase/discussions" id="discussions-tab-214587193">
#  <svg aria-hidden="true" class="octicon octicon-comment-discussion color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M1.5 2.75a.25.25 0 01.25-.25h8.5a.25.25 0 01.25.25v5.5a.25.25 0 01-.25.25h-3.5a.75.75 0 00-.53.22L3.5 11.44V9.25a.75.75 0 00-.75-.75h-1a.25.25 0 01-.25-.25v-5.5zM1.75 1A1.75 1.75 0 000 2.75v5.5C0 9.216.784 10 1.75 10H2v1.543a1.457 1.457 0 002.487 1.03L7.061 10h3.189A1.75 1.75 0 0012 8.25v-5.5A1.75 1.75 0 0010.25 1h-8.5zM14.5 4.75a.25.25 0 00-.25-.25h-.5a.75.75 0 110-1.5h.5c.966 0 1.75.784 1.75 1.75v5.5A1.75 1.75 0 0114.25 12H14v1.543a1.457 1.457 0 01-2.487 1.03L9.22 12.28a.75.75 0 111.06-1.06l2.22 2.22v-2.19a.75.75 0 01.75-.75h1a.25.25 0 00.25-.25v-5.5z" fill-rule="evenodd"></path>
#  </svg> Discussions
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <article class="p-3">
#  <div class="d-flex flex-justify-between mb-3">
#  <div class="d-flex flex-items-center">
#  <span class="State State--open State--small v-align-bottom mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto f3 text-normal ml-1 wb-break-word">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"BIG_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1296302604,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="c6d29e8b2b064050b9e9ed0c9ee83908cc369a804761a7078bf748ba53b70e78" data-turbo="false" data-view-component="true" href="https://github.com/supabase/supabase/issues/7599">
#                  Chore: update the rest of the monorepo to use common assets
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                3
#              </div>
#  </div>
#  <div class="d-flex">
#  <div class="mr-3">
#  <img alt="Isaiah-Hamilton" class="avatar avatar-user avatar-small" height="32" src="https://avatars.githubusercontent.com/u/70828596?v=4" width="32"/>
#  </div>
#  <div class="flex-auto" style="width: 80%;">
#  <div class="Box Box--condensed position-relative timeline-comment--caret">
#  <div class="Box-header f6 color-fg-muted">
#  <strong class="color-fg-default text-bold">
#                    Isaiah-Hamilton
#                  </strong>
#
#                    commented
#
#                  <relative-time class="no-wrap" datetime="2022-07-06T19:43:55Z">Jul 6, 2022</relative-time>
#  </div>
#  <div class="Box-body comment-body markdown-body position-relative overflow-hidden pt-3" style="max-height:200px">
#  <h1>Chore</h1>
#  <h2>Describe the chore</h2>
#  <p>Update the rest of the monorepo to use common assets.</p>
#  <h2>Tasks</h2>
#  <ul class="contains-task-list">
#  <li class="task-list-item"><input class="task-list-item-checkbox" disabled="" id="" type="checkbox"/> Find away to get favicons working fully</li>
#  <li class="task-list-item"><input class="task-list-item-checkbox" disabled="" id="" type="checkbox"/> Update the rest of the monorepo</li>
#  </ul>
#  <div class="position-absolute right-0 left-0 bottom-0 text-center" style="background: linear-gradient(to top, var(--color-canvas-default), var(--color-canvas-default-transparent));">
#  <a class="btn btn-outline btn-sm mx-auto my-3" data-ga-click="Explore, go to issue, location:good first issues;text:read more;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"READ_MORE","actor_id":null,"record_id":1296302604,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="b3499ca6dfef70f621c0c594a48f7ec5536c9ce9b7cdd9fb1b1035186f2d0bc9" href="https://github.com/supabase/supabase/issues/7599">
#                        Read more
#  </a> </div>
#  </div>
#  </div>
#  <div class="mt-3">
#  <span class="discussion-item-icon border-white-fade ml-0 mr-2">
#  <svg aria-hidden="true" class="octicon octicon-tag" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.5 7.775V2.75a.25.25 0 01.25-.25h5.025a.25.25 0 01.177.073l6.25 6.25a.25.25 0 010 .354l-5.025 5.025a.25.25 0 01-.354 0l-6.25-6.25a.25.25 0 01-.073-.177zm-1.5 0V2.75C1 1.784 1.784 1 2.75 1h5.025c.464 0 .91.184 1.238.513l6.25 6.25a1.75 1.75 0 010 2.474l-5.026 5.026a1.75 1.75 0 01-2.474 0l-6.25-6.25A1.75 1.75 0 011 7.775zM6 5a1 1 0 100 2 1 1 0 000-2z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <div class="wb-break-word">
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":1611370746,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="8b70a93f0a31763fa8b3af4bb26fd17d1606d96f6be8e01e44b65947cd27c11e" data-name="help wanted" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22help+wanted%22" id="label-305f55" style="--label-r:0;--label-g:134;--label-b:114;--label-h:171;--label-s:100;--label-l:26;">
#                      help wanted
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-305f55" hidden="hidden">Extra attention is needed</tool-tip>
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":1611370747,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="97895d89521b1c3abf2821fd0132eb4176d2196a9ffe523d63e454840f8c8a8e" data-name="good first issue" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22good+first+issue%22" id="label-9f7029" style="--label-r:112;--label-g:87;--label-b:255;--label-h:248;--label-s:100;--label-l:67;">
#                      good first issue
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-9f7029" hidden="hidden">Good for newcomers</tool-tip>
#  </div>
#  </div>
#  </div>
#  </div>
#  </article>
#  <div class="px-3 pb-3">
#  <article class="d-flex flex-justify-between mb-2">
#  <div class="d-flex flex-items-center">
#  <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto h5 ml-1 wb-break-word">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:small;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"LITTLE_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1292019000,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="34333468858a148e4c42d008615b9759badf5bf38d8ad7f766950f0e74e35a8d" data-turbo="false" data-view-component="true" href="https://github.com/supabase/supabase/issues/7530">
#                      Navbar links 'Guides' and 'Reference' are both higlighted in green at the same time
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                    5
#                  </div>
#  </article>
#  <article class="d-flex flex-justify-between mb-2">
#  <div class="d-flex flex-items-center">
#  <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto h5 ml-1 wb-break-word">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:small;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"LITTLE_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1289885604,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="2e88b599074b7b3e111459787b725c6e3cf70af367ad9e146b0dd13f14e44c6e" data-turbo="false" data-view-component="true" href="https://github.com/supabase/supabase/issues/7508">
#                      Make contents of the table's "Description" field visible in Table Editor
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                    5
#                  </div>
#  </article>
#  <div class="mt-3">
#  <a class="btn btn-outline btn-sm" data-ga-click="Explore, go to repository contribute, location:good first issues; text:more good first issues;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_CONTRIBUTE_PAGE","click_visual_representation":"CLICK_VISUAL_REPRESENTATION_UNKNOWN","actor_id":null,"record_id":214587193,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="e50b7c7e5a552c2d3d89238596b6b1f961861d420081676be27c3cfe0b68bb55" data-turbo="false" data-view-component="true" href="/supabase/supabase/contribute">
#                  Find more good first issues
#  </a> </div>
#  </div>
#  </div>
#  </article>,
#  <article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":10520629,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="527770669531b91043ec8886b8aa0f43882423ab02035aaeb4f6fd9efec97691" data-turbo="false" data-view-component="true" href="/metabase">
#              metabase
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":30203935,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="6a797b881a4f796ee0627f7ba02ca2f2f931477937fe2168efd6bd68c255ad2f" data-turbo="false" data-view-component="true" href="/metabase/metabase">
#              metabase
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":30203935,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="8c6ee94a704ddddf41d4c61276285bce35f2770908ce3a8170eb360d597a0e47" data-view-component="true" href="/login?return_to=%2Fmetabase%2Fmetabase" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="29275 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="29,275">29.3k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":30203935,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="c704af3f578bd9d03933aa60210378f6c54f6ac7e26ea0576f493da5e65d6d13" data-turbo="false" data-view-component="true" href="/metabase/metabase" id="code-tab-30203935">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-default" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":30203935,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="e92e0a5825207d8bdf3c54c289e8871268c6a64196cc77e47eef7e10ea0bec9c" data-turbo="false" data-view-component="true" href="/metabase/metabase/issues" id="issues-tab-30203935">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-light" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":30203935,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="c35b00e29a0ff655fb6e277eb9cbd003f1c15524f0d765932bb40ac6d17e186c" data-turbo="false" data-view-component="true" href="/metabase/metabase/pulls" id="pull-requests-tab-30203935">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <div class="px-3 pt-3">
#  <p class="color-fg-muted mb-0"></p><div>The simplest, fastest way to get business intelligence and analytics  to everyone in your company <g-emoji alias="yum" class="g-emoji" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/1f60b.png">😋</g-emoji>
#  </div>
#  </div>
#  <div class="d-flex flex-wrap border-bottom color-border-muted px-3 pt-2 pb-2">
#  <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":22,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="ab756594950fd1651e8e9ba091011e1dc1c26250c423927c8033e22d6e93dc91" data-view-component="true" href="/topics/visualization" title="Topic: visualization">
#                visualization
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":42,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="a15c9305aaca063a9eb078d9e1a65cf55996b3811d87d1f37cd9fb59cedc136a" data-view-component="true" href="/topics/mysql" title="Topic: mysql">
#                mysql
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":241,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="9335c60e5fb58f48e3ec476eae248c7e6836828e926406f5c420bcc8e091eb46" data-view-component="true" href="/topics/slack" title="Topic: slack">
#                slack
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":831,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="4866435a14079bbe7d47b42a663d09879f4ec54840adda073a7856b7005635ec" data-view-component="true" href="/topics/postgres" title="Topic: postgres">
#                postgres
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":2131,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="702fdaa7da1e8784cfb31466c2b01242924323b9c255fe47daf0a6840e7cc3c4" data-view-component="true" href="/topics/data" title="Topic: data">
#                data
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":2340,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="1e6556d1d50e278e2eaf459771d8c52441a3038507a1effae5d4f80a59fdd44a" data-view-component="true" href="/topics/clojure" title="Topic: clojure">
#                clojure
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":8897,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="71682c5feb5927e5c92a8a0c6c9d59036e0551f215d287a6733e3396dad4ecdf" data-view-component="true" href="/topics/bi" title="Topic: bi">
#                bi
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":8961,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="889d218f73c2f47534af41359f4a4e615f653bb919e643875e12cf5792d9d030" data-view-component="true" href="/topics/database" title="Topic: database">
#                database
# ...
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-dark" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":41609775,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="c6b1c23a0903ff7fcdf89bef6d8a03265cbde34ee48e2dca928c07cf25d32601" data-turbo="false" data-view-component="true" href="/diesel-rs/diesel/pulls" id="pull-requests-tab-41609775">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository discussions, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_DISCUSSIONS","click_visual_representation":"DISCUSSIONS_TAB","actor_id":null,"record_id":41609775,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="a1158998740e35c37806dd2cc650ff8af75b466bed473010677db5dee9651d4b" data-turbo="false" data-view-component="true" href="/diesel-rs/diesel/discussions" id="discussions-tab-41609775">
#  <svg aria-hidden="true" class="octicon octicon-comment-discussion color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M1.5 2.75a.25.25 0 01.25-.25h8.5a.25.25 0 01.25.25v5.5a.25.25 0 01-.25.25h-3.5a.75.75 0 00-.53.22L3.5 11.44V9.25a.75.75 0 00-.75-.75h-1a.25.25 0 01-.25-.25v-5.5zM1.75 1A1.75 1.75 0 000 2.75v5.5C0 9.216.784 10 1.75 10H2v1.543a1.457 1.457 0 002.487 1.03L7.061 10h3.189A1.75 1.75 0 0012 8.25v-5.5A1.75 1.75 0 0010.25 1h-8.5zM14.5 4.75a.25.25 0 00-.25-.25h-.5a.75.75 0 110-1.5h.5c.966 0 1.75.784 1.75 1.75v5.5A1.75 1.75 0 0114.25 12H14v1.543a1.457 1.457 0 01-2.487 1.03L9.22 12.28a.75.75 0 111.06-1.06l2.22 2.22v-2.19a.75.75 0 01.75-.75h1a.25.25 0 00.25-.25v-5.5z" fill-rule="evenodd"></path>
#  </svg> Discussions
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <article class="p-3">
#  <div class="d-flex flex-justify-between mb-3">
#  <div class="d-flex flex-items-center">
#  <span class="State State--open State--small v-align-bottom mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto f3 text-normal ml-1 wb-break-word">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"BIG_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1177331013,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="990ae734b7792300c6cae21296ccfd8107e0c2062c2b730eedd981688bf97bba" data-turbo="false" data-view-component="true" href="https://github.com/diesel-rs/diesel/issues/3094">
#                  Document PostgreSQL features and operators pertaining to JSON/ JSONB columns in the changelog.
#  </a> </h4>
#  </div>
#  </div>
#  <div class="d-flex">
#  <div class="mr-3">
#  <img alt="czotomo" class="avatar avatar-user avatar-small" height="32" src="https://avatars.githubusercontent.com/u/13033195?v=4" width="32"/>
#  </div>
#  <div class="flex-auto" style="width: 80%;">
#  <div class="Box Box--condensed position-relative timeline-comment--caret">
#  <div class="Box-header f6 color-fg-muted">
#  <strong class="color-fg-default text-bold">
#                    czotomo
#                  </strong>
#
#                    commented
#
#                  <relative-time class="no-wrap" datetime="2022-03-22T21:31:52Z">Mar 22, 2022</relative-time>
#  </div>
#  <div class="Box-body comment-body markdown-body position-relative overflow-hidden pt-3" style="max-height:200px">
#  <p>Original issue:</p>
#  <p><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="issue" data-hovercard-url="/diesel-rs/diesel/issues/3032/hovercard" data-id="1117631642" data-permission-text="Title is private" data-url="https://github.com/diesel-rs/diesel/issues/3032" href="https://github.com/diesel-rs/diesel/issues/3032">diesel-rs/diesel#3032</a></p>
#  <p>Relevant PRs:</p>
#  <p><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/diesel-rs/diesel/pull/3035/hovercard" data-id="1121233770" data-permission-text="Title is private" data-url="https://github.com/diesel-rs/diesel/issues/3035" href="https://github.com/diesel-rs/diesel/pull/3035">diesel-rs/diesel#3035</a><br/>
#  <a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/diesel-rs/diesel/pull/3036/hovercard" data-id="1123616310" data-permission-text="Title is private" data-url="https://github.com/diesel-rs/diesel/issues/3036" href="https://github.com/diesel-rs/diesel/pull/3036">diesel-rs/diesel#3036</a><br/>
#  <a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/diesel-rs/diesel/pull/3037/hovercard" data-id="1125194132" data-permission-text="Title is private" data-url="https://github.com/diesel-rs/diesel/issues/3037" href="https://github.com/diesel-rs/diesel/pull/3037">diesel-rs/diesel#3037</a><br/>
#  <a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/diesel-rs/diesel/pull/3092/hovercard" data-id="1174279706" data-permission-text="Title is private" data-url="https://github.com/diesel-rs/diesel/issues/3092" href="https://github.com/diesel-rs/diesel/pull/3092">diesel-rs/diesel#3092</a></p>
#  <div class="position-absolute right-0 left-0 bottom-0 text-center" style="background: linear-gradient(to top, var(--color-canvas-default), var(--color-canvas-default-transparent));">
#  <a class="btn btn-outline btn-sm mx-auto my-3" data-ga-click="Explore, go to issue, location:good first issues;text:read more;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"READ_MORE","actor_id":null,"record_id":1177331013,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="6c514eac29454621bc530dae0e13d5953d75f1e4357a6b758c6d1e36dbd5c8da" href="https://github.com/diesel-rs/diesel/issues/3094">
#                        Read more
#  </a> </div>
#  </div>
#  </div>
#  <div class="mt-3">
#  <span class="discussion-item-icon border-white-fade ml-0 mr-2">
#  <svg aria-hidden="true" class="octicon octicon-tag" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.5 7.775V2.75a.25.25 0 01.25-.25h5.025a.25.25 0 01.177.073l6.25 6.25a.25.25 0 010 .354l-5.025 5.025a.25.25 0 01-.354 0l-6.25-6.25a.25.25 0 01-.073-.177zm-1.5 0V2.75C1 1.784 1.784 1 2.75 1h5.025c.464 0 .91.184 1.238.513l6.25 6.25a1.75 1.75 0 010 2.474l-5.026 5.026a1.75 1.75 0 01-2.474 0l-6.25-6.25A1.75 1.75 0 011 7.775zM6 5a1 1 0 100 2 1 1 0 000-2z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <div class="wb-break-word">
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":254193215,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="7942fcac6a379f1ff33ddc41fc4fe0c24a4b062ae43f71031df071645d542c25" data-name="help wanted" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22help+wanted%22" id="label-4c9554" style="--label-r:21;--label-g:152;--label-b:24;--label-h:121;--label-s:75;--label-l:33;">
#                      help wanted
#  </a>
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":292540851,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="4455e496e004928ddd7947344bda3780831e175e98a4dcabec076e09a2d5e369" data-name="good first issue" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22good+first+issue%22" id="label-a2cff3" style="--label-r:212;--label-g:197;--label-b:249;--label-h:257;--label-s:81;--label-l:87;">
#                      good first issue
#  </a>
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":361388486,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="a35e5da3b0962cc02ce9add473fd2d2dad12569a646eb634b22038484c76e851" data-name="documentation" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3Adocumentation" id="label-9f8ba2" style="--label-r:83;--label-g:25;--label-b:231;--label-h:256;--label-s:81;--label-l:50;">
#                      documentation
#  </a>
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":536100334,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="af0e3c0e4393eccbbd4951928cbabd9a5250c0963aa99fe869db4f70c0bbc968" data-name="postgres" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3Apostgres" id="label-988005" style="--label-r:197;--label-g:222;--label-b:245;--label-h:208;--label-s:70;--label-l:86;">
#                      postgres
#  </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </article>
#  <div class="px-3 pb-3">
#  <article class="d-flex flex-justify-between mb-2">
#  <div class="d-flex flex-items-center">
#  <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto h5 ml-1 wb-break-word">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:small;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"LITTLE_GOOD_FIRST_ISSUE","actor_id":null,"record_id":899103564,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="d7e1e699ea8ea764ac4aefaedf81516b29f1c0c95241717c552025c532b5a7c1" data-turbo="false" data-view-component="true" href="https://github.com/diesel-rs/diesel/issues/2793">
#                      AsChangeset and Insertable produce unhelpful error messages
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                    5
#                  </div>
#  </article>
#  <article class="d-flex flex-justify-between mb-2">
#  <div class="d-flex flex-items-center">
#  <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto h5 ml-1 wb-break-word">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:small;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"LITTLE_GOOD_FIRST_ISSUE","actor_id":null,"record_id":737168691,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="331ed7be4697a0550e61f3f65ae8e2e2efca9cad6db2b39b9fb503914424143e" data-turbo="false" data-view-component="true" href="https://github.com/diesel-rs/diesel/issues/2555">
#                      Experiment with generate `allow_columns_to_appear_in_same_group_by_clause!` via `diesel print-schema`
#  </a> </h4>
#  </div>
#  </article>
#  <div class="mt-3">
#  <a class="btn btn-outline btn-sm" data-ga-click="Explore, go to repository contribute, location:good first issues; text:more good first issues;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_CONTRIBUTE_PAGE","click_visual_representation":"CLICK_VISUAL_REPRESENTATION_UNKNOWN","actor_id":null,"record_id":41609775,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="8193470eaf04e595ef879ab08a4eada48f94b81abded09c1208f21b121c6b435" data-turbo="false" data-view-component="true" href="/diesel-rs/diesel/contribute">
#                  Find more good first issues
#  </a> </div>
#  </div>
#  </div>
#  </article>]

# %%
page_1 = []
for item in all_article:
    Repository_name = item.find('a',class_='text-bold wb-break-word').text
    User_name = item.find('a',class_='').text
    Stars = item.find('span',class_='Counter js-social-count').text
    URL = item.find('a',class_='text-bold wb-break-word')['href']
    User_name = User_name.strip()
    Repository_name = Repository_name.strip()
    URL = URL.strip()
    Stars = Stars.strip()
    page_1_dict = {
        'Repository Name': Repository_name,
        'User Name': User_name,
        'Stars': Stars,
        'URL': base_Url + Url
    }
    
    page_1.append(page_1_dict)

# %%
print(page_1)
# Out:
# [{'Repository Name': 'discourse', 'User Name': 'discourse', 'Stars': '36.1k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'supabase', 'User Name': 'supabase', 'Stars': '36k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'metabase', 'User Name': 'metabase', 'Stars': '29.3k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'nocodb', 'User Name': 'nocodb', 'Stars': '29k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'typeorm', 'User Name': 'typeorm', 'Stars': '28.9k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'dbeaver', 'User Name': 'dbeaver', 'Stars': '27.6k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'sequelize', 'User Name': 'sequelize', 'Stars': '26.5k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'prisma', 'User Name': 'prisma', 'Stars': '24.5k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'redash', 'User Name': 'getredash', 'Stars': '21.5k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'postgrest', 'User Name': 'PostgREST', 'Stars': '19k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'directus', 'User Name': 'directus', 'Stars': '17.1k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'shardingsphere', 'User Name': 'apache', 'Stars': '16.8k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'knex', 'User Name': 'knex', 'Stars': '16.2k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'Qix', 'User Name': 'ty4z2008', 'Stars': '13.9k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'APIJSON', 'User Name': 'Tencent', 'Stars': '13.6k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'cube.js', 'User Name': 'cube-js', 'Stars': '13.5k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'timescaledb', 'User Name': 'timescale', 'Stars': '13.4k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'mybatis-plus', 'User Name': 'baomidou', 'Stars': '13.3k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'NodeBB', 'User Name': 'NodeBB', 'Stars': '12.8k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'cal.com', 'User Name': 'calcom', 'Stars': '12.5k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'analytics', 'User Name': 'plausible', 'Stars': '11.9k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'postgraphile', 'User Name': 'graphile', 'Stars': '11.4k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'beekeeper-studio', 'User Name': 'beekeeper-studio', 'Stars': '11k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'node-postgres', 'User Name': 'brianc', 'Stars': '10.6k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'pgcli', 'User Name': 'dbcli', 'Stars': '10.5k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'full-stack-fastapi-postgresql', 'User Name': 'tiangolo', 'Stars': '9.4k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'dogehouse', 'User Name': 'benawad', 'Stars': '9.2k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'mindsdb', 'User Name': 'mindsdb', 'Stars': '9k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'questdb', 'User Name': 'questdb', 'Stars': '8.9k', 'URL': 'https://github.com//discourse/discourse'}, {'Repository Name': 'diesel', 'User Name': 'diesel-rs', 'Stars': '8.8k', 'URL': 'https://github.com//discourse/discourse'}]

# %%
import pandas as pd

# %%
df = pd.DataFrame(page_1)

# %%
df
# Out:
#                   Repository Name         User Name  Stars  \
# 0                       discourse         discourse  36.1k
# 1                        supabase          supabase    36k
# 2                        metabase          metabase  29.3k
# 3                          nocodb            nocodb    29k
# 4                         typeorm           typeorm  28.9k
# 5                         dbeaver           dbeaver  27.6k
# 6                       sequelize         sequelize  26.5k
# 7                          prisma            prisma  24.5k
# 8                          redash         getredash  21.5k
# 9                       postgrest         PostgREST    19k
# 10                       directus          directus  17.1k
# 11                 shardingsphere            apache  16.8k
# 12                           knex              knex  16.2k
# 13                            Qix          ty4z2008  13.9k
# 14                        APIJSON           Tencent  13.6k
# 15                        cube.js           cube-js  13.5k
# 16                    timescaledb         timescale  13.4k
# 17                   mybatis-plus          baomidou  13.3k
# 18                         NodeBB            NodeBB  12.8k
# 19                        cal.com            calcom  12.5k
# 20                      analytics         plausible  11.9k
# 21                   postgraphile          graphile  11.4k
# 22               beekeeper-studio  beekeeper-studio    11k
# 23                  node-postgres            brianc  10.6k
# 24                          pgcli             dbcli  10.5k
# 25  full-stack-fastapi-postgresql          tiangolo   9.4k
# 26                      dogehouse           benawad   9.2k
# 27                        mindsdb           mindsdb     9k
# 28                        questdb           questdb   8.9k
# 29                         diesel         diesel-rs   8.8k
#
#                                         URL
# 0   https://github.com//discourse/discourse
# 1   https://github.com//discourse/discourse
# 2   https://github.com//discourse/discourse
# 3   https://github.com//discourse/discourse
# 4   https://github.com//discourse/discourse
# 5   https://github.com//discourse/discourse
# 6   https://github.com//discourse/discourse
# 7   https://github.com//discourse/discourse
# 8   https://github.com//discourse/discourse
# 9   https://github.com//discourse/discourse
# 10  https://github.com//discourse/discourse
# 11  https://github.com//discourse/discourse
# 12  https://github.com//discourse/discourse
# 13  https://github.com//discourse/discourse
# 14  https://github.com//discourse/discourse
# 15  https://github.com//discourse/discourse
# 16  https://github.com//discourse/discourse
# 17  https://github.com//discourse/discourse
# 18  https://github.com//discourse/discourse
# 19  https://github.com//discourse/discourse
# 20  https://github.com//discourse/discourse
# 21  https://github.com//discourse/discourse
# 22  https://github.com//discourse/discourse
# 23  https://github.com//discourse/discourse
# 24  https://github.com//discourse/discourse
# 25  https://github.com//discourse/discourse
# 26  https://github.com//discourse/discourse
# 27  https://github.com//discourse/discourse
# 28  https://github.com//discourse/discourse
# 29  https://github.com//discourse/discourse

# %%
df.to_excel('Page1.xlsx')

# %%
base_url = 'https://github.com/topics/postgresql?page='

# %%
url = []
for num in range(1,8):

    url.append(base_url+str(num))

# %%
(url)
# Out:
# ['https://github.com/topics/postgresql?page=1',
#  'https://github.com/topics/postgresql?page=2',
#  'https://github.com/topics/postgresql?page=3',
#  'https://github.com/topics/postgresql?page=4',
#  'https://github.com/topics/postgresql?page=5',
#  'https://github.com/topics/postgresql?page=6',
#  'https://github.com/topics/postgresql?page=7']

# %%
all_article_lst = []
for url_data in url:
    html_data = requests.get(url_data).text
   # print(url_data)
    converted_data = BeautifulSoup(html_data,'lxml')
    all_article = converted_data.find_all('article',class_='border rounded color-shadow-small color-bg-subtle my-4')
   # print(all_article)
    for item in all_article:
        Repository_name = item.find('a',class_='text-bold wb-break-word').text
        Repository_name = Repository_name.strip()
        User_name = item.find('a',class_='').text
        User_name = User_name.strip()
        Stars = item.find('span',class_='Counter js-social-count').text
        URL = item.find('a',class_='text-bold wb-break-word')['href']
        URL = URL.strip()
        
        
        dict2 = {
            'Repository Name': Repository_name,
            'User Name': User_name,
            'Stars': Stars,
            'URL': base_Url +URL
        }
        
        print(dict2)
        
        
        all_article_lst.append(dict2)
# Out:
# {'Repository Name': 'discourse', 'User Name': 'discourse', 'Stars': '36.1k', 'URL': 'https://github.com//discourse/discourse'}
# {'Repository Name': 'supabase', 'User Name': 'supabase', 'Stars': '36k', 'URL': 'https://github.com//supabase/supabase'}
# {'Repository Name': 'metabase', 'User Name': 'metabase', 'Stars': '29.3k', 'URL': 'https://github.com//metabase/metabase'}
# {'Repository Name': 'nocodb', 'User Name': 'nocodb', 'Stars': '29k', 'URL': 'https://github.com//nocodb/nocodb'}
# {'Repository Name': 'typeorm', 'User Name': 'typeorm', 'Stars': '28.9k', 'URL': 'https://github.com//typeorm/typeorm'}
# {'Repository Name': 'dbeaver', 'User Name': 'dbeaver', 'Stars': '27.6k', 'URL': 'https://github.com//dbeaver/dbeaver'}
# {'Repository Name': 'sequelize', 'User Name': 'sequelize', 'Stars': '26.5k', 'URL': 'https://github.com//sequelize/sequelize'}
# {'Repository Name': 'prisma', 'User Name': 'prisma', 'Stars': '24.5k', 'URL': 'https://github.com//prisma/prisma'}
# {'Repository Name': 'redash', 'User Name': 'getredash', 'Stars': '21.5k', 'URL': 'https://github.com//getredash/redash'}
# {'Repository Name': 'postgrest', 'User Name': 'PostgREST', 'Stars': '19k', 'URL': 'https://github.com//PostgREST/postgrest'}
# {'Repository Name': 'shardingsphere', 'User Name': 'apache', 'Stars': '16.8k', 'URL': 'https://github.com//apache/shardingsphere'}
# {'Repository Name': 'knex', 'User Name': 'knex', 'Stars': '16.2k', 'URL': 'https://github.com//knex/knex'}
# {'Repository Name': 'APIJSON', 'User Name': 'Tencent', 'Stars': '13.6k', 'URL': 'https://github.com//Tencent/APIJSON'}
# {'Repository Name': 'cube.js', 'User Name': 'cube-js', 'Stars': '13.5k', 'URL': 'https://github.com//cube-js/cube.js'}
# {'Repository Name': 'timescaledb', 'User Name': 'timescale', 'Stars': '13.4k', 'URL': 'https://github.com//timescale/timescaledb'}
# {'Repository Name': 'mybatis-plus', 'User Name': 'baomidou', 'Stars': '13.3k', 'URL': 'https://github.com//baomidou/mybatis-plus'}
# {'Repository Name': 'NodeBB', 'User Name': 'NodeBB', 'Stars': '12.8k', 'URL': 'https://github.com//NodeBB/NodeBB'}
# {'Repository Name': 'cal.com', 'User Name': 'calcom', 'Stars': '12.5k', 'URL': 'https://github.com//calcom/cal.com'}
# {'Repository Name': 'analytics', 'User Name': 'plausible', 'Stars': '11.9k', 'URL': 'https://github.com//plausible/analytics'}
# {'Repository Name': 'postgraphile', 'User Name': 'graphile', 'Stars': '11.4k', 'URL': 'https://github.com//graphile/postgraphile'}
# {'Repository Name': 'beekeeper-studio', 'User Name': 'beekeeper-studio', 'Stars': '11k', 'URL': 'https://github.com//beekeeper-studio/beekeeper-studio'}
# {'Repository Name': 'node-postgres', 'User Name': 'brianc', 'Stars': '10.6k', 'URL': 'https://github.com//brianc/node-postgres'}
# {'Repository Name': 'pgcli', 'User Name': 'dbcli', 'Stars': '10.5k', 'URL': 'https://github.com//dbcli/pgcli'}
# {'Repository Name': 'full-stack-fastapi-postgresql', 'User Name': 'tiangolo', 'Stars': '9.4k', 'URL': 'https://github.com//tiangolo/full-stack-fastapi-postgresql'}
# {'Repository Name': 'dogehouse', 'User Name': 'benawad', 'Stars': '9.2k', 'URL': 'https://github.com//benawad/dogehouse'}
# {'Repository Name': 'mindsdb', 'User Name': 'mindsdb', 'Stars': '9k', 'URL': 'https://github.com//mindsdb/mindsdb'}
# {'Repository Name': 'questdb', 'User Name': 'questdb', 'Stars': '8.9k', 'URL': 'https://github.com//questdb/questdb'}
# {'Repository Name': 'dbal', 'User Name': 'doctrine', 'Stars': '8.7k', 'URL': 'https://github.com//doctrine/dbal'}
# {'Repository Name': 'awesome-postgres', 'User Name': 'dhamaniasad', 'Stars': '7.9k', 'URL': 'https://github.com//dhamaniasad/awesome-postgres'}
# {'Repository Name': 'usql', 'User Name': 'xo', 'Stars': '7.5k', 'URL': 'https://github.com//xo/usql'}
# {'Repository Name': 'dbal', 'User Name': 'doctrine', 'Stars': '8.7k', 'URL': 'https://github.com//doctrine/dbal'}
# {'Repository Name': 'awesome-postgres', 'User Name': 'dhamaniasad', 'Stars': '7.9k', 'URL': 'https://github.com//dhamaniasad/awesome-postgres'}
# {'Repository Name': 'usql', 'User Name': 'xo', 'Stars': '7.5k', 'URL': 'https://github.com//xo/usql'}
# {'Repository Name': 'pgweb', 'User Name': 'sosedoff', 'Stars': '7.4k', 'URL': 'https://github.com//sosedoff/pgweb'}
# {'Repository Name': 'citus', 'User Name': 'citusdata', 'Stars': '6.9k', 'URL': 'https://github.com//citusdata/citus'}
# {'Repository Name': 'azuredatastudio', 'User Name': 'microsoft', 'Stars': '6.9k', 'URL': 'https://github.com//microsoft/azuredatastudio'}
# {'Repository Name': 'blog', 'User Name': 'digoal', 'Stars': '6.8k', 'URL': 'https://github.com//digoal/blog'}
# {'Repository Name': 'flyway', 'User Name': 'flyway', 'Stars': '6.6k', 'URL': 'https://github.com//flyway/flyway'}
# {'Repository Name': 'xorm', 'User Name': 'go-xorm', 'Stars': '6.5k', 'URL': 'https://github.com//go-xorm/xorm'}
# {'Repository Name': 'sqlx', 'User Name': 'launchbadge', 'Stars': '6.5k', 'URL': 'https://github.com//launchbadge/sqlx'}
# {'Repository Name': 'bookshelf', 'User Name': 'bookshelf', 'Stars': '6.3k', 'URL': 'https://github.com//bookshelf/bookshelf'}
# {'Repository Name': 'NewsBlur', 'User Name': 'samuelclay', 'Stars': '6k', 'URL': 'https://github.com//samuelclay/NewsBlur'}
# {'Repository Name': 'sqlc', 'User Name': 'kyleconroy', 'Stars': '6k', 'URL': 'https://github.com//kyleconroy/sqlc'}
# {'Repository Name': 'dev-setup', 'User Name': 'donnemartin', 'Stars': '5.8k', 'URL': 'https://github.com//donnemartin/dev-setup'}
# {'Repository Name': 'asyncpg', 'User Name': 'MagicStack', 'Stars': '5.6k', 'URL': 'https://github.com//MagicStack/asyncpg'}
# {'Repository Name': 'adminer', 'User Name': 'vrana', 'Stars': '5.3k', 'URL': 'https://github.com//vrana/adminer'}
# {'Repository Name': 'gpdb', 'User Name': 'greenplum-db', 'Stars': '5.3k', 'URL': 'https://github.com//greenplum-db/gpdb'}
# {'Repository Name': 'openreplay', 'User Name': 'openreplay', 'Stars': '5.3k', 'URL': 'https://github.com//openreplay/openreplay'}
# {'Repository Name': 'pg', 'User Name': 'go-pg', 'Stars': '5.1k', 'URL': 'https://github.com//go-pg/pg'}
# {'Repository Name': 'realtime', 'User Name': 'supabase', 'Stars': '5.1k', 'URL': 'https://github.com//supabase/realtime'}
# {'Repository Name': 'sqlboiler', 'User Name': 'volatiletech', 'Stars': '5.1k', 'URL': 'https://github.com//volatiletech/sqlboiler'}
# {'Repository Name': 'jOOQ', 'User Name': 'jOOQ', 'Stars': '5k', 'URL': 'https://github.com//jOOQ/jOOQ'}
# {'Repository Name': 'falcon', 'User Name': 'plotly', 'Stars': '4.9k', 'URL': 'https://github.com//plotly/falcon'}
# {'Repository Name': 'mikro-orm', 'User Name': 'mikro-orm', 'Stars': '4.8k', 'URL': 'https://github.com//mikro-orm/mikro-orm'}
# {'Repository Name': 'patroni', 'User Name': 'zalando', 'Stars': '4.8k', 'URL': 'https://github.com//zalando/patroni'}
# {'Repository Name': 'backup', 'User Name': 'backup', 'Stars': '4.7k', 'URL': 'https://github.com//backup/backup'}
# {'Repository Name': 'sysbench', 'User Name': 'akopytov', 'Stars': '4.6k', 'URL': 'https://github.com//akopytov/sysbench'}
# {'Repository Name': 'FerretDB', 'User Name': 'FerretDB', 'Stars': '4.6k', 'URL': 'https://github.com//FerretDB/FerretDB'}
# {'Repository Name': 'react-firebase-starter', 'User Name': 'kriasoft', 'Stars': '4.4k', 'URL': 'https://github.com//kriasoft/react-firebase-starter'}
# {'Repository Name': 'materialize', 'User Name': 'MaterializeInc', 'Stars': '4.3k', 'URL': 'https://github.com//MaterializeInc/materialize'}
# {'Repository Name': 'bolt', 'User Name': 'bolt', 'Stars': '4.1k', 'URL': 'https://github.com//bolt/bolt'}
# {'Repository Name': 'SqlSugar', 'User Name': 'donet5', 'Stars': '4.1k', 'URL': 'https://github.com//donet5/SqlSugar'}
# {'Repository Name': 'postgres', 'User Name': 'porsager', 'Stars': '4.1k', 'URL': 'https://github.com//porsager/postgres'}
# {'Repository Name': 'pgloader', 'User Name': 'dimitri', 'Stars': '4.1k', 'URL': 'https://github.com//dimitri/pgloader'}
# {'Repository Name': 'coolify', 'User Name': 'coollabsio', 'Stars': '4.1k', 'URL': 'https://github.com//coollabsio/coolify'}
# {'Repository Name': 'zombodb', 'User Name': 'zombodb', 'Stars': '4.1k', 'URL': 'https://github.com//zombodb/zombodb'}
# {'Repository Name': 'franchise', 'User Name': 'HVF', 'Stars': '3.9k', 'URL': 'https://github.com//HVF/franchise'}
# {'Repository Name': 'devilbox', 'User Name': 'cytopia', 'Stars': '3.8k', 'URL': 'https://github.com//cytopia/devilbox'}
# {'Repository Name': 'v2', 'User Name': 'miniflux', 'Stars': '3.8k', 'URL': 'https://github.com//miniflux/v2'}
# {'Repository Name': 'neon', 'User Name': 'neondatabase', 'Stars': '3.8k', 'URL': 'https://github.com//neondatabase/neon'}
# {'Repository Name': 'JSqlParser', 'User Name': 'JSQLParser', 'Stars': '3.8k', 'URL': 'https://github.com//JSQLParser/JSqlParser'}
# {'Repository Name': 'stolon', 'User Name': 'sorintlab', 'Stars': '3.7k', 'URL': 'https://github.com//sorintlab/stolon'}
# {'Repository Name': 'octosql', 'User Name': 'cube2222', 'Stars': '3.7k', 'URL': 'https://github.com//cube2222/octosql'}
# {'Repository Name': 'relay-starter-kit', 'User Name': 'kriasoft', 'Stars': '3.6k', 'URL': 'https://github.com//kriasoft/relay-starter-kit'}
# {'Repository Name': 'ihp', 'User Name': 'digitallyinduced', 'Stars': '3.4k', 'URL': 'https://github.com//digitallyinduced/ihp'}
# {'Repository Name': 'FreeSql', 'User Name': 'dotnetcore', 'Stars': '3.3k', 'URL': 'https://github.com//dotnetcore/FreeSql'}
# {'Repository Name': 'wal-e', 'User Name': 'wal-e', 'Stars': '3.3k', 'URL': 'https://github.com//wal-e/wal-e'}
# {'Repository Name': 'dolibarr', 'User Name': 'Dolibarr', 'Stars': '3.3k', 'URL': 'https://github.com//Dolibarr/dolibarr'}
# {'Repository Name': 'HeidiSQL', 'User Name': 'HeidiSQL', 'Stars': '3.3k', 'URL': 'https://github.com//HeidiSQL/HeidiSQL'}
# {'Repository Name': 'prest', 'User Name': 'prest', 'Stars': '3.3k', 'URL': 'https://github.com//prest/prest'}
# {'Repository Name': 'bytebase', 'User Name': 'bytebase', 'Stars': '3.3k', 'URL': 'https://github.com//bytebase/bytebase'}
# {'Repository Name': 'xo', 'User Name': 'xo', 'Stars': '3.2k', 'URL': 'https://github.com//xo/xo'}
# {'Repository Name': 'pg-promise', 'User Name': 'vitaly-t', 'Stars': '3.2k', 'URL': 'https://github.com//vitaly-t/pg-promise'}
# {'Repository Name': 'db', 'User Name': 'upper', 'Stars': '3.1k', 'URL': 'https://github.com//upper/db'}
# {'Repository Name': 'slonik', 'User Name': 'gajus', 'Stars': '3.1k', 'URL': 'https://github.com//gajus/slonik'}
# {'Repository Name': 'encore', 'User Name': 'encoredev', 'Stars': '3.1k', 'URL': 'https://github.com//encoredev/encore'}
# {'Repository Name': 'node-orm2', 'User Name': 'dresende', 'Stars': '3.1k', 'URL': 'https://github.com//dresende/node-orm2'}
# {'Repository Name': 'php-crud-api', 'User Name': 'mevdschee', 'Stars': '3.1k', 'URL': 'https://github.com//mevdschee/php-crud-api'}
# {'Repository Name': 'tortoise-orm', 'User Name': 'tortoise', 'Stars': '3k', 'URL': 'https://github.com//tortoise/tortoise-orm'}
# {'Repository Name': 'pony', 'User Name': 'ponyorm', 'Stars': '3k', 'URL': 'https://github.com//ponyorm/pony'}
# {'Repository Name': 'Replibyte', 'User Name': 'Qovery', 'Stars': '3k', 'URL': 'https://github.com//Qovery/Replibyte'}
# {'Repository Name': 'postgres-operator', 'User Name': 'CrunchyData', 'Stars': '2.9k', 'URL': 'https://github.com//CrunchyData/postgres-operator'}
# {'Repository Name': 'goose', 'User Name': 'pressly', 'Stars': '2.8k', 'URL': 'https://github.com//pressly/goose'}
# {'Repository Name': 'sequelize-docs-Zh-CN', 'User Name': 'demopark', 'Stars': '2.8k', 'URL': 'https://github.com//demopark/sequelize-docs-Zh-CN'}
# {'Repository Name': 'formspree', 'User Name': 'formspree', 'Stars': '2.8k', 'URL': 'https://github.com//formspree/formspree'}
# {'Repository Name': 'TablePlus', 'User Name': 'TablePlus', 'Stars': '2.7k', 'URL': 'https://github.com//TablePlus/TablePlus'}
# {'Repository Name': 'pgbadger', 'User Name': 'darold', 'Stars': '2.7k', 'URL': 'https://github.com//darold/pgbadger'}
# {'Repository Name': 'dbmate', 'User Name': 'amacneil', 'Stars': '2.7k', 'URL': 'https://github.com//amacneil/dbmate'}
# {'Repository Name': 'EFCore.BulkExtensions', 'User Name': 'borisdj', 'Stars': '2.7k', 'URL': 'https://github.com//borisdj/EFCore.BulkExtensions'}
# {'Repository Name': 'psycopg2', 'User Name': 'psycopg', 'Stars': '2.7k', 'URL': 'https://github.com//psycopg/psycopg2'}
# {'Repository Name': 'postgres-operator', 'User Name': 'zalando', 'Stars': '2.6k', 'URL': 'https://github.com//zalando/postgres-operator'}
# {'Repository Name': 'notadd', 'User Name': 'notadd', 'Stars': '2.6k', 'URL': 'https://github.com//notadd/notadd'}
# {'Repository Name': 'npgsql', 'User Name': 'npgsql', 'Stars': '2.6k', 'URL': 'https://github.com//npgsql/npgsql'}
# {'Repository Name': 'migra', 'User Name': 'djrobstep', 'Stars': '2.5k', 'URL': 'https://github.com//djrobstep/migra'}
# {'Repository Name': 'scala-exercises', 'User Name': 'scala-exercises', 'Stars': '2.5k', 'URL': 'https://github.com//scala-exercises/scala-exercises'}
# {'Repository Name': 'massive-js', 'User Name': 'dmfay', 'Stars': '2.5k', 'URL': 'https://github.com//dmfay/massive-js'}
# {'Repository Name': 'pipelinedb', 'User Name': 'pipelinedb', 'Stars': '2.5k', 'URL': 'https://github.com//pipelinedb/pipelinedb'}
# {'Repository Name': 'pgmodeler', 'User Name': 'pgmodeler', 'Stars': '2.5k', 'URL': 'https://github.com//pgmodeler/pgmodeler'}
# {'Repository Name': 'sqitch', 'User Name': 'sqitchers', 'Stars': '2.4k', 'URL': 'https://github.com//sqitchers/sqitch'}
# {'Repository Name': 'changelog.com', 'User Name': 'thechangelog', 'Stars': '2.4k', 'URL': 'https://github.com//thechangelog/changelog.com'}
# {'Repository Name': 'datastation', 'User Name': 'multiprocessio', 'Stars': '2.4k', 'URL': 'https://github.com//multiprocessio/datastation'}
# {'Repository Name': 'linq2db', 'User Name': 'linq2db', 'Stars': '2.4k', 'URL': 'https://github.com//linq2db/linq2db'}
# {'Repository Name': 'pgsync', 'User Name': 'ankane', 'Stars': '2.4k', 'URL': 'https://github.com//ankane/pgsync'}
# {'Repository Name': 'PolarDB-for-PostgreSQL', 'User Name': 'ApsaraDB', 'Stars': '2.4k', 'URL': 'https://github.com//ApsaraDB/PolarDB-for-PostgreSQL'}
# {'Repository Name': 'querybuilder', 'User Name': 'sqlkata', 'Stars': '2.3k', 'URL': 'https://github.com//sqlkata/querybuilder'}
# {'Repository Name': 'postgresqltuner', 'User Name': 'jfcoz', 'Stars': '2.3k', 'URL': 'https://github.com//jfcoz/postgresqltuner'}
# {'Repository Name': 'graphjin', 'User Name': 'dosco', 'Stars': '2.3k', 'URL': 'https://github.com//dosco/graphjin'}
# {'Repository Name': 'tsung', 'User Name': 'processone', 'Stars': '2.3k', 'URL': 'https://github.com//processone/tsung'}
# {'Repository Name': 'wal-g', 'User Name': 'wal-g', 'Stars': '2.3k', 'URL': 'https://github.com//wal-g/wal-g'}
# {'Repository Name': 'sqlcheck', 'User Name': 'jarulraj', 'Stars': '2.1k', 'URL': 'https://github.com//jarulraj/sqlcheck'}
# {'Repository Name': 'coolstore-microservices', 'User Name': 'vietnam-devs', 'Stars': '2.1k', 'URL': 'https://github.com//vietnam-devs/coolstore-microservices'}
# {'Repository Name': 'fastapi-realworld-example-app', 'User Name': 'nsidnev', 'Stars': '2k', 'URL': 'https://github.com//nsidnev/fastapi-realworld-example-app'}
# {'Repository Name': 'algernon', 'User Name': 'xyproto', 'Stars': '2k', 'URL': 'https://github.com//xyproto/algernon'}
# {'Repository Name': 'sqler', 'User Name': 'alash3al', 'Stars': '2k', 'URL': 'https://github.com//alash3al/sqler'}
# {'Repository Name': 'Gopherus', 'User Name': 'tarunkant', 'Stars': '2k', 'URL': 'https://github.com//tarunkant/Gopherus'}
# {'Repository Name': 'webapp.rs', 'User Name': 'saschagrunert', 'Stars': '2k', 'URL': 'https://github.com//saschagrunert/webapp.rs'}
# {'Repository Name': 'pg_graphql', 'User Name': 'supabase', 'Stars': '2k', 'URL': 'https://github.com//supabase/pg_graphql'}
# {'Repository Name': 'steampipe', 'User Name': 'turbot', 'Stars': '1.9k', 'URL': 'https://github.com//turbot/steampipe'}
# {'Repository Name': 'mara-pipelines', 'User Name': 'mara', 'Stars': '1.9k', 'URL': 'https://github.com//mara/mara-pipelines'}
# {'Repository Name': 'ibis', 'User Name': 'ibis-project', 'Stars': '1.9k', 'URL': 'https://github.com//ibis-project/ibis'}
# {'Repository Name': 'sqorn', 'User Name': 'sqorn', 'Stars': '1.9k', 'URL': 'https://github.com//sqorn/sqorn'}
# {'Repository Name': 'pspg', 'User Name': 'okbob', 'Stars': '1.8k', 'URL': 'https://github.com//okbob/pspg'}
# {'Repository Name': 'denodb', 'User Name': 'eveningkid', 'Stars': '1.7k', 'URL': 'https://github.com//eveningkid/denodb'}
# {'Repository Name': 'pg_cron', 'User Name': 'citusdata', 'Stars': '1.7k', 'URL': 'https://github.com//citusdata/pg_cron'}
# {'Repository Name': 'pgbouncer', 'User Name': 'pgbouncer', 'Stars': '1.7k', 'URL': 'https://github.com//pgbouncer/pgbouncer'}
# {'Repository Name': 'cstore_fdw', 'User Name': 'citusdata', 'Stars': '1.7k', 'URL': 'https://github.com//citusdata/cstore_fdw'}
# {'Repository Name': 'dbgate', 'User Name': 'dbgate', 'Stars': '1.6k', 'URL': 'https://github.com//dbgate/dbgate'}
# {'Repository Name': 'goqu', 'User Name': 'doug-martin', 'Stars': '1.6k', 'URL': 'https://github.com//doug-martin/goqu'}
# {'Repository Name': 'backup-manager', 'User Name': 'backup-manager', 'Stars': '1.6k', 'URL': 'https://github.com//backup-manager/backup-manager'}
# {'Repository Name': 'pgx', 'User Name': 'tcdi', 'Stars': '1.6k', 'URL': 'https://github.com//tcdi/pgx'}
# {'Repository Name': 'pev2', 'User Name': 'dalibo', 'Stars': '1.6k', 'URL': 'https://github.com//dalibo/pev2'}
# {'Repository Name': 'ServiceStack.OrmLite', 'User Name': 'ServiceStack', 'Stars': '1.5k', 'URL': 'https://github.com//ServiceStack/ServiceStack.OrmLite'}
# {'Repository Name': 'plv8', 'User Name': 'plv8', 'Stars': '1.5k', 'URL': 'https://github.com//plv8/plv8'}
# {'Repository Name': 'pg_activity', 'User Name': 'dalibo', 'Stars': '1.5k', 'URL': 'https://github.com//dalibo/pg_activity'}
# {'Repository Name': 'pg_flame', 'User Name': 'mgartner', 'Stars': '1.5k', 'URL': 'https://github.com//mgartner/pg_flame'}
# {'Repository Name': 'postgresml', 'User Name': 'postgresml', 'Stars': '1.5k', 'URL': 'https://github.com//postgresml/postgresml'}
# {'Repository Name': 'data-diff', 'User Name': 'datafold', 'Stars': '1.5k', 'URL': 'https://github.com//datafold/data-diff'}
# {'Repository Name': 'logica', 'User Name': 'EvgSkv', 'Stars': '1.4k', 'URL': 'https://github.com//EvgSkv/logica'}
# {'Repository Name': 'tbls', 'User Name': 'k1LoW', 'Stars': '1.4k', 'URL': 'https://github.com//k1LoW/tbls'}
# {'Repository Name': 'pgtune', 'User Name': 'le0pard', 'Stars': '1.4k', 'URL': 'https://github.com//le0pard/pgtune'}
# {'Repository Name': 'starter', 'User Name': 'graphile', 'Stars': '1.4k', 'URL': 'https://github.com//graphile/starter'}
# {'Repository Name': 'ElectroCRUD', 'User Name': 'garrylachman', 'Stars': '1.4k', 'URL': 'https://github.com//garrylachman/ElectroCRUD'}
# {'Repository Name': 'pgcenter', 'User Name': 'lesovsky', 'Stars': '1.4k', 'URL': 'https://github.com//lesovsky/pgcenter'}
# {'Repository Name': 'Chloe', 'User Name': 'shuxinqin', 'Stars': '1.4k', 'URL': 'https://github.com//shuxinqin/Chloe'}
# {'Repository Name': 'pg_partman', 'User Name': 'pgpartman', 'Stars': '1.4k', 'URL': 'https://github.com//pgpartman/pg_partman'}
# {'Repository Name': 'barman', 'User Name': 'EnterpriseDB', 'Stars': '1.4k', 'URL': 'https://github.com//EnterpriseDB/barman'}
# {'Repository Name': 'Jailer', 'User Name': 'Wisser', 'Stars': '1.4k', 'URL': 'https://github.com//Wisser/Jailer'}
# {'Repository Name': 'transporter', 'User Name': 'compose', 'Stars': '1.3k', 'URL': 'https://github.com//compose/transporter'}
# {'Repository Name': 'reshape', 'User Name': 'fabianlindfors', 'Stars': '1.3k', 'URL': 'https://github.com//fabianlindfors/reshape'}
# {'Repository Name': 'repmgr', 'User Name': 'EnterpriseDB', 'Stars': '1.3k', 'URL': 'https://github.com//EnterpriseDB/repmgr'}
# {'Repository Name': 'pgwatch2', 'User Name': 'cybertec-postgresql', 'Stars': '1.3k', 'URL': 'https://github.com//cybertec-postgresql/pgwatch2'}
# {'Repository Name': 'motor-admin', 'User Name': 'motor-admin', 'Stars': '1.3k', 'URL': 'https://github.com//motor-admin/motor-admin'}
# {'Repository Name': 'database-lab-engine', 'User Name': 'postgres-ai', 'Stars': '1.3k', 'URL': 'https://github.com//postgres-ai/database-lab-engine'}
# {'Repository Name': 'logidze', 'User Name': 'palkan', 'Stars': '1.3k', 'URL': 'https://github.com//palkan/logidze'}
# {'Repository Name': 'postbird', 'User Name': 'Paxa', 'Stars': '1.3k', 'URL': 'https://github.com//Paxa/postbird'}
# {'Repository Name': 'sqldef', 'User Name': 'k0kubun', 'Stars': '1.3k', 'URL': 'https://github.com//k0kubun/sqldef'}
# {'Repository Name': 'prisma-client-go', 'User Name': 'prisma', 'Stars': '1.3k', 'URL': 'https://github.com//prisma/prisma-client-go'}
# {'Repository Name': 'aiopg', 'User Name': 'aio-libs', 'Stars': '1.3k', 'URL': 'https://github.com//aio-libs/aiopg'}
# {'Repository Name': 'bun', 'User Name': 'uptrace', 'Stars': '1.3k', 'URL': 'https://github.com//uptrace/bun'}
# {'Repository Name': 'pgbackrest', 'User Name': 'pgbackrest', 'Stars': '1.3k', 'URL': 'https://github.com//pgbackrest/pgbackrest'}
# {'Repository Name': 'bank', 'User Name': 'pietrzakadrian', 'Stars': '1.2k', 'URL': 'https://github.com//pietrzakadrian/bank'}
# {'Repository Name': 'docs4dev', 'User Name': 'docs4dev', 'Stars': '1.2k', 'URL': 'https://github.com//docs4dev/docs4dev'}
# {'Repository Name': 'fapro', 'User Name': 'fofapro', 'Stars': '1.2k', 'URL': 'https://github.com//fofapro/fapro'}
# {'Repository Name': 'pop', 'User Name': 'gobuffalo', 'Stars': '1.2k', 'URL': 'https://github.com//gobuffalo/pop'}
# {'Repository Name': 'trdsql', 'User Name': 'noborus', 'Stars': '1.2k', 'URL': 'https://github.com//noborus/trdsql'}
# {'Repository Name': 'scalikejdbc', 'User Name': 'scalikejdbc', 'Stars': '1.2k', 'URL': 'https://github.com//scalikejdbc/scalikejdbc'}
# {'Repository Name': 'readyset', 'User Name': 'readysettech', 'Stars': '1.2k', 'URL': 'https://github.com//readysettech/readyset'}
# {'Repository Name': 'postgis', 'User Name': 'postgis', 'Stars': '1.2k', 'URL': 'https://github.com//postgis/postgis'}
# {'Repository Name': 'agensgraph', 'User Name': 'bitnine-oss', 'Stars': '1.2k', 'URL': 'https://github.com//bitnine-oss/agensgraph'}
# {'Repository Name': 'kysely', 'User Name': 'koskimas', 'Stars': '1.2k', 'URL': 'https://github.com//koskimas/kysely'}
# {'Repository Name': 'metasfresh', 'User Name': 'metasfresh', 'Stars': '1.2k', 'URL': 'https://github.com//metasfresh/metasfresh'}
# {'Repository Name': 'fullstack-apollo-express-postgresql-boilerplate', 'User Name': 'the-road-to-graphql', 'Stars': '1.2k', 'URL': 'https://github.com//the-road-to-graphql/fullstack-apollo-express-postgresql-boilerplate'}
# {'Repository Name': 'docker-tutorial', 'User Name': 'twtrubiks', 'Stars': '1.2k', 'URL': 'https://github.com//twtrubiks/docker-tutorial'}
# {'Repository Name': 'pghoard', 'User Name': 'aiven', 'Stars': '1.1k', 'URL': 'https://github.com//aiven/pghoard'}
# {'Repository Name': 'soci', 'User Name': 'SOCI', 'Stars': '1.1k', 'URL': 'https://github.com//SOCI/soci'}
# {'Repository Name': 'orioledb', 'User Name': 'orioledb', 'Stars': '1.1k', 'URL': 'https://github.com//orioledb/orioledb'}
# {'Repository Name': 'pgjdbc', 'User Name': 'pgjdbc', 'Stars': '1.1k', 'URL': 'https://github.com//pgjdbc/pgjdbc'}
# {'Repository Name': 'promscale', 'User Name': 'timescale', 'Stars': '1.1k', 'URL': 'https://github.com//timescale/promscale'}
# {'Repository Name': 'efcore.pg', 'User Name': 'npgsql', 'Stars': '1.1k', 'URL': 'https://github.com//npgsql/efcore.pg'}
# {'Repository Name': 'treefrog-framework', 'User Name': 'treefrogframework', 'Stars': '1.1k', 'URL': 'https://github.com//treefrogframework/treefrog-framework'}
# {'Repository Name': 'node-pg-migrate', 'User Name': 'salsita', 'Stars': '1.1k', 'URL': 'https://github.com//salsita/node-pg-migrate'}
# {'Repository Name': 'baserow', 'User Name': 'bram2w', 'Stars': '1.1k', 'URL': 'https://github.com//bram2w/baserow'}
# {'Repository Name': 'PostDock', 'User Name': 'paunin', 'Stars': '1.1k', 'URL': 'https://github.com//paunin/PostDock'}
# {'Repository Name': 'netkiller.github.io', 'User Name': 'netkiller', 'Stars': '1k', 'URL': 'https://github.com//netkiller/netkiller.github.io'}
# {'Repository Name': 'lithium', 'User Name': 'matt-42', 'Stars': '1k', 'URL': 'https://github.com//matt-42/lithium'}
# {'Repository Name': 'worker', 'User Name': 'graphile', 'Stars': '1k', 'URL': 'https://github.com//graphile/worker'}
# {'Repository Name': 'aquameta', 'User Name': 'aquametalabs', 'Stars': '1k', 'URL': 'https://github.com//aquametalabs/aquameta'}
# {'Repository Name': 'Pizzly', 'User Name': 'Bearer', 'Stars': '1k', 'URL': 'https://github.com//Bearer/Pizzly'}
# {'Repository Name': 'kubegres', 'User Name': 'reactive-tech', 'Stars': '1k', 'URL': 'https://github.com//reactive-tech/kubegres'}
# {'Repository Name': 'docker-postgis', 'User Name': 'postgis', 'Stars': '1k', 'URL': 'https://github.com//postgis/docker-postgis'}
# {'Repository Name': 'cocalc', 'User Name': 'sagemathinc', 'Stars': '990', 'URL': 'https://github.com//sagemathinc/cocalc'}
# {'Repository Name': 'startpack', 'User Name': 'tldr-devops', 'Stars': '988', 'URL': 'https://github.com//tldr-devops/startpack'}
# {'Repository Name': 'spilo', 'User Name': 'zalando', 'Stars': '988', 'URL': 'https://github.com//zalando/spilo'}
# {'Repository Name': 'pg-mem', 'User Name': 'oguimbal', 'Stars': '980', 'URL': 'https://github.com//oguimbal/pg-mem'}
# {'Repository Name': 'schemats', 'User Name': 'SweetIQ', 'Stars': '965', 'URL': 'https://github.com//SweetIQ/schemats'}
# {'Repository Name': 'crunchy-containers', 'User Name': 'CrunchyData', 'Stars': '957', 'URL': 'https://github.com//CrunchyData/crunchy-containers'}
# {'Repository Name': 'vscode-sqltools', 'User Name': 'mtxr', 'Stars': '957', 'URL': 'https://github.com//mtxr/vscode-sqltools'}
# {'Repository Name': 'sqlancer', 'User Name': 'sqlancer', 'Stars': '955', 'URL': 'https://github.com//sqlancer/sqlancer'}
# {'Repository Name': 'pgcat', 'User Name': 'levkk', 'Stars': '949', 'URL': 'https://github.com//levkk/pgcat'}
# {'Repository Name': 'eralchemy', 'User Name': 'Alexis-benoist', 'Stars': '932', 'URL': 'https://github.com//Alexis-benoist/eralchemy'}

# %%
import pandas as pd

# %%
df = pd.DataFrame(all_article_lst)

# %%
df[:200]
# Out:
#     Repository Name      User Name  Stars  \
# 0         discourse      discourse  36.1k
# 1          supabase       supabase    36k
# 2          metabase       metabase  29.3k
# 3            nocodb         nocodb    29k
# 4           typeorm        typeorm  28.9k
# ..              ...            ...    ...
# 195          worker       graphile     1k
# 196        aquameta   aquametalabs     1k
# 197          Pizzly         Bearer     1k
# 198        kubegres  reactive-tech     1k
# 199  docker-postgis        postgis     1k
#
#                                             URL
# 0       https://github.com//discourse/discourse
# 1         https://github.com//supabase/supabase
# 2         https://github.com//metabase/metabase
# 3             https://github.com//nocodb/nocodb
# 4           https://github.com//typeorm/typeorm
# ..                                          ...
# 195         https://github.com//graphile/worker
# 196   https://github.com//aquametalabs/aquameta
# 197           https://github.com//Bearer/Pizzly
# 198  https://github.com//reactive-tech/kubegres
# 199  https://github.com//postgis/docker-postgis
#
# [200 rows x 4 columns]

# %%
df[:200].to_excel('All-Postgresql200-Data.xlsx')
