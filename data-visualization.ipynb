# %%
import requests

# %%
html_data = requests.get('https://github.com/topics/data-visualization').text

# %%
html_data
# Out:
# '\n\n<!DOCTYPE html>\n<html\n  lang="en"\n  \n  data-color-mode="auto" data-light-theme="light" data-dark-theme="dark"\n  data-a11y-animated-images="system" data-a11y-link-underlines="true"\n  >\n\n\n\n\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n  \n\n  <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/light-0eace2597ca3.css" /><link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/dark-a167e256da9c.css" /><link data-color-theme="dark_dimmed" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_dimmed-d11f2cf8009b.css" /><link data-color-theme="dark_high_contrast" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_high_contrast-ea7373db06c8.css" /><link data-color-theme="dark_colorblind" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_colorblind-afa99dcf40f7.css" /><link data-color-theme="light_colorblind" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_colorblind-af6c685139ba.css" /><link data-color-theme="light_high_contrast" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_high_contrast-578cdbc8a5a9.css" /><link data-color-theme="light_tritanopia" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_tritanopia-5cb699a7e247.css" /><link data-color-theme="dark_tritanopia" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_tritanopia-9b32204967c6.css" />\n    <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/primer-primitives-971c6be3ec9f.css" />\n    <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/primer-08e422afeb43.css" />\n    <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/global-dbe4faca932a.css" />\n    <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/github-36dce55f3db6.css" />\n  <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/site-dfc0853a912d.css" />\n<link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/explore-e56a0802d3f5.css" />\n<link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/dashboard-1691e09b2199.css" />\n<link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/discussions-4a9715cdd9f3.css" />\n\n  \n\n\n  <script type="application/json" id="client-env">{"locale":"en","featureFlags":["docset_management_ui","failbot_handle_non_errors","geojson_azure_maps","image_metric_tracking","turbo_experiment_risky","sample_network_conn_type","no_character_key_shortcuts_in_inputs","custom_inp","remove_child_patch"]}</script>\n<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/wp-runtime-f5c247c2b38b.js"></script>\n<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_dompurify_dist_purify_js-6890e890956f.js"></scri ...

# %%
print(type(html_data))
# Out:
# <class 'str'>

# %%
from bs4 import BeautifulSoup

# %%
con_data = BeautifulSoup(html_data,'lxml')

# %%
type(con_data)
# Out:
# bs4.BeautifulSoup

# %%
print(con_data)
# Out:
# <!DOCTYPE html>
# <html data-a11y-animated-images="system" data-a11y-link-underlines="true" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/light-0eace2597ca3.css" media="all" rel="stylesheet"/><link crossorigin="anonymous" href="https://github.githubassets.com/assets/dark-a167e256da9c.css" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_dimmed" data-href="https://github.githubassets.com/assets/dark_dimmed-d11f2cf8009b.css" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_high_contrast" data-href="https://github.githubassets.com/assets/dark_high_contrast-ea7373db06c8.css" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_colorblind" data-href="https://github.githubassets.com/assets/dark_colorblind-afa99dcf40f7.css" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="light_colorblind" data-href="https://github.githubassets.com/assets/light_colorblind-af6c685139ba.css" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="light_high_contrast" data-href="https://github.githubassets.com/assets/light_high_contrast-578cdbc8a5a9.css" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="light_tritanopia" data-href="https://github.githubassets.com/assets/light_tritanopia-5cb699a7e247.css" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_tritanopia" data-href="https://github.githubassets.com/assets/dark_tritanopia-9b32204967c6.css" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/primer-primitives-971c6be3ec9f.css" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/primer-08e422afeb43.css" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/global-dbe4faca932a.css" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/github-36dce55f3db6.css" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/site-dfc0853a912d.css" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/explore-e56a0802d3f5.css" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/dashboard-1691e09b2199.css" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/discussions-4a9715cdd9f3.css" media="all" rel="stylesheet"/>
# <script id="client-env" type="application/json">{"locale":"en","featureFlags":["docset_management_ui","failbot_handle_non_errors","geojson_azure_maps","image_metric_tracking","turbo_experiment_risky","sample_network_conn_type","no_character_key_shortcuts_in_inputs","custom_inp","remove_child_patch"]}</script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/wp-runtime-f5c247c2b38b.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_dompurify_dist_purify_js-6890e890956f.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_stacktrace-parser_dist_stack-trace-parser_esm_js-node_modules_github_bro-a4c183-79f9611c275b.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_hydro-analytics-client_dist_analytics-client_js-node_modules_gith-6a10dd-e66ebda625fb.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/ui_packages_failbot_failbot_ts-afaa9a250f2e.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/environment-2e9dfc62de38.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_selector-observer_dist_index_esm_js-9f960d9b217c.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_primer_behaviors_dist_esm_focus-zone_js-086f7a27bac0.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_relative-time-element_dist_index_js-c76945c5961a.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_fzy_js_index_js-node_modules_github_combobox-nav_dist_index_js-node_modu-344bff-421f7a8c1008.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_delegated-events_dist_index_js-node_modules_github_details-dialog-elemen-29dc30-a2a71f11a507.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_filter-input-element_dist_index_js-node_modules_github_remote-inp-59c459-d0c49521eb35.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_file-attachment-element_dist_index_js-node_modules_primer_view-co-eb424d-7baa8ec97711.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/github-elements-458e6ff8e072.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/element-registry-cc792c37080f.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_catalyst_lib_index_js-node_modules_github_hydro-analytics-client_-978abc0-15861e0630b6.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_lit-html_lit-html_js-5b376145beff.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_mini-throttle_dist_index_js-node_modules_github_alive-client_dist-bf5aa2-1b562c29ab8e.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_morphdom_dist_morphdom-esm_js-5bff297a06de.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_turbo_dist_turbo_es2017-esm_js-c91f4ad18b62.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_color-convert_index_js-72c9fbde5ad4.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_remote-form_dist_index_js-node_modules_scroll-anchoring_dist_scro-231ccf-aa129238d13b.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_session-resume_dist_index_js-node_modules_primer_behaviors_dist_e-ac74c6-c3eb71941f78.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_primer_behaviors_dist_esm_dimensions_js-node_modules_github_jtml_lib_index_js-95b84ee6bc34.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_paste-markdown_dist_index_esm_js-node_modules_github_quote-select-81e6af-77a71286acee.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/app_assets_modules_github_updatable-content_ts-c73b0e1e6f7c.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_task-list_ts-app_assets_modules_github_onfocus_ts-app_ass-421cec-751caa0072bd.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/app_assets_modules_github_sticky-scroll-into-view_ts-cbcee0788fe3.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_ajax-error_ts-app_assets_modules_github_behaviors_include-467754-b59a2b2827ad.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_commenting_edit_ts-app_assets_modules_github_behaviors_ht-83c235-b85e9f4f1304.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/behaviors-3e6599dbf753.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_delegated-events_dist_index_js-node_modules_github_catalyst_lib_index_js-d0256ebff5cd.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/notifications-global-99d196517b1b.js" type="application/javascript"></script>
# <title>data-visualization · GitHub Topics · GitHub</title>
# <meta content="/topics/:topic_name(.:format)" data-turbo-transient="" name="route-pattern"/>
# <meta content="topics" data-turbo-transient="" name="route-controller"/>
# <meta content="show" data-turbo-transient="" name="route-action"/>
# <meta content="82c569b93da5c18ed649ebd4c2c79437db4611a6a1373e805a3cb001c64130b7" name="current-catalog-service-hash"/>
# <meta content="E426:31AF5B:8EF5A:9F94F:65C77780" data-pjax-transient="true" name="request-id"/><meta content="227fe047678d9384e80bddfd08a00026ecbc3a6ff5bb2e4a5a4a1abeefd63151" data-pjax-transient="true" name="html-safe-nonce"/><meta content="eyJyZWZlcnJlciI6IiIsInJlcXVlc3RfaWQiOiJFNDI2OjMxQUY1Qjo4RUY1QTo5Rjk0Rjo2NUM3Nzc4MCIsInZpc2l0b3JfaWQiOiI0Nzg2MzExMTUyNjQzMDQ1MjQ4IiwicmVnaW9uX2VkZ2UiOiJjZW50cmFsaW5kaWEiLCJyZWdpb25fcmVuZGVyIjoiY2VudHJhbGluZGlhIn0=" data-pjax-transient="true" name="visitor-payload"/><meta content="3d6e7ca839a0e28503020e174d4dc622eef9289b73791c7ff8f565d49f5493d5" data-pjax-transient="true" name="visitor-hmac"/>
# <meta content="copilot" data-turbo-transient="true" name="github-keyboard-shortcuts"/>
# <meta data-turbo-transient="" name="selected-link" value="/topics/data-visualization"/>
# <link href="https://github.githubassets.com/" rel="assets"/>
# <meta content="c1kuD-K2HIVF635lypcsWPoD4kilo5-jA_wBFyT4uMY" name="google-site-verification"/>
# <meta content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU" name="google-site-verification"/>
# <meta content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA" name="google-site-verification"/>
# <meta content="GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc" name="google-site-verification"/>
# <meta content="Apib7-x98H0j5cPqHWwSMm6dNU4GmODRoqxLiDzdx9I" name="google-site-verification"/>
# <meta content="https://collector.github.com/github/collect" name="octolytics-url"/>
# <meta content="" name="user-login"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="GitHub is where people build software. More than 100 million people use GitHub to discover, fork, and contribute to over 420 million projects." name="description"/>
# <link href="/opensearch.xml" rel="search" title="GitHub" type="application/opensearchdescription+xml"/>
# <link href="https://github.com/fluidicon.png" rel="fluid-icon" title="GitHub"/>
# <meta content="1401488693436528" property="fb:app_id"/>
# <meta content="app-id=1477376905, app-argument=https://github.com/topics/data-visualization" name="apple-itunes-app"/>
# <meta content="https://github.com" property="og:url"/>
# <meta content="GitHub" property="og:site_name"/>
# <meta content="Build software better, together" property="og:title"/>
# <meta content="GitHub is where people build software. More than 100 million people use GitHub to discover, fork, and contribute to over 420 million projects." property="og:description"/>
# <meta content="https://github.githubassets.com/assets/github-logo-55c5b9a1fe52.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="1200" property="og:image:height"/>
# <meta content="https://github.githubassets.com/assets/github-mark-57519b92ca4e.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="https://github.githubassets.com/assets/github-octocat-13c86b8b336d.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="github" property="twitter:site"/>
# <meta content="13334762" property="twitter:site:id"/>
# <meta content="github" property="twitter:creator"/>
# <meta content="13334762" property="twitter:creator:id"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="GitHub" property="twitter:title"/>
# <meta content="GitHub is where people build software. More than 100 million people use GitHub to discover, fork, and contribute to over 420 million projects." property="twitter:description"/>
# <meta content="https://github.githubassets.com/assets/github-logo-55c5b9a1fe52.png" property="twitter:image:src"/>
# <meta content="1200" property="twitter:image:width"/>
# <meta content="1200" property="twitter:image:height"/>
# <meta content="github.com" name="hostname"/>
# <meta content="github.com" name="expected-hostname"/>
# <meta content="f520ffa89aff8417c1ba7704623f810a6555e8ff7d2a0b6510194aaf88452a7a" data-turbo-track="reload" http-equiv="x-pjax-version"/>
# <meta content="4faadb9eac50687d0fe57db20e87e3353001aa4d0af8802a2e9dcdc071763a59" data-turbo-track="reload" http-equiv="x-pjax-csp-version"/>
# <meta content="0a793dcef80159dfdecaf5e38c1e60b55f78b31cd74af6664471eed50a4794b5" data-turbo-track="reload" http-equiv="x-pjax-css-version"/>
# <meta content="b6b8867834a93820cbb7897bcc19ca7d0de06a00c21817871b74983242080b4e" data-turbo-track="reload" http-equiv="x-pjax-js-version"/>
# <meta content="no-preview" data-turbo-transient="" name="turbo-cache-control"/>
# <meta content="logged-out env-production page-responsive" name="turbo-body-classes"/>
# <meta content="https://api.github.com/_private/browser/stats" name="browser-stats-url"/>
# <meta content="https://api.github.com/_private/browser/errors" name="browser-errors-url"/>
# <link color="#000000" href="https://github.githubassets.com/assets/pinned-octocat-093da3e6fa40.svg" rel="mask-icon"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.png" rel="alternate icon" type="image/png"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.svg" rel="icon" type="image/svg+xml"/>
# <meta content="#1e2327" name="theme-color"/>
# <meta content="light dark" name="color-scheme"/>
# <link crossorigin="use-credentials" href="/manifest.json" rel="manifest"/>
# </head>
# <body class="logged-out env-production page-responsive" style="word-wrap: break-word;">
# <div class="logged-out env-production page-responsive" data-turbo-body="" style="word-wrap: break-word;">
# <div class="position-relative js-header-wrapper">
# <a class="px-2 py-4 color-bg-accent-emphasis color-fg-on-emphasis show-on-focus js-skip-to-content" href="#start-of-content">Skip to content</a>
# <span class="progress-pjax-loader Progress position-fixed width-full" data-view-component="true">
# <span class="Progress-item progress-pjax-loader-bar left-0 top-0 color-bg-accent-emphasis" data-view-component="true" style="width: 0%;"></span>
# </span>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/react-lib-1fbfc5be2c18.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_primer_octicons-react_dist_index_esm_js-node_modules_primer_react_lib-es-2e8e7c-b299afe58dd7.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_primer_react_lib-esm_Box_Box_js-ebfceb11fb57.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_primer_react_lib-esm_Button_Button_js-0528cb519251.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_primer_react_lib-esm_ActionList_index_js-e001d0eead25.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_primer_react_lib-esm_Button_IconButton_js-node_modules_primer_react_lib--23bcad-ccf1d5fc6054.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/ui_packages_react-core_create-browser-history_ts-ui_packages_react-core_deferred-registry_ts--ebbb92-64923177f972.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/keyboard-shortcuts-dialog-a2ca669523db.js" type="application/javascript"></script>
# <react-partial data-ssr="false" partial-name="keyboard-shortcuts-dialog">
# <script data-target="react-partial.embeddedData" type="application/json">{"props":{}}</script>
# <div data-target="react-partial.reactRoot"></div>
# </react-partial>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/vendors-node_modules_github_remote-form_dist_index_js-node_modules_delegated-events_dist_inde-94fd67-99519581d0f8.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" src="https://github.githubassets.com/assets/sessions-1164ee5f3e37.js" type="application/javascript"></script>
# <header class="Header-old header-logged-out js-details-container Details position-relative f4 py-3" data-color-mode="light" data-dark-theme="dark" data-light-theme="light" role="banner">
# <button aria-label="Toggle navigation" class="Header-backdrop d-lg-none border-0 position-fixed top-0 left-0 width-full height-full js-details-target" type="button">
# <span class="d-none">Toggle navigation</span>
# </button>
# <div class="d-flex flex-column flex-lg-row flex-items-center p-responsive height-full position-relative z-1">
# <div class="d-flex flex-justify-between flex-items-center width-full width-lg-auto">
# <a aria-label="Homepage" class="mr-lg-3 color-fg-inherit flex-order-2" data-ga-click="(Logged out) Header, go to homepage, icon:logo-wordmark" href="https://github.com/">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="32" version="1.1" viewbox="0 0 16 16" width="32">
# <path d="M8 0c4.42 0 8 3.58 8 8a8.013 8.013 0 0 1-5.45 7.59c-.4.08-.55-.17-.55-.38 0-.27.01-1.13.01-2.2 0-.75-.25-1.23-.54-1.48 1.78-.2 3.65-.88 3.65-3.95 0-.88-.31-1.59-.82-2.15.08-.2.36-1.02-.08-2.12 0 0-.67-.22-2.2.82-.64-.18-1.32-.27-2-.27-.68 0-1.36.09-2 .27-1.53-1.03-2.2-.82-2.2-.82-.44 1.1-.16 1.92-.08 2.12-.51.56-.82 1.28-.82 2.15 0 3.06 1.86 3.75 3.64 3.95-.23.2-.44.55-.51 1.07-.46.21-1.61.55-2.33-.66-.15-.24-.6-.83-1.23-.82-.67.01-.27.38.01.53.34.19.73.9.82 1.13.16.45.68 1.31 2.69.94 0 .67.01 1.3.01 1.49 0 .21-.15.45-.55.38A7.995 7.995 0 0 1 0 8c0-4.42 3.58-8 8-8Z"></path>
# </svg>
# </a>
# <div class="flex-1">
# <a class="d-inline-block d-lg-none flex-order-1 f5 no-underline border color-border-default rounded-2 px-2 py-1 color-fg-inherit" data-ga-click="(Logged out) Header, clicked Sign in, text:sign-in" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header menu","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="b0fac51ea60bd15e638982a256eb89d4cae0ae7000ff28d2a354f76560e230d3" href="/login?return_to=https%3A%2F%2Fgithub.com%2Ftopics%2Fdata-visualization">
#           Sign in
#         </a>
# </div>
# <div class="flex-1 flex-order-2 text-right">
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target Button--link Button--medium Button d-lg-none color-fg-inherit p-1" data-view-component="true" type="button"> <span class="Button-content">
# <span class="Button-label"><div class="HeaderMenu-toggle-bar rounded my-1"></div>
# <div class="HeaderMenu-toggle-bar rounded my-1"></div>
# <div class="HeaderMenu-toggle-bar rounded my-1"></div></span>
# </span>
# </button>
# </div>
# </div>
# <div class="HeaderMenu--logged-out p-responsive height-fit position-lg-relative d-lg-flex flex-column flex-auto pt-7 pb-4 top-0">
# <div class="header-menu-wrapper d-flex flex-column flex-self-end flex-lg-row flex-justify-between flex-auto p-3 p-lg-0 rounded rounded-lg-0 mt-3 mt-lg-0">
# <nav aria-label="Global" class="mt-0 px-3 px-lg-0 mb-3 mb-lg-0">
# <ul class="d-lg-flex list-style-none">
# <li class="HeaderMenu-item position-relative flex-wrap flex-justify-between flex-items-center d-block d-lg-flex flex-lg-nowrap flex-lg-items-center js-details-container js-header-menu-item">
# <button aria-expanded="false" class="HeaderMenu-link border-0 width-full width-lg-auto px-0 px-lg-2 py-3 py-lg-2 no-wrap d-flex flex-items-center flex-justify-between js-details-target" type="button">
#         Product
#         <svg aria-hidden="true" class="octicon octicon-chevron-down HeaderMenu-icon ml-1" data-view-component="true" height="16" opacity="0.5" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M12.78 5.22a.749.749 0 0 1 0 1.06l-4.25 4.25a.749.749 0 0 1-1.06 0L3.22 6.28a.749.749 0 1 1 1.06-1.06L8 8.939l3.72-3.719a.749.749 0 0 1 1.06 0Z"></path>
# </svg>
# </button>
# <div class="HeaderMenu-dropdown dropdown-menu rounded m-0 p-0 py-2 py-lg-4 position-relative position-lg-absolute left-0 left-lg-n3 d-lg-flex dropdown-menu-wide">
# <div class="px-lg-4 border-lg-right mb-4 mb-lg-0 pr-lg-7">
# <ul class="list-style-none f5">
# <li>
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center pb-lg-3" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Actions","label":"ref_cta:Actions;"}' href="/features/actions">
# <svg aria-hidden="true" class="octicon octicon-workflow color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M1 3a2 2 0 0 1 2-2h6.5a2 2 0 0 1 2 2v6.5a2 2 0 0 1-2 2H7v4.063C7 16.355 7.644 17 8.438 17H12.5v-2.5a2 2 0 0 1 2-2H21a2 2 0 0 1 2 2V21a2 2 0 0 1-2 2h-6.5a2 2 0 0 1-2-2v-2.5H8.437A2.939 2.939 0 0 1 5.5 15.562V11.5H3a2 2 0 0 1-2-2Zm2-.5a.5.5 0 0 0-.5.5v6.5a.5.5 0 0 0 .5.5h6.5a.5.5 0 0 0 .5-.5V3a.5.5 0 0 0-.5-.5ZM14.5 14a.5.5 0 0 0-.5.5V21a.5.5 0 0 0 .5.5H21a.5.5 0 0 0 .5-.5v-6.5a.5.5 0 0 0-.5-.5Z"></path>
# </svg>
# <div>
# <div class="color-fg-default h4">Actions</div>
#         Automate any workflow
#       </div>
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center pb-lg-3" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Packages","label":"ref_cta:Packages;"}' href="/features/packages">
# <svg aria-hidden="true" class="octicon octicon-package color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M12.876.64V.639l8.25 4.763c.541.313.875.89.875 1.515v9.525a1.75 1.75 0 0 1-.875 1.516l-8.25 4.762a1.748 1.748 0 0 1-1.75 0l-8.25-4.763a1.75 1.75 0 0 1-.875-1.515V6.917c0-.625.334-1.202.875-1.515L11.126.64a1.748 1.748 0 0 1 1.75 0Zm-1 1.298L4.251 6.34l7.75 4.474 7.75-4.474-7.625-4.402a.248.248 0 0 0-.25 0Zm.875 19.123 7.625-4.402a.25.25 0 0 0 .125-.216V7.639l-7.75 4.474ZM3.501 7.64v8.803c0 .09.048.172.125.216l7.625 4.402v-8.947Z"></path>
# </svg>
# <div>
# <div class="color-fg-default h4">Packages</div>
#         Host and manage packages
#       </div>
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center pb-lg-3" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Security","label":"ref_cta:Security;"}' href="/features/security">
# <svg aria-hidden="true" class="octicon octicon-shield-check color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M16.53 9.78a.75.75 0 0 0-1.06-1.06L11 13.19l-1.97-1.97a.75.75 0 0 0-1.06 1.06l2.5 2.5a.75.75 0 0 0 1.06 0l5-5Z"></path><path d="m12.54.637 8.25 2.675A1.75 1.75 0 0 1 22 4.976V10c0 6.19-3.771 10.704-9.401 12.83a1.704 1.704 0 0 1-1.198 0C5.77 20.705 2 16.19 2 10V4.976c0-.758.489-1.43 1.21-1.664L11.46.637a1.748 1.748 0 0 1 1.08 0Zm-.617 1.426-8.25 2.676a.249.249 0 0 0-.173.237V10c0 5.46 3.28 9.483 8.43 11.426a.199.199 0 0 0 .14 0C17.22 19.483 20.5 15.461 20.5 10V4.976a.25.25 0 0 0-.173-.237l-8.25-2.676a.253.253 0 0 0-.154 0Z"></path>
# </svg>
# <div>
# <div class="color-fg-default h4">Security</div>
#         Find and fix vulnerabilities
#       </div>
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center pb-lg-3" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Codespaces","label":"ref_cta:Codespaces;"}' href="/features/codespaces">
# <svg aria-hidden="true" class="octicon octicon-codespaces color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M3.5 3.75C3.5 2.784 4.284 2 5.25 2h13.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0 1 18.75 13H5.25a1.75 1.75 0 0 1-1.75-1.75Zm-2 12c0-.966.784-1.75 1.75-1.75h17.5c.966 0 1.75.784 1.75 1.75v4a1.75 1.75 0 0 1-1.75 1.75H3.25a1.75 1.75 0 0 1-1.75-1.75ZM5.25 3.5a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h13.5a.25.25 0 0 0 .25-.25v-7.5a.25.25 0 0 0-.25-.25Zm-2 12a.25.25 0 0 0-.25.25v4c0 .138.112.25.25.25h17.5a.25.25 0 0 0 .25-.25v-4a.25.25 0 0 0-.25-.25Z"></path><path d="M10 17.75a.75.75 0 0 1 .75-.75h6.5a.75.75 0 0 1 0 1.5h-6.5a.75.75 0 0 1-.75-.75Zm-4 0a.75.75 0 0 1 .75-.75h.5a.75.75 0 0 1 0 1.5h-.5a.75.75 0 0 1-.75-.75Z"></path>
# </svg>
# <div>
# <div class="color-fg-default h4">Codespaces</div>
#         Instant dev environments
#       </div>
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center pb-lg-3" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Copilot","label":"ref_cta:Copilot;"}' href="/features/copilot">
# <svg aria-hidden="true" class="octicon octicon-copilot color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M23.922 16.992c-.861 1.495-5.859 5.023-11.922 5.023-6.063 0-11.061-3.528-11.922-5.023A.641.641 0 0 1 0 16.736v-2.869a.841.841 0 0 1 .053-.22c.372-.935 1.347-2.292 2.605-2.656.167-.429.414-1.055.644-1.517a10.195 10.195 0 0 1-.052-1.086c0-1.331.282-2.499 1.132-3.368.397-.406.89-.717 1.474-.952 1.399-1.136 3.392-2.093 6.122-2.093 2.731 0 4.767.957 6.166 2.093.584.235 1.077.546 1.474.952.85.869 1.132 2.037 1.132 3.368 0 .368-.014.733-.052 1.086.23.462.477 1.088.644 1.517 1.258.364 2.233 1.721 2.605 2.656a.832.832 0 0 1 .053.22v2.869a.641.641 0 0 1-.078.256ZM12.172 11h-.344a4.323 4.323 0 0 1-.355.508C10.703 12.455 9.555 13 7.965 13c-1.725 0-2.989-.359-3.782-1.259a2.005 2.005 0 0 1-.085-.104L4 11.741v6.585c1.435.779 4.514 2.179 8 2.179 3.486 0 6.565-1.4 8-2.179v-6.585l-.098-.104s-.033.045-.085.104c-.793.9-2.057 1.259-3.782 1.259-1.59 0-2.738-.545-3.508-1.492a4.323 4.323 0 0 1-.355-.508h-.016.016Zm.641-2.935c.136 1.057.403 1.913.878 2.497.442.544 1.134.938 2.344.938 1.573 0 2.292-.337 2.657-.751.384-.435.558-1.15.558-2.361 0-1.14-.243-1.847-.705-2.319-.477-.488-1.319-.862-2.824-1.025-1.487-.161-2.192.138-2.533.529-.269.307-.437.808-.438 1.578v.021c0 .265.021.562.063.893Zm-1.626 0c.042-.331.063-.628.063-.894v-.02c-.001-.77-.169-1.271-.438-1.578-.341-.391-1.046-.69-2.533-.529-1.505.163-2.347.537-2.824 1.025-.462.472-.705 1.179-.705 2.319 0 1.211.175 1.926.558 2.361.365.414 1.084.751 2.657.751 1.21 0 1.902-.394 2.344-.938.475-.584.742-1.44.878-2.497Z"></path><path d="M14.5 14.25a1 1 0 0 1 1 1v2a1 1 0 0 1-2 0v-2a1 1 0 0 1 1-1Zm-5 0a1 1 0 0 1 1 1v2a1 1 0 0 1-2 0v-2a1 1 0 0 1 1-1Z"></path>
# </svg>
# <div>
# <div class="color-fg-default h4">Copilot</div>
#         Write better code with AI
#       </div>
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center pb-lg-3" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Code review","label":"ref_cta:Code review;"}' href="/features/code-review">
# <svg aria-hidden="true" class="octicon octicon-code-review color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M10.3 6.74a.75.75 0 0 1-.04 1.06l-2.908 2.7 2.908 2.7a.75.75 0 1 1-1.02 1.1l-3.5-3.25a.75.75 0 0 1 0-1.1l3.5-3.25a.75.75 0 0 1 1.06.04Zm3.44 1.06a.75.75 0 1 1 1.02-1.1l3.5 3.25a.75.75 0 0 1 0 1.1l-3.5 3.25a.75.75 0 1 1-1.02-1.1l2.908-2.7-2.908-2.7Z"></path><path d="M1.5 4.25c0-.966.784-1.75 1.75-1.75h17.5c.966 0 1.75.784 1.75 1.75v12.5a1.75 1.75 0 0 1-1.75 1.75h-9.69l-3.573 3.573A1.458 1.458 0 0 1 5 21.043V18.5H3.25a1.75 1.75 0 0 1-1.75-1.75ZM3.25 4a.25.25 0 0 0-.25.25v12.5c0 .138.112.25.25.25h2.5a.75.75 0 0 1 .75.75v3.19l3.72-3.72a.749.749 0 0 1 .53-.22h10a.25.25 0 0 0 .25-.25V4.25a.25.25 0 0 0-.25-.25Z"></path>
# </svg>
# <div>
# <div class="color-fg-default h4">Code review</div>
#         Manage code changes
#       </div>
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center pb-lg-3" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Issues","label":"ref_cta:Issues;"}' href="/features/issues">
# <svg aria-hidden="true" class="octicon octicon-issue-opened color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M12 1c6.075 0 11 4.925 11 11s-4.925 11-11 11S1 18.075 1 12 5.925 1 12 1ZM2.5 12a9.5 9.5 0 0 0 9.5 9.5 9.5 9.5 0 0 0 9.5-9.5A9.5 9.5 0 0 0 12 2.5 9.5 9.5 0 0 0 2.5 12Zm9.5 2a2 2 0 1 1-.001-3.999A2 2 0 0 1 12 14Z"></path>
# </svg>
# <div>
# <div class="color-fg-default h4">Issues</div>
#         Plan and track work
#       </div>
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Discussions","label":"ref_cta:Discussions;"}' href="/features/discussions">
# <svg aria-hidden="true" class="octicon octicon-comment-discussion color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M1.75 1h12.5c.966 0 1.75.784 1.75 1.75v9.5A1.75 1.75 0 0 1 14.25 14H8.061l-2.574 2.573A1.458 1.458 0 0 1 3 15.543V14H1.75A1.75 1.75 0 0 1 0 12.25v-9.5C0 1.784.784 1 1.75 1ZM1.5 2.75v9.5c0 .138.112.25.25.25h2a.75.75 0 0 1 .75.75v2.19l2.72-2.72a.749.749 0 0 1 .53-.22h6.5a.25.25 0 0 0 .25-.25v-9.5a.25.25 0 0 0-.25-.25H1.75a.25.25 0 0 0-.25.25Z"></path><path d="M22.5 8.75a.25.25 0 0 0-.25-.25h-3.5a.75.75 0 0 1 0-1.5h3.5c.966 0 1.75.784 1.75 1.75v9.5A1.75 1.75 0 0 1 22.25 20H21v1.543a1.457 1.457 0 0 1-2.487 1.03L15.939 20H10.75A1.75 1.75 0 0 1 9 18.25v-1.465a.75.75 0 0 1 1.5 0v1.465c0 .138.112.25.25.25h5.5a.75.75 0 0 1 .53.22l2.72 2.72v-2.19a.75.75 0 0 1 .75-.75h2a.25.25 0 0 0 .25-.25v-9.5Z"></path>
# </svg>
# <div>
# <div class="color-fg-default h4">Discussions</div>
#         Collaborate outside of code
#       </div>
# </a></li>
# </ul>
# </div>
# <div class="px-lg-4">
# <span class="d-block h4 color-fg-default my-1" id="product-explore-heading">Explore</span>
# <ul aria-labelledby="product-explore-heading" class="list-style-none f5">
# <li>
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to All features","label":"ref_cta:All features;"}' href="/features">
#       All features
#
#
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Documentation","label":"ref_cta:Documentation;"}' href="https://docs.github.com" target="_blank">
#       Documentation
#
#     <svg aria-hidden="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.75 2h3.5a.75.75 0 0 1 0 1.5h-3.5a.25.25 0 0 0-.25.25v8.5c0 .138.112.25.25.25h8.5a.25.25 0 0 0 .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75 1.75 0 0 1 12.25 14h-8.5A1.75 1.75 0 0 1 2 12.25v-8.5C2 2.784 2.784 2 3.75 2Zm6.854-1h4.146a.25.25 0 0 1 .25.25v4.146a.25.25 0 0 1-.427.177L13.03 4.03 9.28 7.78a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z"></path>
# </svg>
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to GitHub Skills","label":"ref_cta:GitHub Skills;"}' href="https://skills.github.com/" target="_blank">
#       GitHub Skills
#
#     <svg aria-hidden="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.75 2h3.5a.75.75 0 0 1 0 1.5h-3.5a.25.25 0 0 0-.25.25v8.5c0 .138.112.25.25.25h8.5a.25.25 0 0 0 .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75 1.75 0 0 1 12.25 14h-8.5A1.75 1.75 0 0 1 2 12.25v-8.5C2 2.784 2.784 2 3.75 2Zm6.854-1h4.146a.25.25 0 0 1 .25.25v4.146a.25.25 0 0 1-.427.177L13.03 4.03 9.28 7.78a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z"></path>
# </svg>
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Blog","label":"ref_cta:Blog;"}' href="https://github.blog" target="_blank">
#       Blog
#
#     <svg aria-hidden="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.75 2h3.5a.75.75 0 0 1 0 1.5h-3.5a.25.25 0 0 0-.25.25v8.5c0 .138.112.25.25.25h8.5a.25.25 0 0 0 .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75 1.75 0 0 1 12.25 14h-8.5A1.75 1.75 0 0 1 2 12.25v-8.5C2 2.784 2.784 2 3.75 2Zm6.854-1h4.146a.25.25 0 0 1 .25.25v4.146a.25.25 0 0 1-.427.177L13.03 4.03 9.28 7.78a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z"></path>
# </svg>
# </a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="HeaderMenu-item position-relative flex-wrap flex-justify-between flex-items-center d-block d-lg-flex flex-lg-nowrap flex-lg-items-center js-details-container js-header-menu-item">
# <button aria-expanded="false" class="HeaderMenu-link border-0 width-full width-lg-auto px-0 px-lg-2 py-3 py-lg-2 no-wrap d-flex flex-items-center flex-justify-between js-details-target" type="button">
#         Solutions
#         <svg aria-hidden="true" class="octicon octicon-chevron-down HeaderMenu-icon ml-1" data-view-component="true" height="16" opacity="0.5" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M12.78 5.22a.749.749 0 0 1 0 1.06l-4.25 4.25a.749.749 0 0 1-1.06 0L3.22 6.28a.749.749 0 1 1 1.06-1.06L8 8.939l3.72-3.719a.749.749 0 0 1 1.06 0Z"></path>
# </svg>
# </button>
# <div class="HeaderMenu-dropdown dropdown-menu rounded m-0 p-0 py-2 py-lg-4 position-relative position-lg-absolute left-0 left-lg-n3 px-lg-4">
# <div class="border-bottom pb-3 mb-3">
# <span class="d-block h4 color-fg-default my-1" id="solutions-for-heading">For</span>
# <ul aria-labelledby="solutions-for-heading" class="list-style-none f5">
# <li>
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"category":"Header dropdown (logged out), Solutions","action":"click to go to Enterprise","label":"ref_cta:Enterprise;"}' href="/enterprise">
#       Enterprise
#
#
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"category":"Header dropdown (logged out), Solutions","action":"click to go to Teams","label":"ref_cta:Teams;"}' href="/team">
#       Teams
#
#
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"category":"Header dropdown (logged out), Solutions","action":"click to go to Startups","label":"ref_cta:Startups;"}' href="/enterprise/startups">
#       Startups
#
#
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"category":"Header dropdown (logged out), Solutions","action":"click to go to Education","label":"ref_cta:Education;"}' href="https://education.github.com" target="_blank">
#       Education
#
#     <svg aria-hidden="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.75 2h3.5a.75.75 0 0 1 0 1.5h-3.5a.25.25 0 0 0-.25.25v8.5c0 .138.112.25.25.25h8.5a.25.25 0 0 0 .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75 1.75 0 0 1 12.25 14h-8.5A1.75 1.75 0 0 1 2 12.25v-8.5C2 2.784 2.784 2 3.75 2Zm6.854-1h4.146a.25.25 0 0 1 .25.25v4.146a.25.25 0 0 1-.427.177L13.03 4.03 9.28 7.78a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z"></path>
# </svg>
# </a></li>
# </ul>
# </div>
# <div class="border-bottom pb-3 mb-3">
# <span class="d-block h4 color-fg-default my-1" id="solutions-by-solution-heading">By Solution</span>
# <ul aria-labelledby="solutions-by-solution-heading" class="list-style-none f5">
# <li>
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"category":"Header dropdown (logged out), Solutions","action":"click to go to CI/CD &amp;amp; Automation","label":"ref_cta:CI/CD &amp;amp; Automation;"}' href="/solutions/ci-cd/">
#       CI/CD &amp; Automation
#
#
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"category":"Header dropdown (logged out), Solutions","action":"click to go to DevOps","label":"ref_cta:DevOps;"}' href="https://resources.github.com/devops/" target="_blank">
#       DevOps
#
#     <svg aria-hidden="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.75 2h3.5a.75.75 0 0 1 0 1.5h-3.5a.25.25 0 0 0-.25.25v8.5c0 .138.112.25.25.25h8.5a.25.25 0 0 0 .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75 1.75 0 0 1 12.25 14h-8.5A1.75 1.75 0 0 1 2 12.25v-8.5C2 2.784 2.784 2 3.75 2Zm6.854-1h4.146a.25.25 0 0 1 .25.25v4.146a.25.25 0 0 1-.427.177L13.03 4.03 9.28 7.78a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z"></path>
# </svg>
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"category":"Header dropdown (logged out), Solutions","action":"click to go to DevSecOps","label":"ref_cta:DevSecOps;"}' href="https://resources.github.com/devops/fundamentals/devsecops/" target="_blank">
#       DevSecOps
#
#     <svg aria-hidden="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.75 2h3.5a.75.75 0 0 1 0 1.5h-3.5a.25.25 0 0 0-.25.25v8.5c0 .138.112.25.25.25h8.5a.25.25 0 0 0 .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75 1.75 0 0 1 12.25 14h-8.5A1.75 1.75 0 0 1 2 12.25v-8.5C2 2.784 2.784 2 3.75 2Zm6.854-1h4.146a.25.25 0 0 1 .25.25v4.146a.25.25 0 0 1-.427.177L13.03 4.03 9.28 7.78a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z"></path>
# </svg>
# </a></li>
# </ul>
# </div>
# <div class="">
# <span class="d-block h4 color-fg-default my-1" id="solutions-resources-heading">Resources</span>
# <ul aria-labelledby="solutions-resources-heading" class="list-style-none f5">
# <li>
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"category":"Header dropdown (logged out), Solutions","action":"click to go to Learning Pathways","label":"ref_cta:Learning Pathways;"}' href="https://resources.github.com/learn/pathways/" target="_blank">
#       Learning Pathways
#
#     <svg aria-hidden="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.75 2h3.5a.75.75 0 0 1 0 1.5h-3.5a.25.25 0 0 0-.25.25v8.5c0 .138.112.25.25.25h8.5a.25.25 0 0 0 .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75 1.75 0 0 1 12.25 14h-8.5A1.75 1.75 0 0 1 2 12.25v-8.5C2 2.784 2.784 2 3.75 2Zm6.854-1h4.146a.25.25 0 0 1 .25.25v4.146a.25.25 0 0 1-.427.177L13.03 4.03 9.28 7.78a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z"></path>
# </svg>
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"category":"Header dropdown (logged out), Solutions","action":"click to go to White papers, Ebooks, Webinars","label":"ref_cta:White papers, Ebooks, Webinars;"}' href="https://resources.github.com/" target="_blank">
#       White papers, Ebooks, Webinars
#
#     <svg aria-hidden="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.75 2h3.5a.75.75 0 0 1 0 1.5h-3.5a.25.25 0 0 0-.25.25v8.5c0 .138.112.25.25.25h8.5a.25.25 0 0 0 .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75 1.75 0 0 1 12.25 14h-8.5A1.75 1.75 0 0 1 2 12.25v-8.5C2 2.784 2.784 2 3.75 2Zm6.854-1h4.146a.25.25 0 0 1 .25.25v4.146a.25.25 0 0 1-.427.177L13.03 4.03 9.28 7.78a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z"></path>
# </svg>
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"category":"Header dropdown (logged out), Solutions","action":"click to go to Customer Stories","label":"ref_cta:Customer Stories;"}' href="/customer-stories">
#       Customer Stories
#
#
# </a></li>
# <li>
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary" data-analytics-event='{"category":"Header dropdown (logged out), Solutions","action":"click to go to Partners","label":"ref_cta:Partners;"}' href="https://partner.github.com/" target="_blank">
#       Partners
#
#     <svg aria-hidden="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.75 2h3.5a.75.75 0 0 1 0 1.5h-3.5a.25.25 0 0 0-.25.25v8.5c0 .138.112.25.25.25h8.5a.25.25 0 0 0 .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75 1.75 0 0 1 12.25 14h-8.5A1.75 1.75 0 0 1 2 12.25v-8.5C2 2.784 2.784 2 3.75 2Zm6.854-1h4.146a.25.25 0 0 1 .25.25v4.146a.25.25 0 0 1-.427.177L13.03 4.03 9.28 7.78a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z"></path>
# </svg>
# </a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="HeaderMenu-item position-relative flex-wrap flex-justify-between flex-items-center d-block d-lg-flex flex-lg-nowrap flex-lg-items-center js-details-container js-header-menu-item">
# <button aria-expanded="false" class="HeaderMenu-link border-0 width-full width-lg-auto px-0 px-lg-2 py-3 py-lg-2 no-wrap d-flex flex-items-center flex-justify-between js-details-target" type="button">
#         Open Source
#         <svg aria-hidden="true" class="octicon octicon-chevron-down HeaderMenu-icon ml-1" data-view-component="true" height="16" opacity="0.5" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M12.78 5.22a.749.749 0 0 1 0 1.06l-4.25 4.25a.749.749 0 0 1-1.06 0L3.22 6.28a.749.749 0 1 1 1.06-1.06L8 8.939l3.72-3.719a.749.749 0 0 1 1.06 0Z"></path>
# </svg>
# </button>
# <div class="HeaderMenu-dropdown dropdown-menu rounded m-0 p-0 py-2 py-lg-4 position-relative position-lg-absolute left-0 left-lg-n3 px-lg-4">
# <div class="border-bottom pb-3 mb-3">
# <ul class="list-style-none f5">
# <li>
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center" data-analytics-event='{"category":"Header dropdown (logged out), Open Source","action":"click to go to GitHub Sponsors","label":"ref_cta:GitHub Sponsors;"}' href="/sponsors">
# <div>
# <div class="color-fg-default h4">GitHub Sponsors</div>
#         Fund open source developers
#       </div>
# </a></li>
# </ul>
# </div>
# <div class="border-bottom pb-3 mb-3">
# <ul class="list-style-none f5">
# <li>
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center" data-analytics-event='{"category":"Header dropdown (logged out), Open Source","action":"click to go to The ReadME Project","label":"ref_cta:The ReadME Project;"}' href="/readme">
# <div>
# <div class="color-fg-default h4">The ReadME Project</div>
#         GitHub community articles
#       </div>
# </a></li>
# </ul>
# </div>
# <div class="">
# ...
#             series-database
# </a> <a class="topic-tag topic-tag-link Link f6 mb-2" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":22808,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="d7356342c27cbe42e910f0c51b20405ff88c15a467aed1ce19c65f7f76fce1ad" data-view-component="true" href="/topics/data-visualization" title="Topic: data-visualization">
#             data-visualization
# </a> <a class="topic-tag topic-tag-link Link f6 mb-2" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":23952,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="87866973b0e748c080bcd2f4c1e64edb6c834c12909da84f763f7420015c2580" data-view-component="true" href="/topics/data-warehouse" title="Topic: data-warehouse">
#             data-warehouse
# </a> <a class="topic-tag topic-tag-link Link f6 mb-2" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":27720,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="ae0fe956e4cc37ef2a52a9c4730b1ea036518940817d2a30a581b8f9e8ea9be9" data-view-component="true" href="/topics/stream-processing" title="Topic: stream-processing">
#             stream-processing
# </a> <a class="topic-tag topic-tag-link Link f6 mb-2" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":45089,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="31f8395bdfb69dd854f097eca2dfbdda4dc6131f6631d25aae40ceea4b3ef656" data-view-component="true" href="/topics/data-analytics" title="Topic: data-analytics">
#             data-analytics
# </a> <a class="topic-tag topic-tag-link Link f6 mb-2" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":72967,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="0de884a3afb90b7de46bb1e3c6f3c74bd39c272c0ed2daec7966c0e4f920d2e1" data-view-component="true" href="/topics/awesome-list" title="Topic: awesome-list">
#             awesome-list
# </a> <a class="topic-tag topic-tag-link Link f6 mb-2" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":73246,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="a4c6113fce0ecd9665aa9db0226dcb973f70b7f49f145c3fb68d7353ffee568b" data-view-component="true" href="/topics/distributed-database" title="Topic: distributed-database">
#             distributed-database
# </a> <a class="topic-tag topic-tag-link Link f6 mb-2" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":269687,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="2fcf8b668f40db25868c40f11d87116b954aa57065e7441fecb884cceab15f17" data-view-component="true" href="/topics/visualize-data" title="Topic: visualize-data">
#             visualize-data
# </a> <a class="topic-tag topic-tag-link Link f6 mb-2" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":301995,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="8c5005dfe76184926e22580eaa71d2d8a356a0dfd041b091e4454845e1fd1f68" data-view-component="true" href="/topics/streaming-data" title="Topic: streaming-data">
#             streaming-data
# </a> </div>
# <div class="p-3">
# <ul class="d-flex f6 list-style-none color-fg-muted">
# <li class="mr-4">
#             Updated
#             <relative-time class="no-wrap" datetime="2024-01-12T06:53:01Z">Jan 12, 2024</relative-time>
# </li>
# </ul>
# </div>
# </div>
# </article>
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="https://github.com/topics/data-visualization" class="ajax-pagination-form js-ajax-pagination" data-turbo="false" method="get">
# <input name="page" type="hidden" value="2"/>
# <button class="ajax-pagination-btn btn color-border-default f6 mt-0 width-full" data-disable-with="Loading more…" type="submit">
#       Load more…
#     </button>
# </form>
# </div>
# <div class="col-md-4 col-lg-3">
# <p class="mb-1">
# <span class="color-fg-muted">Created by</span> Charles Joseph Minard
#     </p>
# <dl class="my-4">
# <dt class="d-none">
#     Followers
#   </dt>
# <dd class="mb-1 color-fg-muted">
# <svg aria-label="Topic followers" class="octicon octicon-people mr-1" data-view-component="true" height="16" role="img" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 5.5a3.5 3.5 0 1 1 5.898 2.549 5.508 5.508 0 0 1 3.034 4.084.75.75 0 1 1-1.482.235 4 4 0 0 0-7.9 0 .75.75 0 0 1-1.482-.236A5.507 5.507 0 0 1 3.102 8.05 3.493 3.493 0 0 1 2 5.5ZM11 4a3.001 3.001 0 0 1 2.22 5.018 5.01 5.01 0 0 1 2.56 3.012.749.749 0 0 1-.885.954.752.752 0 0 1-.549-.514 3.507 3.507 0 0 0-2.522-2.372.75.75 0 0 1-.574-.73v-.352a.75.75 0 0 1 .416-.672A1.5 1.5 0 0 0 11 5.5.75.75 0 0 1 11 4Zm-5.5-.5a2 2 0 1 0-.001 3.999A2 2 0 0 0 5.5 3.5Z"></path>
# </svg>
#     62.2k followers
#   </dd>
# <dt class="d-none">
#       Wikipedia
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-link color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="m7.775 3.275 1.25-1.25a3.5 3.5 0 1 1 4.95 4.95l-2.5 2.5a3.5 3.5 0 0 1-4.95 0 .751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018 1.998 1.998 0 0 0 2.83 0l2.5-2.5a2.002 2.002 0 0 0-2.83-2.83l-1.25 1.25a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042Zm-4.69 9.64a1.998 1.998 0 0 0 2.83 0l1.25-1.25a.751.751 0 0 1 1.042.018.751.751 0 0 1 .018 1.042l-1.25 1.25a3.5 3.5 0 1 1-4.95-4.95l2.5-2.5a3.5 3.5 0 0 1 4.95 0 .751.751 0 0 1-.018 1.042.751.751 0 0 1-1.042.018 1.998 1.998 0 0 0-2.83 0l-2.5 2.5a1.998 1.998 0 0 0 0 2.83Z"></path>
# </svg>
# <a aria-label="en.wikipedia.org/wiki/Data_visualization" href="https://en.wikipedia.org/wiki/Data_visualization">
# <span class="css-truncate css-truncate-target">
#           Wikipedia
#         </span>
# </a>
# </dd>
# </dl>
# </div>
# </div>
# </div>
# </div>
# </main>
# </div>
# <footer class="footer pt-8 pb-6 f6 color-fg-muted p-responsive" role="contentinfo">
# <h2 class="sr-only">Footer</h2>
# <div class="d-flex flex-justify-center flex-items-center flex-column-reverse flex-lg-row flex-wrap flex-lg-nowrap">
# <div class="d-flex flex-items-center flex-shrink-0 mx-2">
# <a aria-label="Homepage" class="footer-octicon mr-2" href="https://github.com" title="GitHub">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M8 0c4.42 0 8 3.58 8 8a8.013 8.013 0 0 1-5.45 7.59c-.4.08-.55-.17-.55-.38 0-.27.01-1.13.01-2.2 0-.75-.25-1.23-.54-1.48 1.78-.2 3.65-.88 3.65-3.95 0-.88-.31-1.59-.82-2.15.08-.2.36-1.02-.08-2.12 0 0-.67-.22-2.2.82-.64-.18-1.32-.27-2-.27-.68 0-1.36.09-2 .27-1.53-1.03-2.2-.82-2.2-.82-.44 1.1-.16 1.92-.08 2.12-.51.56-.82 1.28-.82 2.15 0 3.06 1.86 3.75 3.64 3.95-.23.2-.44.55-.51 1.07-.46.21-1.61.55-2.33-.66-.15-.24-.6-.83-1.23-.82-.67.01-.27.38.01.53.34.19.73.9.82 1.13.16.45.68 1.31 2.69.94 0 .67.01 1.3.01 1.49 0 .21-.15.45-.55.38A7.995 7.995 0 0 1 0 8c0-4.42 3.58-8 8-8Z"></path>
# </svg>
# </a>
# <span>
#         © 2024 GitHub, Inc.
#       </span>
# </div>
# <nav aria-label="Footer">
# <h3 class="sr-only" id="sr-footer-heading">Footer navigation</h3>
# <ul aria-labelledby="sr-footer-heading" class="list-style-none d-flex flex-justify-center flex-wrap mb-2 mb-lg-0">
# <li class="mx-2">
# <a class="Link--secondary Link" data-analytics-event='{"category":"Footer","action":"go to Terms","label":"text:terms"}' data-view-component="true" href="https://docs.github.com/site-policy/github-terms/github-terms-of-service">Terms</a>
# </li>
# <li class="mx-2">
# <a class="Link--secondary Link" data-analytics-event='{"category":"Footer","action":"go to privacy","label":"text:privacy"}' data-view-component="true" href="https://docs.github.com/site-policy/privacy-policies/github-privacy-statement">Privacy</a>
# </li>
# <li class="mx-2">
# <a class="Link--secondary Link" data-analytics-event='{"category":"Footer","action":"go to security","label":"text:security"}' data-view-component="true" href="/security">Security</a>
# </li>
# <li class="mx-2">
# <a class="Link--secondary Link" data-analytics-event='{"category":"Footer","action":"go to status","label":"text:status"}' data-view-component="true" href="https://www.githubstatus.com/">Status</a>
# </li>
# <li class="mx-2">
# <a class="Link--secondary Link" data-analytics-event='{"category":"Footer","action":"go to docs","label":"text:docs"}' data-view-component="true" href="https://docs.github.com">Docs</a>
# </li>
# <li class="mx-2">
# <a class="Link--secondary Link" data-analytics-event='{"category":"Footer","action":"go to contact","label":"text:contact"}' data-view-component="true" href="https://support.github.com?tags=dotcom-footer">Contact</a>
# </li>
# <li class="mx-2">
# <cookie-consent-link>
# <button class="Link--secondary underline-on-hover border-0 p-0 color-bg-transparent" data-action="click:cookie-consent-link#showConsentManagement" type="button">
#       Manage cookies
#     </button>
# </cookie-consent-link>
# </li>
# <li class="mx-2">
# <cookie-consent-link>
# <button class="Link--secondary underline-on-hover border-0 p-0 color-bg-transparent" data-action="click:cookie-consent-link#showConsentManagement" type="button">
#       Do not share my personal information
#     </button>
# </cookie-consent-link>
# </li>
# </ul>
# </nav>
# </div>
# </footer>
# <cookie-consent class="position-fixed bottom-0 left-0" data-cookie-consent-required="false" data-initial-cookie-consent-allowed="" id="cookie-consent-banner" style="z-index: 999999"></cookie-consent>
# <div class="ajax-error-message flash flash-error" hidden="" id="ajax-error-message">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M6.457 1.047c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0 1 14.082 15H1.918a1.75 1.75 0 0 1-1.543-2.575Zm1.763.707a.25.25 0 0 0-.44 0L1.698 13.132a.25.25 0 0 0 .22.368h12.164a.25.25 0 0 0 .22-.368Zm.53 3.996v2.5a.75.75 0 0 1-1.5 0v-2.5a.75.75 0 0 1 1.5 0ZM9 11a1 1 0 1 1-2 0 1 1 0 0 1 2 0Z"></path>
# </svg>
# <button aria-label="Dismiss error" class="flash-close js-ajax-error-dismiss" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 0 1 1.06 0L8 6.94l3.22-3.22a.749.749 0 0 1 1.275.326.749.749 0 0 1-.215.734L9.06 8l3.22 3.22a.749.749 0 0 1-.326 1.275.749.749 0 0 1-.734-.215L8 9.06l-3.22 3.22a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042L6.94 8 3.72 4.78a.75.75 0 0 1 0-1.06Z"></path>
# </svg>
# </button>
#     You can’t perform that action at this time.
#   </div>
# <template id="site-details-dialog">
# <details class="details-reset details-overlay details-overlay-dark lh-default color-fg-default hx_rsm" open="">
# <summary aria-label="Close dialog" role="button"></summary>
# <details-dialog class="Box Box--overlay d-flex flex-column anim-fade-in fast hx_rsm-dialog hx_rsm-modal">
# <button aria-label="Close dialog" class="Box-btn-octicon m-0 btn-octicon position-absolute right-0 top-0" data-close-dialog="" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 0 1 1.06 0L8 6.94l3.22-3.22a.749.749 0 0 1 1.275.326.749.749 0 0 1-.215.734L9.06 8l3.22 3.22a.749.749 0 0 1-.326 1.275.749.749 0 0 1-.734-.215L8 9.06l-3.22 3.22a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042L6.94 8 3.72 4.78a.75.75 0 0 1 0-1.06Z"></path>
# </svg>
# </button>
# <div class="octocat-spinner my-6 js-details-dialog-spinner"></div>
# </details-dialog>
# </details>
# </template>
# <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;" tabindex="0">
# <div class="Popover-message Popover-message--bottom-left Popover-message--large Box color-shadow-large" style="width:360px;">
# </div>
# </div>
# <template id="snippet-clipboard-copy-button">
# <div class="zeroclipboard-container position-absolute right-0 top-0">
# <clipboard-copy aria-label="Copy" class="ClipboardButton btn js-clipboard-copy m-2 p-0 tooltipped-no-delay" data-copy-feedback="Copied!" data-tooltip-direction="w">
# <svg aria-hidden="true" class="octicon octicon-copy js-clipboard-copy-icon m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M0 6.75C0 5.784.784 5 1.75 5h1.5a.75.75 0 0 1 0 1.5h-1.5a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 0 0 .25-.25v-1.5a.75.75 0 0 1 1.5 0v1.5A1.75 1.75 0 0 1 9.25 16h-7.5A1.75 1.75 0 0 1 0 14.25Z"></path><path d="M5 1.75C5 .784 5.784 0 6.75 0h7.5C15.216 0 16 .784 16 1.75v7.5A1.75 1.75 0 0 1 14.25 11h-7.5A1.75 1.75 0 0 1 5 9.25Zm1.75-.25a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 0 0 .25-.25v-7.5a.25.25 0 0 0-.25-.25Z"></path>
# </svg>
# <svg aria-hidden="true" class="octicon octicon-check js-clipboard-check-icon color-fg-success d-none m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M13.78 4.22a.75.75 0 0 1 0 1.06l-7.25 7.25a.75.75 0 0 1-1.06 0L2.22 9.28a.751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018L6 10.94l6.72-6.72a.75.75 0 0 1 1.06 0Z"></path>
# </svg>
# </clipboard-copy>
# </div>
# </template>
# <template id="snippet-clipboard-copy-button-unpositioned">
# <div class="zeroclipboard-container">
# <clipboard-copy aria-label="Copy" class="ClipboardButton btn btn-invisible js-clipboard-copy m-2 p-0 tooltipped-no-delay d-flex flex-justify-center flex-items-center" data-copy-feedback="Copied!" data-tooltip-direction="w">
# <svg aria-hidden="true" class="octicon octicon-copy js-clipboard-copy-icon" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M0 6.75C0 5.784.784 5 1.75 5h1.5a.75.75 0 0 1 0 1.5h-1.5a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 0 0 .25-.25v-1.5a.75.75 0 0 1 1.5 0v1.5A1.75 1.75 0 0 1 9.25 16h-7.5A1.75 1.75 0 0 1 0 14.25Z"></path><path d="M5 1.75C5 .784 5.784 0 6.75 0h7.5C15.216 0 16 .784 16 1.75v7.5A1.75 1.75 0 0 1 14.25 11h-7.5A1.75 1.75 0 0 1 5 9.25Zm1.75-.25a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 0 0 .25-.25v-7.5a.25.25 0 0 0-.25-.25Z"></path>
# </svg>
# <svg aria-hidden="true" class="octicon octicon-check js-clipboard-check-icon color-fg-success d-none" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M13.78 4.22a.75.75 0 0 1 0 1.06l-7.25 7.25a.75.75 0 0 1-1.06 0L2.22 9.28a.751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018L6 10.94l6.72-6.72a.75.75 0 0 1 1.06 0Z"></path>
# </svg>
# </clipboard-copy>
# </div>
# </template>
# </div>
# <div aria-atomic="true" aria-live="polite" class="sr-only" id="js-global-screen-reader-notice"></div>
# <div aria-atomic="true" aria-live="assertive" class="sr-only" id="js-global-screen-reader-notice-assertive"></div>
# </body>
# </html>

# %%
first_article = con_data.find('article',class_='border rounded color-shadow-small color-bg-subtle my-4')

# %%
first_article
# Out:
# <article class="border rounded color-shadow-small color-bg-subtle my-4">
# <a class="overflow-hidden flex-items-center rounded-top-2 Link color-border-muted border-bottom d-flex position-relative" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_IMAGE","actor_id":null,"record_id":943149,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="9222767076be9df7c83fc030c7508f4dd02e90e733a91bcb045e11bc9ea0f7e0" data-turbo="false" data-view-component="true" href="/d3/d3" style="max-height:275px">
# <img alt="d3" class="d-block width-full" loading="lazy" src="https://repository-images.githubusercontent.com/943149/c8e15cb8-7046-4518-9677-cd5f56b226c0"/>
# </a>
# <div class="px-3">
# <div class="d-flex flex-justify-between flex-items-start flex-wrap gap-2 my-3">
# <div class="d-flex flex-1">
# <span style="margin-top:2px">
# <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 0 1 4.5 0h8.75a.75.75 0 0 1 .75.75v12.5a.75.75 0 0 1-.75.75h-2.5a.75.75 0 0 1 0-1.5h1.75v-2h-8a1 1 0 0 0-.714 1.7.75.75 0 1 1-1.072 1.05A2.495 2.495 0 0 1 2 11.5Zm10.5-1h-8a1 1 0 0 0-1 1v6.708A2.486 2.486 0 0 1 4.5 9h8ZM5 12.25a.25.25 0 0 1 .25-.25h3.5a.25.25 0 0 1 .25.25v3.25a.25.25 0 0 1-.4.2l-1.45-1.087a.249.249 0 0 0-.3 0L5.4 15.7a.25.25 0 0 1-.4-.2Z"></path>
# </svg>
# </span>
# <h3 class="f3 color-fg-muted text-normal lh-condensed">
# <a class="Link" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":1562726,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="439a74e476c899b81f0336bb11a47258e0c53b8b0b257cb79092c44c917d43d8" data-turbo="false" data-view-component="true" href="/d3">
#             d3
# </a>          /
#           <a class="Link text-bold wb-break-word" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":943149,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="3e34357fbcffe8e7b93fe8340b69d2efc02d061ac9ce9930bd0fb8e4ab839ee8" data-turbo="false" data-view-component="true" href="/d3/d3">
#             d3
# </a> </h3>
# </div>
# <div class="d-flex flex-items-center">
# <div class="BtnGroup d-flex" data-view-component="true">
# <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":943149,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="c497ca2ec88e3dcda22e5fdeb95515b4d476e7c0a29f367d2f4ca03ba7bbef53" data-view-component="true" href="/login?return_to=%2Fd3%2Fd3" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8 .25a.75.75 0 0 1 .673.418l1.882 3.815 4.21.612a.75.75 0 0 1 .416 1.279l-3.046 2.97.719 4.192a.751.751 0 0 1-1.088.791L8 12.347l-3.766 1.98a.75.75 0 0 1-1.088-.79l.72-4.194L.818 6.374a.75.75 0 0 1 .416-1.28l4.21-.611L7.327.668A.75.75 0 0 1 8 .25Zm0 2.445L6.615 5.5a.75.75 0 0 1-.564.41l-3.097.45 2.24 2.184a.75.75 0 0 1 .216.664l-.528 3.084 2.769-1.456a.75.75 0 0 1 .698 0l2.77 1.456-.53-3.084a.75.75 0 0 1 .216-.664l2.24-2.183-3.096-.45a.75.75 0 0 1-.564-.41L8 2.694Z"></path>
# </svg><span class="d-inline" data-view-component="true">
#           Star
# </span> <span aria-label="107211 users starred this repository" class="Counter js-social-count" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="107,211">107k</span>
# </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="m4.427 7.427 3.396 3.396a.25.25 0 0 0 .354 0l3.396-3.396A.25.25 0 0 0 11.396 7H4.604a.25.25 0 0 0-.177.427Z"></path>
# </svg>
# </button></div>
# </div>
# </div>
# </div>
# <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
# <ul class="tabnav-tabs" data-view-component="true">
# <li class="d-inline-flex" data-view-component="true">
# <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":943149,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="5a7e2b6af085956d15972f869aa4ca9afaed7417534691a00d1ba335920df5b6" data-turbo="false" data-view-component="true" href="/d3/d3" id="code-tab-943149">
# <svg aria-hidden="true" class="octicon octicon-code color-fg-default" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="m11.28 3.22 4.25 4.25a.75.75 0 0 1 0 1.06l-4.25 4.25a.749.749 0 0 1-1.275-.326.749.749 0 0 1 .215-.734L13.94 8l-3.72-3.72a.749.749 0 0 1 .326-1.275.749.749 0 0 1 .734.215Zm-6.56 0a.751.751 0 0 1 1.042.018.751.751 0 0 1 .018 1.042L2.06 8l3.72 3.72a.749.749 0 0 1-.326 1.275.749.749 0 0 1-.734-.215L.47 8.53a.75.75 0 0 1 0-1.06Z"></path>
# </svg> Code
#
#
# </a></li>
# <li class="d-inline-flex" data-view-component="true">
# <a class="tabnav-tab f6 px-2 py-1" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":943149,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="84e67ffd0577c29310781a55a9a5e8653a5aaf99a54fde98ad72204c1efc0fdc" data-turbo="false" data-view-component="true" href="/d3/d3/issues" id="issues-tab-943149">
# <svg aria-hidden="true" class="octicon octicon-issue-opened color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8 9.5a1.5 1.5 0 1 0 0-3 1.5 1.5 0 0 0 0 3Z"></path><path d="M8 0a8 8 0 1 1 0 16A8 8 0 0 1 8 0ZM1.5 8a6.5 6.5 0 1 0 13 0 6.5 6.5 0 0 0-13 0Z"></path>
# </svg> Issues
#
#
# </a></li>
# <li class="d-inline-flex" data-view-component="true">
# <a class="tabnav-tab f6 px-2 py-1" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":943149,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="13102e833cc38b5c7f57b13c9183ff0f9ca2bfe00bca0d00c8a076ed23645a79" data-turbo="false" data-view-component="true" href="/d3/d3/pulls" id="pull-requests-tab-943149">
# <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.5 3.25a2.25 2.25 0 1 1 3 2.122v5.256a2.251 2.251 0 1 1-1.5 0V5.372A2.25 2.25 0 0 1 1.5 3.25Zm5.677-.177L9.573.677A.25.25 0 0 1 10 .854V2.5h1A2.5 2.5 0 0 1 13.5 5v5.628a2.251 2.251 0 1 1-1.5 0V5a1 1 0 0 0-1-1h-1v1.646a.25.25 0 0 1-.427.177L7.177 3.427a.25.25 0 0 1 0-.354ZM3.75 2.5a.75.75 0 1 0 0 1.5.75.75 0 0 0 0-1.5Zm0 9.5a.75.75 0 1 0 0 1.5.75.75 0 0 0 0-1.5Zm8.25.75a.75.75 0 1 0 1.5 0 .75.75 0 0 0-1.5 0Z"></path>
# </svg> Pull requests
#
#
# </a></li>
# <li class="d-inline-flex" data-view-component="true">
# <a class="tabnav-tab f6 px-2 py-1" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_DISCUSSIONS","click_visual_representation":"DISCUSSIONS_TAB","actor_id":null,"record_id":943149,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="ea6c3d3ec5fa9925683eb26e1c36f2bb311d0872c28ef9f2892aefec8af3a8f6" data-turbo="false" data-view-component="true" href="/d3/d3/discussions" id="discussions-tab-943149">
# <svg aria-hidden="true" class="octicon octicon-comment-discussion color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 1h8.5c.966 0 1.75.784 1.75 1.75v5.5A1.75 1.75 0 0 1 10.25 10H7.061l-2.574 2.573A1.458 1.458 0 0 1 2 11.543V10h-.25A1.75 1.75 0 0 1 0 8.25v-5.5C0 1.784.784 1 1.75 1ZM1.5 2.75v5.5c0 .138.112.25.25.25h1a.75.75 0 0 1 .75.75v2.19l2.72-2.72a.749.749 0 0 1 .53-.22h3.5a.25.25 0 0 0 .25-.25v-5.5a.25.25 0 0 0-.25-.25h-8.5a.25.25 0 0 0-.25.25Zm13 2a.25.25 0 0 0-.25-.25h-.5a.75.75 0 0 1 0-1.5h.5c.966 0 1.75.784 1.75 1.75v5.5A1.75 1.75 0 0 1 14.25 12H14v1.543a1.458 1.458 0 0 1-2.487 1.03L9.22 12.28a.749.749 0 0 1 .326-1.275.749.749 0 0 1 .734.215l2.22 2.22v-2.19a.75.75 0 0 1 .75-.75h1a.25.25 0 0 0 .25-.25Z"></path>
# </svg> Discussions
#
#
# </a></li>
# </ul>
# </nav>
# <div class="color-bg-default rounded-bottom-2">
# <div class="px-3 pt-3">
# <p class="color-fg-muted mb-0">Bring data to life with SVG, Canvas and HTML. 📊📈🎉</p>
# </div>
# <div class="d-flex flex-wrap border-bottom color-border-muted px-3 pt-2 pb-2">
# <a class="topic-tag topic-tag-link Link f6 mb-2" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":22,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="4106956a24b6d6b710480bde4f6aa5d7b8ad28f05af287f48a58b463c6384940" data-view-component="true" href="/topics/visualization" title="Topic: visualization">
#             visualization
# </a> <a class="topic-tag topic-tag-link Link f6 mb-2" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":58,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="ce9b8cd5876e5bdbdfa2a654f043249b6e1c7c080e3449223336cd6f21e4bbf0" data-view-component="true" href="/topics/d3" title="Topic: d3">
#             d3
# </a> <a class="topic-tag topic-tag-link Link f6 mb-2" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":123,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="7b4a9e26342e7090dfae2dfc6063995e276e2653a4b9440f654c436de59f5b11" data-view-component="true" href="/topics/svg" title="Topic: svg">
#             svg
# </a> <a class="topic-tag topic-tag-link Link f6 mb-2" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":786,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="0b2a09dbf1b8beaa2000bd4d83086a5580b85aa8bfd2568deef77869e7c79857" data-view-component="true" href="/topics/chart" title="Topic: chart">
#             chart
# </a> <a class="topic-tag topic-tag-link Link f6 mb-2" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":790,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="d0a62ef9c1a1bf18ae48582a4047aed893f70097d440e383c83665b58e80a6f0" data-view-component="true" href="/topics/charts" title="Topic: charts">
#             charts
# </a> <a class="topic-tag topic-tag-link Link f6 mb-2" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":22808,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="d7356342c27cbe42e910f0c51b20405ff88c15a467aed1ce19c65f7f76fce1ad" data-view-component="true" href="/topics/data-visualization" title="Topic: data-visualization">
#             data-visualization
# </a> </div>
# <div class="p-3">
# <ul class="d-flex f6 list-style-none color-fg-muted">
# <li class="mr-4">
#             Updated
#             <relative-time class="no-wrap" datetime="2024-01-29T16:31:44Z">Jan 29, 2024</relative-time>
# </li>
# <li class="mr-4">
# <span class="f6 my-1 ml-0">
# <span class="repo-language-color" style="background-color: #89e051"></span>
# <span itemprop="programmingLanguage">Shell</span>
# </span>
# </li>
# </ul>
# </div>
# </div>
# </article>

# %%
Repository_name = first_article.find('a',class_='text-bold wb-break-word').text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 Repository_name = first_article.find('a',class_='text-bold wb-break-word').text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
Repository_name.strip()
# Out:
# 'd3'

# %%
User_name = first_article.find('a',class_='').text

# %%
User_name.strip()
# Out:
# 'd3'

# %%
Stars = first_article.find('span',class_='Counter js-social-count').text

# %%
Stars.strip()
# Out:
# '102k'

# %%
Url = first_article.find('a',class_='text-bold wb-break-word')['href']

# %%
base_Url = 'https://github.com/'

# %%
print(base_Url + Url)
# Out:
# https://github.com//d3/d3

# %%
all_article = con_data.find_all('article',class_='border rounded color-shadow-small color-bg-subtle my-4')

# %%
all_article
# Out:
# [<article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":1562726,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="d83717a28f506485b8bc46429aca675092e2b7ef794cfde05ffac7b9622b31b3" data-turbo="false" data-view-component="true" href="/d3">
#              d3
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":943149,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="7647bf9ae66f2120df02ce79ce6cf1b3e0cbd2234a68a0938a26e5b7262806c7" data-turbo="false" data-view-component="true" href="/d3/d3">
#              d3
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":943149,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="9ef72bcf96bcde8f89656d2c6098f8c269b344f5d9d8484ddf004a6f0b6fe363" data-view-component="true" href="/login?return_to=%2Fd3%2Fd3" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="102087 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="102,087">102k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":943149,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="a9844da2c2887069a3c42d1022b30db708a690a65919fcb597f962b3bac13229" data-turbo="false" data-view-component="true" href="/d3/d3" id="code-tab-943149">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-default" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":943149,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="dc123b5c3d3f732bb0569f654fe5c33a9bc6dced26be6d2098e52a0a46e98979" data-turbo="false" data-view-component="true" href="/d3/d3/issues" id="issues-tab-943149">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-light" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":943149,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="145f193ceec760fb16126fd8a8cefabdbcc3f38d0dbbb5bedcc8f535e29923c3" data-turbo="false" data-view-component="true" href="/d3/d3/pulls" id="pull-requests-tab-943149">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository discussions, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_DISCUSSIONS","click_visual_representation":"DISCUSSIONS_TAB","actor_id":null,"record_id":943149,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="781bdfedfa7eef8b77ba9a28c0736abcb6fbb67d22999721f15b62c6079372f6" data-turbo="false" data-view-component="true" href="/d3/d3/discussions" id="discussions-tab-943149">
#  <svg aria-hidden="true" class="octicon octicon-comment-discussion color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M1.5 2.75a.25.25 0 01.25-.25h8.5a.25.25 0 01.25.25v5.5a.25.25 0 01-.25.25h-3.5a.75.75 0 00-.53.22L3.5 11.44V9.25a.75.75 0 00-.75-.75h-1a.25.25 0 01-.25-.25v-5.5zM1.75 1A1.75 1.75 0 000 2.75v5.5C0 9.216.784 10 1.75 10H2v1.543a1.457 1.457 0 002.487 1.03L7.061 10h3.189A1.75 1.75 0 0012 8.25v-5.5A1.75 1.75 0 0010.25 1h-8.5zM14.5 4.75a.25.25 0 00-.25-.25h-.5a.75.75 0 110-1.5h.5c.966 0 1.75.784 1.75 1.75v5.5A1.75 1.75 0 0114.25 12H14v1.543a1.457 1.457 0 01-2.487 1.03L9.22 12.28a.75.75 0 111.06-1.06l2.22 2.22v-2.19a.75.75 0 01.75-.75h1a.25.25 0 00.25-.25v-5.5z" fill-rule="evenodd"></path>
#  </svg> Discussions
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <div class="px-3 pt-3">
#  <p class="color-fg-muted mb-0"></p><div>Bring data to life with SVG, Canvas and HTML. <g-emoji alias="bar_chart" class="g-emoji" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/1f4ca.png">📊</g-emoji><g-emoji alias="chart_with_upwards_trend" class="g-emoji" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/1f4c8.png">📈</g-emoji><g-emoji alias="tada" class="g-emoji" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/1f389.png">🎉</g-emoji>
#  </div>
#  </div>
#  <div class="d-flex flex-wrap border-bottom color-border-muted px-3 pt-2 pb-2">
#  <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":22,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="7e519170ac3707163660eb147091d0f081c21ed9f012162a140e6cd0c0ca2d05" data-view-component="true" href="/topics/visualization" title="Topic: visualization">
#                visualization
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":123,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="a1a0eab010899b3748f8f2578859e87d01d37e3ff0de41ede6619bbd6b8e2d4a" data-view-component="true" href="/topics/svg" title="Topic: svg">
#                svg
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":786,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="02a31b029afb1bcae34d4a015737b27bfd67e98d2b2339500a0ab06c3a55aecb" data-view-component="true" href="/topics/chart" title="Topic: chart">
#                chart
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":790,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="7af0712f614ec167aa5c80647cb18b24ec2569ea3b01a256e8451917664038d0" data-view-component="true" href="/topics/charts" title="Topic: charts">
#                charts
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":22808,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="ebb237af5af5fbd41667c92068313f45a15fb49d4b19c9fc9f0d0823ddf744e6" data-view-component="true" href="/topics/data-visualization" title="Topic: data-visualization">
#                data-visualization
#  </a> </div>
#  <div class="p-3">
#  <ul class="d-flex f6 list-style-none color-fg-muted">
#  <li class="mr-4">
#                Updated
#                <relative-time class="no-wrap" datetime="2022-07-09T14:42:14Z">Jul 9, 2022</relative-time>
#  </li>
#  <li class="mr-4">
#  <span class="f6 my-1 ml-0">
#  <span class="repo-language-color" style="background-color: #f1e05a"></span>
#  <span itemprop="programmingLanguage">JavaScript</span>
#  </span>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </article>,
#  <article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":47359,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="4993cf5bcf9abfb488a39b1e1f97ea91facfb1b343287d37bb9b6890e35ca79b" data-turbo="false" data-view-component="true" href="/apache">
#              apache
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":9185792,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="7b46c31d2ba4c3e1f73d2347dc6b52de0a0bda103ba16025775306dba6b79e41" data-turbo="false" data-view-component="true" href="/apache/echarts">
#              echarts
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":9185792,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="6fde49ec5b09a25935ee0bf6834fa228ee721e02096b332e271d9c4a80637b94" data-view-component="true" href="/login?return_to=%2Fapache%2Fecharts" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="51935 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="51,935">51.9k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":9185792,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="e7b82752e36a47eeb07e5dc360dcfaa1238a052b8a2f66f194378d5b4bd4405d" data-turbo="false" data-view-component="true" href="/apache/echarts" id="code-tab-9185792">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-default" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":9185792,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="caceb45c2dde1e85afea6a1a196046d479026f45ed8901c3251cfb1f4b4c7576" data-turbo="false" data-view-component="true" href="/apache/echarts/issues" id="issues-tab-9185792">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-light" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":9185792,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="f45915723b15a123bf073f2651d2e32a20894b2782eae147b4cb870c2b680384" data-turbo="false" data-view-component="true" href="/apache/echarts/pulls" id="pull-requests-tab-9185792">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <div class="px-3 pt-3">
#  <p class="color-fg-muted mb-0"></p><div>Apache ECharts is a powerful, interactive charting and data visualization library for browser</div>
#  </div>
#  <div class="d-flex flex-wrap border-bottom color-border-muted px-3 pt-2 pb-2">
#  <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":22,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="7e519170ac3707163660eb147091d0f081c21ed9f012162a140e6cd0c0ca2d05" data-view-component="true" href="/topics/visualization" title="Topic: visualization">
#                visualization
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":123,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="a1a0eab010899b3748f8f2578859e87d01d37e3ff0de41ede6619bbd6b8e2d4a" data-view-component="true" href="/topics/svg" title="Topic: svg">
#                svg
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":790,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="7af0712f614ec167aa5c80647cb18b24ec2569ea3b01a256e8451917664038d0" data-view-component="true" href="/topics/charts" title="Topic: charts">
#                charts
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":9049,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="047f091fcb272182007a9281d740a9efdb8a810d884af5ae63e58e9373ab49dc" data-view-component="true" href="/topics/canvas" title="Topic: canvas">
#                canvas
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":9148,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="3e4f1317971112f11fabf135e8817aef4ceb98f94382cac1c102452881c72805" data-view-component="true" href="/topics/charting-library" title="Topic: charting-library">
#                charting-library
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":20817,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="3a65918aae1d161d600a2fc0eea108f5995395b232d958cda41f105937d74205" data-view-component="true" href="/topics/apache" title="Topic: apache">
#                apache
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":22808,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="ebb237af5af5fbd41667c92068313f45a15fb49d4b19c9fc9f0d0823ddf744e6" data-view-component="true" href="/topics/data-visualization" title="Topic: data-visualization">
#                data-visualization
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":44535,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="f3db203e4c0512d6190f5fc1e3f2144f0ef579febb85e72e6baff76a3dbe86b7" data-view-component="true" href="/topics/data-viz" title="Topic: data-viz">
#                data-viz
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":177332,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="b2e7a5432168ce3b419ea7ff0a4059414f657aa183ad83228c8c46632541ae64" data-view-component="true" href="/topics/echarts" title="Topic: echarts">
#                echarts
#  </a> </div>
#  <div class="p-3">
#  <ul class="d-flex f6 list-style-none color-fg-muted">
#  <li class="mr-4">
#                Updated
#                <relative-time class="no-wrap" datetime="2022-07-29T03:40:13Z">Jul 29, 2022</relative-time>
#  </li>
#  <li class="mr-4">
#  <span class="f6 my-1 ml-0">
#  <span class="repo-language-color" style="background-color: #3178c6"></span>
#  <span itemprop="programmingLanguage">TypeScript</span>
#  </span>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </article>,
#  <article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <a class="overflow-hidden flex-items-center rounded-top-2 color-border-muted border-bottom d-flex position-relative" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_IMAGE","actor_id":null,"record_id":15111821,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="2408b4a6e0caa635efe6c9cbcc916f0c4d76df65715983622524a8adc7abab7c" data-turbo="false" data-view-component="true" href="/grafana/grafana" style="max-height:275px">
#  <img alt="grafana" class="d-block width-full" loading="lazy" src="https://repository-images.githubusercontent.com/15111821/ec8ccf00-1db1-11eb-87b4-95f15e4b1fc2"/>
#  </a>
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":7195757,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="15cb4a172ca4afcc2727e132a0f2dbac98b131472717295db5a76c6692161ec3" data-turbo="false" data-view-component="true" href="/grafana">
#              grafana
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":15111821,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="c5a7485db2b611b2eee84b43b5b98d48e3a31f2de07ed04990c7faba4038f877" data-turbo="false" data-view-component="true" href="/grafana/grafana">
#              grafana
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":15111821,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="9e37024901dcccf070bb947f7f3c1b243e845c3622ca501fd4e331748faf8ecd" data-view-component="true" href="/login?return_to=%2Fgrafana%2Fgrafana" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="50157 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="50,157">50.2k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":15111821,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="07ff009d74a5e6df5edebd406da1b3c46909b7bb2eb4307896bb420c40d60483" data-turbo="false" data-view-component="true" href="/grafana/grafana" id="code-tab-15111821">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":15111821,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="4d2fb2079b9b0fec44e4bd3ff8e1326ca787cfedef6fcee5754bccc063c3adce" data-turbo="false" data-view-component="true" href="/grafana/grafana/issues" id="issues-tab-15111821">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-dark" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":15111821,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="b079f2a519a662a91b74f670e6efdb8a844a16ca2e9c40e7f5d570d5b0de03e1" data-turbo="false" data-view-component="true" href="/grafana/grafana/pulls" id="pull-requests-tab-15111821">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository discussions, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_DISCUSSIONS","click_visual_representation":"DISCUSSIONS_TAB","actor_id":null,"record_id":15111821,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="5882d924a0d5c75d2f949154ca488ad9e086dfce779a3c38ec449ab6e377b836" data-turbo="false" data-view-component="true" href="/grafana/grafana/discussions" id="discussions-tab-15111821">
#  <svg aria-hidden="true" class="octicon octicon-comment-discussion color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M1.5 2.75a.25.25 0 01.25-.25h8.5a.25.25 0 01.25.25v5.5a.25.25 0 01-.25.25h-3.5a.75.75 0 00-.53.22L3.5 11.44V9.25a.75.75 0 00-.75-.75h-1a.25.25 0 01-.25-.25v-5.5zM1.75 1A1.75 1.75 0 000 2.75v5.5C0 9.216.784 10 1.75 10H2v1.543a1.457 1.457 0 002.487 1.03L7.061 10h3.189A1.75 1.75 0 0012 8.25v-5.5A1.75 1.75 0 0010.25 1h-8.5zM14.5 4.75a.25.25 0 00-.25-.25h-.5a.75.75 0 110-1.5h.5c.966 0 1.75.784 1.75 1.75v5.5A1.75 1.75 0 0114.25 12H14v1.543a1.457 1.457 0 01-2.487 1.03L9.22 12.28a.75.75 0 111.06-1.06l2.22 2.22v-2.19a.75.75 0 01.75-.75h1a.25.25 0 00.25-.25v-5.5z" fill-rule="evenodd"></path>
#  </svg> Discussions
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <article class="p-3">
#  <div class="d-flex flex-justify-between mb-3">
#  <div class="d-flex flex-items-center">
#  <span class="State State--open State--small v-align-bottom mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto f3 text-normal ml-1 wb-break-word">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"BIG_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1317591756,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="c6e478b5a888883dccf9b7adfdb6b3c48c450e0566a0b917548a082b49dcaba1" data-turbo="false" data-view-component="true" href="https://github.com/grafana/grafana/issues/52773">
#                  Footer: Grafana Version / Commit is an empty link
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                3
#              </div>
#  </div>
#  <div class="d-flex">
#  <div class="mr-3">
#  <img alt="zuchka" class="avatar avatar-user avatar-small" height="32" src="https://avatars.githubusercontent.com/u/37156449?v=4" width="32"/>
#  </div>
#  <div class="flex-auto" style="width: 80%;">
#  <div class="Box Box--condensed position-relative timeline-comment--caret">
#  <div class="Box-header f6 color-fg-muted">
#  <strong class="color-fg-default text-bold">
#                    zuchka
#                  </strong>
#
#                    commented
#
#                  <relative-time class="no-wrap" datetime="2022-07-26T01:53:59Z">Jul 26, 2022</relative-time>
#  </div>
#  <div class="Box-body comment-body markdown-body position-relative overflow-hidden pt-3" style="max-height:200px">
#  <p><strong>What happened</strong>:<br/>
#  Wherever Grafana generates a footer, it adds the Grafana version and commit to the list of links:</p>
#  <p><a href="https://github.com/grafana/grafana/blob/238d761450738cdef822589f321500879fa49b32/public/app/core/components/Footer/Footer.tsx#L48">https://github.com/grafana/grafana/blob/238d761450738cdef822589f321500879fa49b32/public/app/core/components/Footer/Footer.tsx#L48</a></p>
#  <p>The link is empty, which I've always found a little disappointing. I was thinking we could reference the commit like this:</p>
#  <pre class="notranslate"><code class="notranslate">links.push({ te
#  </code></pre>
#  <div class="position-absolute right-0 left-0 bottom-0 text-center" style="background: linear-gradient(to top, var(--color-canvas-default), var(--color-canvas-default-transparent));">
#  <a class="btn btn-outline btn-sm mx-auto my-3" data-ga-click="Explore, go to issue, location:good first issues;text:read more;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"READ_MORE","actor_id":null,"record_id":1317591756,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="f05f939c4c3efa1d412cedad255e443f6abc38e6e42b4b934507f7bb5aee2389" href="https://github.com/grafana/grafana/issues/52773">
#                        Read more
#  </a> </div>
#  </div>
#  </div>
#  <div class="mt-3">
#  <span class="discussion-item-icon border-white-fade ml-0 mr-2">
#  <svg aria-hidden="true" class="octicon octicon-tag" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.5 7.775V2.75a.25.25 0 01.25-.25h5.025a.25.25 0 01.177.073l6.25 6.25a.25.25 0 010 .354l-5.025 5.025a.25.25 0 01-.354 0l-6.25-6.25a.25.25 0 01-.073-.177zm-1.5 0V2.75C1 1.784 1.784 1 2.75 1h5.025c.464 0 .91.184 1.238.513l6.25 6.25a1.75 1.75 0 010 2.474l-5.026 5.026a1.75 1.75 0 01-2.474 0l-6.25-6.25A1.75 1.75 0 011 7.775zM6 5a1 1 0 100 2 1 1 0 000-2z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <div class="wb-break-word">
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":70176318,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="2d154e9db13bf54ab0853b070d487edf407d28964c39a0d15b894e2948643964" data-name="type/bug" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3Atype%2Fbug" id="label-58b141" style="--label-r:215;--label-g:58;--label-b:74;--label-h:353;--label-s:66;--label-l:53;">
#                      type/bug
#  </a>
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":223098243,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="eb33bdfd504155449941c1c51bdb36d62b39e1e2efdf33cbed6496fcd2978bc5" data-name="help wanted" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22help+wanted%22" id="label-5ff28a" style="--label-r:191;--label-g:229;--label-b:191;--label-h:120;--label-s:42;--label-l:82;">
#                      help wanted
#  </a>
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":1544967554,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="1bb7cd07dbfe3a914a145c370484e7a64c0f84be36d8ac41d01426d4d0c1e4c7" data-name="area/navigation" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3Aarea%2Fnavigation" id="label-514da4" style="--label-r:199;--label-g:222;--label-b:248;--label-h:211;--label-s:77;--label-l:87;">
#                      area/navigation
#  </a>
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":2497777241,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="9fe1452e95dab39849096f6c01865b7d8baba54fee7a612ed1ce17597b5b77f0" data-name="good first issue" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22good+first+issue%22" id="label-8b0eaa" style="--label-r:112;--label-g:87;--label-b:255;--label-h:248;--label-s:100;--label-l:67;">
#                      good first issue
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-8b0eaa" hidden="hidden">Good for newcomers</tool-tip>
#  </div>
#  </div>
#  </div>
#  </div>
#  </article>
#  <div class="px-3 pb-3">
#  <article class="d-flex flex-justify-between mb-2">
#  <div class="d-flex flex-items-center">
#  <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto h5 ml-1 wb-break-word">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:small;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"LITTLE_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1295825122,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="a14816ba062899db99c117132d40abfb3962172219834bf0878a1c429bf33dd2" data-turbo="false" data-view-component="true" href="https://github.com/grafana/grafana/issues/51813">
#                      Dashboard Dropdown Menus do not close when opened one by one
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                    1
#                  </div>
#  </article>
#  <article class="d-flex flex-justify-between mb-2">
#  <div class="d-flex flex-items-center">
#  <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto h5 ml-1 wb-break-word">
# ...
#                data-visualisation
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":447322,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="8ee4ede9c269052789960c8930f2a542ff83ecfe10575480f42f5783317fdc8a" data-view-component="true" href="/topics/f2" title="Topic: f2">
#                f2
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":629894,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="156c890096dd2d0902c9a2f0b8655f896761b0c5438d8a77823a2ae22bc8dc85" data-view-component="true" href="/topics/antv" title="Topic: antv">
#                antv
#  </a> </div>
#  <div class="p-3">
#  <ul class="d-flex f6 list-style-none color-fg-muted">
#  <li class="mr-4">
#                Updated
#                <relative-time class="no-wrap" datetime="2022-07-22T14:50:43Z">Jul 22, 2022</relative-time>
#  </li>
#  <li class="mr-4">
#  <span class="f6 my-1 ml-0">
#  <span class="repo-language-color" style="background-color: #3178c6"></span>
#  <span itemprop="programmingLanguage">TypeScript</span>
#  </span>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </article>,
#  <article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":43234,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="367f22c1583d3ea0da9ae8cdfce8d7d9fd5765525d4221989073cf1ad3c2d62f" data-turbo="false" data-view-component="true" href="/leeoniya">
#              leeoniya
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":211381955,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="7caa8c872d05c73ebefb48d7f8fb5494fd3b9cdf3521d34bbd29711873e85c5e" data-turbo="false" data-view-component="true" href="/leeoniya/uPlot">
#              uPlot
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <a aria-label="Sponsor @leeoniya" class="btn btn-sm mr-2" data-hydro-click='{"event_type":"sponsors.button_click","payload":{"button":"TOPIC_PAGE_SPONSOR","sponsorable_login":"leeoniya","originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="05ae6ce7f6d924b8018cb7177d5ecb2a4a01affc6bce11368b108fc9f29a9b4a" data-view-component="true" href="/sponsors/leeoniya">
#  <svg aria-hidden="true" class="octicon octicon-heart icon-sponsor mr-1 v-align-middle color-fg-sponsors anim-pulse-in" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.25 2.5c-1.336 0-2.75 1.164-2.75 3 0 2.15 1.58 4.144 3.365 5.682A20.565 20.565 0 008 13.393a20.561 20.561 0 003.135-2.211C12.92 9.644 14.5 7.65 14.5 5.5c0-1.836-1.414-3-2.75-3-1.373 0-2.609.986-3.029 2.456a.75.75 0 01-1.442 0C6.859 3.486 5.623 2.5 4.25 2.5zM8 14.25l-.345.666-.002-.001-.006-.003-.018-.01a7.643 7.643 0 01-.31-.17 22.075 22.075 0 01-3.434-2.414C2.045 10.731 0 8.35 0 5.5 0 2.836 2.086 1 4.25 1 5.797 1 7.153 1.802 8 3.02 8.847 1.802 10.203 1 11.75 1 13.914 1 16 2.836 16 5.5c0 2.85-2.045 5.231-3.885 6.818a22.08 22.08 0 01-3.744 2.584l-.018.01-.006.003h-.002L8 14.25zm0 0l.345.666a.752.752 0 01-.69 0L8 14.25z" fill-rule="evenodd"></path>
#  </svg>
#  <span class="v-align-middle">Sponsor</span>
#  </a>
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":211381955,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="0237f465dc95474e7d1df1b35aec3e38c2dac8771c3267a0d0b469efd9e728c9" data-view-component="true" href="/login?return_to=%2Fleeoniya%2FuPlot" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="7221 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="7,221">7.2k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":211381955,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="77f8a916900dfd06336da8de6f7f4d521351470dfc28272f9bbf5acde6c45c2b" data-turbo="false" data-view-component="true" href="/leeoniya/uPlot" id="code-tab-211381955">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":211381955,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="6a8abe17db6162b2ec7c98fc132af84c94acbf889640f582691de5fd3b2573f1" data-turbo="false" data-view-component="true" href="/leeoniya/uPlot/issues" id="issues-tab-211381955">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-dark" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":211381955,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="76eb51b70acccc538d63e24c498ef03186b2406712effb2a6bd7c948df9635b0" data-turbo="false" data-view-component="true" href="/leeoniya/uPlot/pulls" id="pull-requests-tab-211381955">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <article class="p-3">
#  <div class="d-flex flex-justify-between mb-3">
#  <div class="d-flex flex-items-center">
#  <span class="State State--open State--small v-align-bottom mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto f3 text-normal ml-1 wb-break-word">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"BIG_GOOD_FIRST_ISSUE","actor_id":null,"record_id":537950452,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="53cf483875cd23a402afad8750db2780ca05ee53192c313b181a299338eea0d1" data-turbo="false" data-view-component="true" href="https://github.com/leeoniya/uPlot/issues/72">
#                  Tests
#  </a> </h4>
#  </div>
#  </div>
#  <div class="d-flex">
#  <div class="mr-3">
#  <img alt="leeoniya" class="avatar avatar-user avatar-small" height="32" src="https://avatars.githubusercontent.com/u/43234?v=4" width="32"/>
#  </div>
#  <div class="flex-auto" style="width: 80%;">
#  <div class="Box Box--condensed position-relative timeline-comment--caret">
#  <div class="Box-header f6 color-fg-muted">
#  <strong class="color-fg-default text-bold">
#                    leeoniya
#                  </strong>
#
#                    commented
#
#                  <relative-time class="no-wrap" datetime="2019-12-14T18:50:43Z">Dec 14, 2019</relative-time>
#  </div>
#  <div class="Box-body comment-body markdown-body position-relative overflow-hidden pt-3" style="max-height:200px">
#  <p>it's becoming more time-consuming and error-prone to manually re-test all the demos following internal refactorings and API adjustments.</p>
#  <p>now that the API is fleshed out a bit, it's possible to test a large amount of code (non-granularly) without having to simulate all interactions via Puppeteer or similar.</p>
#  <p>a lot of code can already be regression-tested by simply running all the demos and val</p>
#  <div class="position-absolute right-0 left-0 bottom-0 text-center" style="background: linear-gradient(to top, var(--color-canvas-default), var(--color-canvas-default-transparent));">
#  <a class="btn btn-outline btn-sm mx-auto my-3" data-ga-click="Explore, go to issue, location:good first issues;text:read more;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"READ_MORE","actor_id":null,"record_id":537950452,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="dfe6dd45acf3f1d158c1aeb0e52e9675ec62297cd804cb0aa0850898ef545a7f" href="https://github.com/leeoniya/uPlot/issues/72">
#                        Read more
#  </a> </div>
#  </div>
#  </div>
#  <div class="mt-3">
#  <span class="discussion-item-icon border-white-fade ml-0 mr-2">
#  <svg aria-hidden="true" class="octicon octicon-tag" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.5 7.775V2.75a.25.25 0 01.25-.25h5.025a.25.25 0 01.177.073l6.25 6.25a.25.25 0 010 .354l-5.025 5.025a.25.25 0 01-.354 0l-6.25-6.25a.25.25 0 01-.073-.177zm-1.5 0V2.75C1 1.784 1.784 1 2.75 1h5.025c.464 0 .91.184 1.238.513l6.25 6.25a1.75 1.75 0 010 2.474l-5.026 5.026a1.75 1.75 0 01-2.474 0l-6.25-6.25A1.75 1.75 0 011 7.775zM6 5a1 1 0 100 2 1 1 0 000-2z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <div class="wb-break-word">
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":1582337676,"originating_url":"https://github.com/topics/data-visualization","user_id":null}}' data-hydro-click-hmac="0a5728ddf0998d24f6f3ba460c4e4ecbe19e8533761c28e12ee2aa4afa452985" data-name="good first issue" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22good+first+issue%22" id="label-8df197" style="--label-r:112;--label-g:87;--label-b:255;--label-h:248;--label-s:100;--label-l:67;">
#                      good first issue
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-8df197" hidden="hidden">Good for newcomers</tool-tip>
#  </div>
#  </div>
#  </div>
#  </div>
#  </article>
#  </div>
#  </article>]

# %%
page_1 = []
for item in all_article:
    Repository_name = item.find('a',class_='text-bold wb-break-word').text
    User_name = item.find('a',class_='').text
    Stars = item.find('span',class_='Counter js-social-count').text
    URL = item.find('a',class_='text-bold wb-break-word')['href']
    User_name = User_name.strip()
    Repository_name = Repository_name.strip()
    URL = URL.strip()
    Stars = Stars.strip()
    page_1_dict = {
        'Repository Name': Repository_name,
        'User Name': User_name,
        'Stars': Stars,
        'URL': base_Url + Url
    }
    
    page_1.append(page_1_dict)

# %%
print(page_1)
# Out:
# [{'Repository Name': 'd3', 'User Name': 'd3', 'Stars': '102k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'echarts', 'User Name': 'apache', 'Stars': '51.9k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'grafana', 'User Name': 'grafana', 'Stars': '50.2k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'superset', 'User Name': 'apache', 'Stars': '47.3k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'pixijs', 'User Name': 'pixijs', 'Stars': '37k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'metabase', 'User Name': 'metabase', 'Stars': '29.3k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'streamlit', 'User Name': 'streamlit', 'Stars': '20.1k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'awesome-datascience', 'User Name': 'academic', 'Stars': '19.1k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'directus', 'User Name': 'directus', 'Stars': '17.1k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'dash', 'User Name': 'plotly', 'Stars': '17.1k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'matplotlib', 'User Name': 'matplotlib', 'Stars': '15.9k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'Data-Science-For-Beginners', 'User Name': 'microsoft', 'Stars': '15.6k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'visx', 'User Name': 'airbnb', 'Stars': '15.5k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'plotly.js', 'User Name': 'plotly', 'Stars': '14.9k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'apexcharts.js', 'User Name': 'apexcharts', 'Stars': '11.7k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'G2', 'User Name': 'antvis', 'Stars': '11.3k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'best-of-ml-python', 'User Name': 'ml-tooling', 'Stars': '11.3k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'awesome-bigdata', 'User Name': 'newTendermint', 'Stars': '11.1k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'deck.gl', 'User Name': 'visgl', 'Stars': '10.1k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'victory', 'User Name': 'FormidableLabs', 'Stars': '9.8k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'awesome-creative-coding', 'User Name': 'terkelg', 'Stars': '9.8k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'seaborn', 'User Name': 'mwaskom', 'Stars': '9.6k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'c3', 'User Name': 'c3js', 'Stars': '9.2k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'G6', 'User Name': 'antvis', 'Stars': '9.1k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'kepler.gl', 'User Name': 'keplergl', 'Stars': '8.7k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'react-vis', 'User Name': 'uber', 'Stars': '8.3k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'rawgraphs-app', 'User Name': 'rawgraphs', 'Stars': '8.2k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'gradio', 'User Name': 'gradio-app', 'Stars': '8k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'F2', 'User Name': 'antvis', 'Stars': '7.7k', 'URL': 'https://github.com//d3/d3'}, {'Repository Name': 'uPlot', 'User Name': 'leeoniya', 'Stars': '7.2k', 'URL': 'https://github.com//d3/d3'}]

# %%
import pandas as pd

# %%
df = pd.DataFrame(page_1)

# %%
df
# Out:
#                Repository Name       User Name  Stars  \
# 0                           d3              d3   102k
# 1                      echarts          apache  51.9k
# 2                      grafana         grafana  50.2k
# 3                     superset          apache  47.3k
# 4                       pixijs          pixijs    37k
# 5                     metabase        metabase  29.3k
# 6                    streamlit       streamlit  20.1k
# 7          awesome-datascience        academic  19.1k
# 8                     directus        directus  17.1k
# 9                         dash          plotly  17.1k
# 10                  matplotlib      matplotlib  15.9k
# 11  Data-Science-For-Beginners       microsoft  15.6k
# 12                        visx          airbnb  15.5k
# 13                   plotly.js          plotly  14.9k
# 14               apexcharts.js      apexcharts  11.7k
# 15                          G2          antvis  11.3k
# 16           best-of-ml-python      ml-tooling  11.3k
# 17             awesome-bigdata   newTendermint  11.1k
# 18                     deck.gl           visgl  10.1k
# 19                     victory  FormidableLabs   9.8k
# 20     awesome-creative-coding         terkelg   9.8k
# 21                     seaborn         mwaskom   9.6k
# 22                          c3            c3js   9.2k
# 23                          G6          antvis   9.1k
# 24                   kepler.gl        keplergl   8.7k
# 25                   react-vis            uber   8.3k
# 26               rawgraphs-app       rawgraphs   8.2k
# 27                      gradio      gradio-app     8k
# 28                          F2          antvis   7.7k
# 29                       uPlot        leeoniya   7.2k
#
#                           URL
# 0   https://github.com//d3/d3
# 1   https://github.com//d3/d3
# 2   https://github.com//d3/d3
# 3   https://github.com//d3/d3
# 4   https://github.com//d3/d3
# 5   https://github.com//d3/d3
# 6   https://github.com//d3/d3
# 7   https://github.com//d3/d3
# 8   https://github.com//d3/d3
# 9   https://github.com//d3/d3
# 10  https://github.com//d3/d3
# 11  https://github.com//d3/d3
# 12  https://github.com//d3/d3
# 13  https://github.com//d3/d3
# 14  https://github.com//d3/d3
# 15  https://github.com//d3/d3
# 16  https://github.com//d3/d3
# 17  https://github.com//d3/d3
# 18  https://github.com//d3/d3
# 19  https://github.com//d3/d3
# 20  https://github.com//d3/d3
# 21  https://github.com//d3/d3
# 22  https://github.com//d3/d3
# 23  https://github.com//d3/d3
# 24  https://github.com//d3/d3
# 25  https://github.com//d3/d3
# 26  https://github.com//d3/d3
# 27  https://github.com//d3/d3
# 28  https://github.com//d3/d3
# 29  https://github.com//d3/d3

# %%
df.to_excel('Page1.xlsx')

# %%
base_url = 'https://github.com/topics/data-visualization?page='

# %%
url = []
for num in range(1,8):
    
    url.append(base_url+str(num))

# %%
url
# Out:
# ['https://github.com/topics/data-visualization?page=1',
#  'https://github.com/topics/data-visualization?page=2',
#  'https://github.com/topics/data-visualization?page=3',
#  'https://github.com/topics/data-visualization?page=4',
#  'https://github.com/topics/data-visualization?page=5',
#  'https://github.com/topics/data-visualization?page=6',
#  'https://github.com/topics/data-visualization?page=7']

# %%
all_article_lst = []
for url_data in url:
    html_data = requests.get(url_data).text
   # print(url_data)
    converted_data = BeautifulSoup(html_data,'lxml')
    all_article = converted_data.find_all('article',class_='border rounded color-shadow-small color-bg-subtle my-4')
   # print(all_article)
    for item in all_article:
        Repository_name = item.find('a',class_='text-bold wb-break-word').text
        Repository_name = Repository_name.strip()
        User_name = item.find('a',class_='').text
        User_name = User_name.strip()
        Stars = item.find('span',class_='Counter js-social-count').text
        URL = item.find('a',class_='text-bold wb-break-word')['href']
        URL = URL.strip()
        
        
        dict2 = {
            'Repository Name': Repository_name,
            'User Name': User_name,
            'Stars': Stars,
            'URL': base_Url +URL
        }
        
        print(dict2)
        
        
        all_article_lst.append(dict2)
# Out:
# {'Repository Name': 'd3', 'User Name': 'd3', 'Stars': '102k', 'URL': 'https://github.com//d3/d3'}
# {'Repository Name': 'echarts', 'User Name': 'apache', 'Stars': '51.9k', 'URL': 'https://github.com//apache/echarts'}
# {'Repository Name': 'grafana', 'User Name': 'grafana', 'Stars': '50.2k', 'URL': 'https://github.com//grafana/grafana'}
# {'Repository Name': 'superset', 'User Name': 'apache', 'Stars': '47.3k', 'URL': 'https://github.com//apache/superset'}
# {'Repository Name': 'pixijs', 'User Name': 'pixijs', 'Stars': '37k', 'URL': 'https://github.com//pixijs/pixijs'}
# {'Repository Name': 'metabase', 'User Name': 'metabase', 'Stars': '29.3k', 'URL': 'https://github.com//metabase/metabase'}
# {'Repository Name': 'streamlit', 'User Name': 'streamlit', 'Stars': '20.1k', 'URL': 'https://github.com//streamlit/streamlit'}
# {'Repository Name': 'awesome-datascience', 'User Name': 'academic', 'Stars': '19.1k', 'URL': 'https://github.com//academic/awesome-datascience'}
# {'Repository Name': 'directus', 'User Name': 'directus', 'Stars': '17.1k', 'URL': 'https://github.com//directus/directus'}
# {'Repository Name': 'dash', 'User Name': 'plotly', 'Stars': '17.1k', 'URL': 'https://github.com//plotly/dash'}
# {'Repository Name': 'matplotlib', 'User Name': 'matplotlib', 'Stars': '15.9k', 'URL': 'https://github.com//matplotlib/matplotlib'}
# {'Repository Name': 'Data-Science-For-Beginners', 'User Name': 'microsoft', 'Stars': '15.6k', 'URL': 'https://github.com//microsoft/Data-Science-For-Beginners'}
# {'Repository Name': 'visx', 'User Name': 'airbnb', 'Stars': '15.5k', 'URL': 'https://github.com//airbnb/visx'}
# {'Repository Name': 'plotly.js', 'User Name': 'plotly', 'Stars': '14.9k', 'URL': 'https://github.com//plotly/plotly.js'}
# {'Repository Name': 'apexcharts.js', 'User Name': 'apexcharts', 'Stars': '11.7k', 'URL': 'https://github.com//apexcharts/apexcharts.js'}
# {'Repository Name': 'G2', 'User Name': 'antvis', 'Stars': '11.3k', 'URL': 'https://github.com//antvis/G2'}
# {'Repository Name': 'best-of-ml-python', 'User Name': 'ml-tooling', 'Stars': '11.3k', 'URL': 'https://github.com//ml-tooling/best-of-ml-python'}
# {'Repository Name': 'awesome-bigdata', 'User Name': 'newTendermint', 'Stars': '11.1k', 'URL': 'https://github.com//newTendermint/awesome-bigdata'}
# {'Repository Name': 'deck.gl', 'User Name': 'visgl', 'Stars': '10.1k', 'URL': 'https://github.com//visgl/deck.gl'}
# {'Repository Name': 'awesome-creative-coding', 'User Name': 'terkelg', 'Stars': '9.8k', 'URL': 'https://github.com//terkelg/awesome-creative-coding'}
# {'Repository Name': 'victory', 'User Name': 'FormidableLabs', 'Stars': '9.8k', 'URL': 'https://github.com//FormidableLabs/victory'}
# {'Repository Name': 'seaborn', 'User Name': 'mwaskom', 'Stars': '9.6k', 'URL': 'https://github.com//mwaskom/seaborn'}
# {'Repository Name': 'c3', 'User Name': 'c3js', 'Stars': '9.2k', 'URL': 'https://github.com//c3js/c3'}
# {'Repository Name': 'G6', 'User Name': 'antvis', 'Stars': '9.1k', 'URL': 'https://github.com//antvis/G6'}
# {'Repository Name': 'kepler.gl', 'User Name': 'keplergl', 'Stars': '8.7k', 'URL': 'https://github.com//keplergl/kepler.gl'}
# {'Repository Name': 'react-vis', 'User Name': 'uber', 'Stars': '8.3k', 'URL': 'https://github.com//uber/react-vis'}
# {'Repository Name': 'rawgraphs-app', 'User Name': 'rawgraphs', 'Stars': '8.2k', 'URL': 'https://github.com//rawgraphs/rawgraphs-app'}
# {'Repository Name': 'gradio', 'User Name': 'gradio-app', 'Stars': '8k', 'URL': 'https://github.com//gradio-app/gradio'}
# {'Repository Name': 'F2', 'User Name': 'antvis', 'Stars': '7.7k', 'URL': 'https://github.com//antvis/F2'}
# {'Repository Name': 'uPlot', 'User Name': 'leeoniya', 'Stars': '7.2k', 'URL': 'https://github.com//leeoniya/uPlot'}
# {'Repository Name': 'facets', 'User Name': 'PAIR-code', 'Stars': '7k', 'URL': 'https://github.com//PAIR-code/facets'}
# {'Repository Name': 'sourcerer-app', 'User Name': 'sourcerer-io', 'Stars': '6.7k', 'URL': 'https://github.com//sourcerer-io/sourcerer-app'}
# {'Repository Name': 'react-map-gl', 'User Name': 'visgl', 'Stars': '6.6k', 'URL': 'https://github.com//visgl/react-map-gl'}
# {'Repository Name': 'GoJS', 'User Name': 'NorthwoodsSoftware', 'Stars': '6.3k', 'URL': 'https://github.com//NorthwoodsSoftware/GoJS'}
# {'Repository Name': 'roughViz', 'User Name': 'jwilber', 'Stars': '6.3k', 'URL': 'https://github.com//jwilber/roughViz'}
# {'Repository Name': 'dataease', 'User Name': 'dataease', 'Stars': '6.3k', 'URL': 'https://github.com//dataease/dataease'}
# {'Repository Name': 'BizCharts', 'User Name': 'alibaba', 'Stars': '5.9k', 'URL': 'https://github.com//alibaba/BizCharts'}
# {'Repository Name': 'heatmap.js', 'User Name': 'pa7', 'Stars': '5.8k', 'URL': 'https://github.com//pa7/heatmap.js'}
# {'Repository Name': 'SandDance', 'User Name': 'microsoft', 'Stars': '5.8k', 'URL': 'https://github.com//microsoft/SandDance'}
# {'Repository Name': 'react-chartjs-2', 'User Name': 'reactchartjs', 'Stars': '5.2k', 'URL': 'https://github.com//reactchartjs/react-chartjs-2'}
# {'Repository Name': 'Live-Charts', 'User Name': 'Live-Charts', 'Stars': '5.2k', 'URL': 'https://github.com//Live-Charts/Live-Charts'}
# {'Repository Name': 'tui.chart', 'User Name': 'nhn', 'Stars': '5.1k', 'URL': 'https://github.com//nhn/tui.chart'}
# {'Repository Name': 'clip', 'User Name': 'asmuth', 'Stars': '5.1k', 'URL': 'https://github.com//asmuth/clip'}
# {'Repository Name': 'charts.css', 'User Name': 'ChartsCSS', 'Stars': '4.9k', 'URL': 'https://github.com//ChartsCSS/charts.css'}
# {'Repository Name': 'perspective', 'User Name': 'finos', 'Stars': '4.8k', 'URL': 'https://github.com//finos/perspective'}
# {'Repository Name': 'Historical-ranking-data-visualization-based-on-d3.js', 'User Name': 'Jannchie', 'Stars': '4.7k', 'URL': 'https://github.com//Jannchie/Historical-ranking-data-visualization-based-on-d3.js'}
# {'Repository Name': 'sqlpad', 'User Name': 'sqlpad', 'Stars': '4.5k', 'URL': 'https://github.com//sqlpad/sqlpad'}
# {'Repository Name': 'davinci', 'User Name': 'edp963', 'Stars': '4.4k', 'URL': 'https://github.com//edp963/davinci'}
# {'Repository Name': 'iDataV', 'User Name': 'yyhsong', 'Stars': '4.3k', 'URL': 'https://github.com//yyhsong/iDataV'}
# {'Repository Name': 'britecharts', 'User Name': 'britecharts', 'Stars': '3.7k', 'URL': 'https://github.com//britecharts/britecharts'}
# {'Repository Name': 'orange3', 'User Name': 'biolab', 'Stars': '3.6k', 'URL': 'https://github.com//biolab/orange3'}
# {'Repository Name': 'dtale', 'User Name': 'man-group', 'Stars': '3.6k', 'URL': 'https://github.com//man-group/dtale'}
# {'Repository Name': 'datascience', 'User Name': 'r0f1', 'Stars': '3.4k', 'URL': 'https://github.com//r0f1/datascience'}
# {'Repository Name': 'missingno', 'User Name': 'ResidentMario', 'Stars': '3.3k', 'URL': 'https://github.com//ResidentMario/missingno'}
# {'Repository Name': 'awesome-dataviz', 'User Name': 'javierluraschi', 'Stars': '3.1k', 'URL': 'https://github.com//javierluraschi/awesome-dataviz'}
# {'Repository Name': 'tablesaw', 'User Name': 'jtablesaw', 'Stars': '3k', 'URL': 'https://github.com//jtablesaw/tablesaw'}
# {'Repository Name': 'machine_learning_complete', 'User Name': 'Nyandwi', 'Stars': '2.9k', 'URL': 'https://github.com//Nyandwi/machine_learning_complete'}
# {'Repository Name': 'CBoard', 'User Name': 'TuiQiao', 'Stars': '2.9k', 'URL': 'https://github.com//TuiQiao/CBoard'}
# {'Repository Name': '3d-force-graph', 'User Name': 'vasturiano', 'Stars': '2.8k', 'URL': 'https://github.com//vasturiano/3d-force-graph'}
# {'Repository Name': 'matplotlib-cheatsheet', 'User Name': 'rougier', 'Stars': '2.8k', 'URL': 'https://github.com//rougier/matplotlib-cheatsheet'}
# {'Repository Name': 'awesome-jupyter', 'User Name': 'markusschanta', 'Stars': '2.8k', 'URL': 'https://github.com//markusschanta/awesome-jupyter'}
# {'Repository Name': 'datav', 'User Name': 'sunface', 'Stars': '2.8k', 'URL': 'https://github.com//sunface/datav'}
# {'Repository Name': 'matplotplusplus', 'User Name': 'alandefreitas', 'Stars': '2.8k', 'URL': 'https://github.com//alandefreitas/matplotplusplus'}
# {'Repository Name': 'L7', 'User Name': 'antvis', 'Stars': '2.7k', 'URL': 'https://github.com//antvis/L7'}
# {'Repository Name': 'Data-science', 'User Name': 'khuyentran1401', 'Stars': '2.7k', 'URL': 'https://github.com//khuyentran1401/Data-science'}
# {'Repository Name': 'inmap', 'User Name': 'TalkingData', 'Stars': '2.7k', 'URL': 'https://github.com//TalkingData/inmap'}
# {'Repository Name': 'ml-workspace', 'User Name': 'ml-tooling', 'Stars': '2.7k', 'URL': 'https://github.com//ml-tooling/ml-workspace'}
# {'Repository Name': 'aim', 'User Name': 'aimhubio', 'Stars': '2.6k', 'URL': 'https://github.com//aimhubio/aim'}
# {'Repository Name': 'react-trend', 'User Name': 'unsplash', 'Stars': '2.5k', 'URL': 'https://github.com//unsplash/react-trend'}
# {'Repository Name': 'datastation', 'User Name': 'multiprocessio', 'Stars': '2.4k', 'URL': 'https://github.com//multiprocessio/datastation'}
# {'Repository Name': 'electricitymap-contrib', 'User Name': 'electricitymap', 'Stars': '2.4k', 'URL': 'https://github.com//electricitymap/electricitymap-contrib'}
# {'Repository Name': 'ScottPlot', 'User Name': 'ScottPlot', 'Stars': '2.4k', 'URL': 'https://github.com//ScottPlot/ScottPlot'}
# {'Repository Name': 'semiotic', 'User Name': 'nteract', 'Stars': '2.3k', 'URL': 'https://github.com//nteract/semiotic'}
# {'Repository Name': 'plotly.R', 'User Name': 'plotly', 'Stars': '2.2k', 'URL': 'https://github.com//plotly/plotly.R'}
# {'Repository Name': 'hedgehog-lab', 'User Name': 'Hedgehog-Computing', 'Stars': '2.2k', 'URL': 'https://github.com//Hedgehog-Computing/hedgehog-lab'}
# {'Repository Name': 'awesome-single-cell', 'User Name': 'seandavi', 'Stars': '2.1k', 'URL': 'https://github.com//seandavi/awesome-single-cell'}
# {'Repository Name': 'AAChartKit-Swift', 'User Name': 'AAChartModel', 'Stars': '2.1k', 'URL': 'https://github.com//AAChartModel/AAChartKit-Swift'}
# {'Repository Name': 'sweetviz', 'User Name': 'fbdesignpro', 'Stars': '2.1k', 'URL': 'https://github.com//fbdesignpro/sweetviz'}
# {'Repository Name': 'vectorbt', 'User Name': 'polakowo', 'Stars': '2.1k', 'URL': 'https://github.com//polakowo/vectorbt'}
# {'Repository Name': 'luma.gl', 'User Name': 'visgl', 'Stars': '2k', 'URL': 'https://github.com//visgl/luma.gl'}
# {'Repository Name': 'victory-native', 'User Name': 'FormidableLabs', 'Stars': '2k', 'URL': 'https://github.com//FormidableLabs/victory-native'}
# {'Repository Name': 'calendar-heatmap', 'User Name': 'DKirwan', 'Stars': '2k', 'URL': 'https://github.com//DKirwan/calendar-heatmap'}
# {'Repository Name': 'plot', 'User Name': 'observablehq', 'Stars': '2k', 'URL': 'https://github.com//observablehq/plot'}
# {'Repository Name': 'running_page', 'User Name': 'yihong0618', 'Stars': '2k', 'URL': 'https://github.com//yihong0618/running_page'}
# {'Repository Name': 'XCharts', 'User Name': 'XCharts-Team', 'Stars': '2k', 'URL': 'https://github.com//XCharts-Team/XCharts'}
# {'Repository Name': 'AnyChart-Android', 'User Name': 'AnyChart', 'Stars': '1.9k', 'URL': 'https://github.com//AnyChart/AnyChart-Android'}
# {'Repository Name': 'poli', 'User Name': 'shzlw', 'Stars': '1.9k', 'URL': 'https://github.com//shzlw/poli'}
# {'Repository Name': 'LiveCharts2', 'User Name': 'beto-rodriguez', 'Stars': '1.9k', 'URL': 'https://github.com//beto-rodriguez/LiveCharts2'}
# {'Repository Name': 'pbpython', 'User Name': 'chris1610', 'Stars': '1.8k', 'URL': 'https://github.com//chris1610/pbpython'}
# {'Repository Name': 'radzen-blazor', 'User Name': 'radzenhq', 'Stars': '1.8k', 'URL': 'https://github.com//radzenhq/radzen-blazor'}
# {'Repository Name': 'gganimate', 'User Name': 'thomasp85', 'Stars': '1.8k', 'URL': 'https://github.com//thomasp85/gganimate'}
# {'Repository Name': 'mercury', 'User Name': 'mljar', 'Stars': '1.8k', 'URL': 'https://github.com//mljar/mercury'}
# {'Repository Name': 'Linear-Algebra-With-Python', 'User Name': 'weijie-chen', 'Stars': '1.7k', 'URL': 'https://github.com//weijie-chen/Linear-Algebra-With-Python'}
# {'Repository Name': 'hypertools', 'User Name': 'ContextLab', 'Stars': '1.7k', 'URL': 'https://github.com//ContextLab/hypertools'}
# {'Repository Name': 'tabix', 'User Name': 'tabixio', 'Stars': '1.7k', 'URL': 'https://github.com//tabixio/tabix'}
# {'Repository Name': 'wesanderson', 'User Name': 'karthik', 'Stars': '1.6k', 'URL': 'https://github.com//karthik/wesanderson'}
# {'Repository Name': 'awesome-business-intelligence', 'User Name': 'thenaturalist', 'Stars': '1.6k', 'URL': 'https://github.com//thenaturalist/awesome-business-intelligence'}
# {'Repository Name': 'vizzu-lib', 'User Name': 'vizzuhq', 'Stars': '1.6k', 'URL': 'https://github.com//vizzuhq/vizzu-lib'}
# {'Repository Name': 'ervy', 'User Name': 'chunqiuyiyu', 'Stars': '1.5k', 'URL': 'https://github.com//chunqiuyiyu/ervy'}
# {'Repository Name': 'DAT8', 'User Name': 'justmarkham', 'Stars': '1.5k', 'URL': 'https://github.com//justmarkham/DAT8'}
# {'Repository Name': 'just-dashboard', 'User Name': 'kantord', 'Stars': '1.5k', 'URL': 'https://github.com//kantord/just-dashboard'}
# {'Repository Name': 'esquisse', 'User Name': 'dreamRs', 'Stars': '1.5k', 'URL': 'https://github.com//dreamRs/esquisse'}
# {'Repository Name': 'rough-charts', 'User Name': 'beizhedenglong', 'Stars': '1.5k', 'URL': 'https://github.com//beizhedenglong/rough-charts'}
# {'Repository Name': 'awesome-python-data-science', 'User Name': 'krzjoa', 'Stars': '1.4k', 'URL': 'https://github.com//krzjoa/awesome-python-data-science'}
# {'Repository Name': 'tsne-cuda', 'User Name': 'CannyLab', 'Stars': '1.4k', 'URL': 'https://github.com//CannyLab/tsne-cuda'}
# {'Repository Name': 'JSCity', 'User Name': 'aserg-ufmg', 'Stars': '1.4k', 'URL': 'https://github.com//aserg-ufmg/JSCity'}
# {'Repository Name': 'jvectormap', 'User Name': 'bjornd', 'Stars': '1.3k', 'URL': 'https://github.com//bjornd/jvectormap'}
# {'Repository Name': 'helix-toolkit', 'User Name': 'helix-toolkit', 'Stars': '1.3k', 'URL': 'https://github.com//helix-toolkit/helix-toolkit'}
# {'Repository Name': 'php-spx', 'User Name': 'NoiseByNorthwest', 'Stars': '1.3k', 'URL': 'https://github.com//NoiseByNorthwest/php-spx'}
# {'Repository Name': 'lightdash', 'User Name': 'lightdash', 'Stars': '1.3k', 'URL': 'https://github.com//lightdash/lightdash'}
# {'Repository Name': 'Dex', 'User Name': 'PatMartin', 'Stars': '1.3k', 'URL': 'https://github.com//PatMartin/Dex'}
# {'Repository Name': 'go-recipes', 'User Name': 'nikolaydubina', 'Stars': '1.2k', 'URL': 'https://github.com//nikolaydubina/go-recipes'}
# {'Repository Name': 'vue-data-board', 'User Name': 'dongsuo', 'Stars': '1.2k', 'URL': 'https://github.com//dongsuo/vue-data-board'}
# {'Repository Name': 'muze', 'User Name': 'chartshq', 'Stars': '1.2k', 'URL': 'https://github.com//chartshq/muze'}
# {'Repository Name': 'chart', 'User Name': 'pavelkuligin', 'Stars': '1.1k', 'URL': 'https://github.com//pavelkuligin/chart'}
# {'Repository Name': 'neovis.js', 'User Name': 'neo4j-contrib', 'Stars': '1.1k', 'URL': 'https://github.com//neo4j-contrib/neovis.js'}
# {'Repository Name': 'data-forge-ts', 'User Name': 'data-forge', 'Stars': '1.1k', 'URL': 'https://github.com//data-forge/data-forge-ts'}
# {'Repository Name': 'AVA', 'User Name': 'antvis', 'Stars': '1.1k', 'URL': 'https://github.com//antvis/AVA'}
# {'Repository Name': 'moneymanagerex', 'User Name': 'moneymanagerex', 'Stars': '1.1k', 'URL': 'https://github.com//moneymanagerex/moneymanagerex'}
# {'Repository Name': 'vue-apexcharts', 'User Name': 'apexcharts', 'Stars': '1.1k', 'URL': 'https://github.com//apexcharts/vue-apexcharts'}
# {'Repository Name': 'data-science-on-gcp', 'User Name': 'GoogleCloudPlatform', 'Stars': '1.1k', 'URL': 'https://github.com//GoogleCloudPlatform/data-science-on-gcp'}
# {'Repository Name': 'amcharts4', 'User Name': 'amcharts', 'Stars': '1.1k', 'URL': 'https://github.com//amcharts/amcharts4'}
# {'Repository Name': 'globe.gl', 'User Name': 'vasturiano', 'Stars': '1.1k', 'URL': 'https://github.com//vasturiano/globe.gl'}
# {'Repository Name': 'owid-grapher', 'User Name': 'owid', 'Stars': '1.1k', 'URL': 'https://github.com//owid/owid-grapher'}
# {'Repository Name': 'graphvite', 'User Name': 'DeepGraphLearning', 'Stars': '1.1k', 'URL': 'https://github.com//DeepGraphLearning/graphvite'}
# {'Repository Name': 'hrbrthemes', 'User Name': 'hrbrmstr', 'Stars': '1k', 'URL': 'https://github.com//hrbrmstr/hrbrthemes'}
# {'Repository Name': 'awesome-clojurescript', 'User Name': 'hantuzun', 'Stars': '944', 'URL': 'https://github.com//hantuzun/awesome-clojurescript'}
# {'Repository Name': 'troika', 'User Name': 'protectwise', 'Stars': '908', 'URL': 'https://github.com//protectwise/troika'}
# {'Repository Name': 'jsxgraph', 'User Name': 'jsxgraph', 'Stars': '896', 'URL': 'https://github.com//jsxgraph/jsxgraph'}
# {'Repository Name': 'jfreechart', 'User Name': 'jfree', 'Stars': '869', 'URL': 'https://github.com//jfree/jfreechart'}
# {'Repository Name': 'monorepo', 'User Name': 'mito-ds', 'Stars': '868', 'URL': 'https://github.com//mito-ds/monorepo'}
# {'Repository Name': 'react-plotly.js', 'User Name': 'plotly', 'Stars': '842', 'URL': 'https://github.com//plotly/react-plotly.js'}
# {'Repository Name': 'datart', 'User Name': 'running-elephant', 'Stars': '835', 'URL': 'https://github.com//running-elephant/datart'}
# {'Repository Name': 'anichart.js', 'User Name': 'Jannchie', 'Stars': '819', 'URL': 'https://github.com//Jannchie/anichart.js'}
# {'Repository Name': 'd4', 'User Name': 'joelburget', 'Stars': '810', 'URL': 'https://github.com//joelburget/d4'}
# {'Repository Name': 'cookbook-2nd', 'User Name': 'ipython-books', 'Stars': '806', 'URL': 'https://github.com//ipython-books/cookbook-2nd'}
# {'Repository Name': 'ggthemr', 'User Name': 'Mikata-Project', 'Stars': '797', 'URL': 'https://github.com//Mikata-Project/ggthemr'}
# {'Repository Name': 'streetscape.gl', 'User Name': 'aurora-opensource', 'Stars': '795', 'URL': 'https://github.com//aurora-opensource/streetscape.gl'}
# {'Repository Name': 'qs_ledger', 'User Name': 'markwk', 'Stars': '790', 'URL': 'https://github.com//markwk/qs_ledger'}
# {'Repository Name': 'lets-plot', 'User Name': 'JetBrains', 'Stars': '777', 'URL': 'https://github.com//JetBrains/lets-plot'}
# {'Repository Name': 'crayon', 'User Name': 'torrvision', 'Stars': '780', 'URL': 'https://github.com//torrvision/crayon'}
# {'Repository Name': 'Teaching', 'User Name': 'DrWaleedAYousef', 'Stars': '753', 'URL': 'https://github.com//DrWaleedAYousef/Teaching'}
# {'Repository Name': 'chartbrew', 'User Name': 'chartbrew', 'Stars': '742', 'URL': 'https://github.com//chartbrew/chartbrew'}
# {'Repository Name': 'explorer', 'User Name': 'keen', 'Stars': '738', 'URL': 'https://github.com//keen/explorer'}
# {'Repository Name': 'ChartFun', 'User Name': 'ddiu8081', 'Stars': '731', 'URL': 'https://github.com//ddiu8081/ChartFun'}
# {'Repository Name': 'party-mode', 'User Name': 'preziotte', 'Stars': '726', 'URL': 'https://github.com//preziotte/party-mode'}
# {'Repository Name': 'proplot', 'User Name': 'proplot-dev', 'Stars': '724', 'URL': 'https://github.com//proplot-dev/proplot'}
# {'Repository Name': 'graphic', 'User Name': 'entronad', 'Stars': '723', 'URL': 'https://github.com//entronad/graphic'}
# {'Repository Name': 'evidence', 'User Name': 'evidence-dev', 'Stars': '722', 'URL': 'https://github.com//evidence-dev/evidence'}
# {'Repository Name': 'MetBrewer', 'User Name': 'BlakeRMills', 'Stars': '712', 'URL': 'https://github.com//BlakeRMills/MetBrewer'}
# {'Repository Name': 'waffle', 'User Name': 'hrbrmstr', 'Stars': '702', 'URL': 'https://github.com//hrbrmstr/waffle'}
# {'Repository Name': 'leaflet-dvf', 'User Name': 'humangeo', 'Stars': '687', 'URL': 'https://github.com//humangeo/leaflet-dvf'}
# {'Repository Name': 'three-globe', 'User Name': 'vasturiano', 'Stars': '686', 'URL': 'https://github.com//vasturiano/three-globe'}
# {'Repository Name': 'engsoccerdata', 'User Name': 'jalapic', 'Stars': '685', 'URL': 'https://github.com//jalapic/engsoccerdata'}
# {'Repository Name': 'AAChartCore', 'User Name': 'AAChartModel', 'Stars': '672', 'URL': 'https://github.com//AAChartModel/AAChartCore'}
# {'Repository Name': 'plotly_express', 'User Name': 'plotly', 'Stars': '671', 'URL': 'https://github.com//plotly/plotly_express'}
# {'Repository Name': 'reaviz', 'User Name': 'reaviz', 'Stars': '668', 'URL': 'https://github.com//reaviz/reaviz'}
# {'Repository Name': 'awesome-ggplot2', 'User Name': 'erikgahner', 'Stars': '655', 'URL': 'https://github.com//erikgahner/awesome-ggplot2'}
# {'Repository Name': 'visdown', 'User Name': 'amitkaps', 'Stars': '656', 'URL': 'https://github.com//amitkaps/visdown'}
# {'Repository Name': 'gramm', 'User Name': 'piermorel', 'Stars': '647', 'URL': 'https://github.com//piermorel/gramm'}
# {'Repository Name': 'd3-node', 'User Name': 'd3-node', 'Stars': '645', 'URL': 'https://github.com//d3-node/d3-node'}
# {'Repository Name': 'see', 'User Name': 'easystats', 'Stars': '645', 'URL': 'https://github.com//easystats/see'}
# {'Repository Name': 'Csharp-Data-Visualization', 'User Name': 'swharden', 'Stars': '642', 'URL': 'https://github.com//swharden/Csharp-Data-Visualization'}
# {'Repository Name': 'datagear', 'User Name': 'datageartech', 'Stars': '639', 'URL': 'https://github.com//datageartech/datagear'}
# {'Repository Name': 'cookbook-2nd-code', 'User Name': 'ipython-books', 'Stars': '638', 'URL': 'https://github.com//ipython-books/cookbook-2nd-code'}
# {'Repository Name': 'abixen-platform', 'User Name': 'abixen', 'Stars': '644', 'URL': 'https://github.com//abixen/abixen-platform'}
# {'Repository Name': 'ModernDive_book', 'User Name': 'moderndive', 'Stars': '630', 'URL': 'https://github.com//moderndive/ModernDive_book'}
# {'Repository Name': 'antd-umi-sys', 'User Name': 'mpw0311', 'Stars': '623', 'URL': 'https://github.com//mpw0311/antd-umi-sys'}
# {'Repository Name': 'data-science-with-ruby', 'User Name': 'arbox', 'Stars': '608', 'URL': 'https://github.com//arbox/data-science-with-ruby'}
# {'Repository Name': 'turnilo', 'User Name': 'allegro', 'Stars': '617', 'URL': 'https://github.com//allegro/turnilo'}
# {'Repository Name': 'datapane', 'User Name': 'datapane', 'Stars': '600', 'URL': 'https://github.com//datapane/datapane'}
# {'Repository Name': 'flutter_echarts', 'User Name': 'entronad', 'Stars': '588', 'URL': 'https://github.com//entronad/flutter_echarts'}
# {'Repository Name': 'worldview', 'User Name': 'nasa-gibs', 'Stars': '588', 'URL': 'https://github.com//nasa-gibs/worldview'}
# {'Repository Name': 'keen-js', 'User Name': 'keen', 'Stars': '583', 'URL': 'https://github.com//keen/keen-js'}
# {'Repository Name': 'centreon', 'User Name': 'centreon', 'Stars': '561', 'URL': 'https://github.com//centreon/centreon'}
# {'Repository Name': 'kepler-mapper', 'User Name': 'scikit-tda', 'Stars': '568', 'URL': 'https://github.com//scikit-tda/kepler-mapper'}
# {'Repository Name': 'plotly', 'User Name': 'igiagkiozis', 'Stars': '556', 'URL': 'https://github.com//igiagkiozis/plotly'}
# {'Repository Name': 'Tutorials', 'User Name': 'TannerGilbert', 'Stars': '555', 'URL': 'https://github.com//TannerGilbert/Tutorials'}
# {'Repository Name': 'sjPlot', 'User Name': 'strengejacke', 'Stars': '541', 'URL': 'https://github.com//strengejacke/sjPlot'}
# {'Repository Name': 'facebook_data_analyzer', 'User Name': 'Lackoftactics', 'Stars': '532', 'URL': 'https://github.com//Lackoftactics/facebook_data_analyzer'}
# {'Repository Name': 'Courses-', 'User Name': 'salimt', 'Stars': '545', 'URL': 'https://github.com//salimt/Courses-'}
# {'Repository Name': 'rweekly.org', 'User Name': 'rweekly', 'Stars': '525', 'URL': 'https://github.com//rweekly/rweekly.org'}
# {'Repository Name': 'retentioneering-tools', 'User Name': 'retentioneering', 'Stars': '521', 'URL': 'https://github.com//retentioneering/retentioneering-tools'}
# {'Repository Name': 'OpenSpace', 'User Name': 'OpenSpace', 'Stars': '502', 'URL': 'https://github.com//OpenSpace/OpenSpace'}
# {'Repository Name': 'Book-SocialMediaMiningPython', 'User Name': 'bonzanini', 'Stars': '500', 'URL': 'https://github.com//bonzanini/Book-SocialMediaMiningPython'}
# {'Repository Name': 'PyWaffle', 'User Name': 'gyli', 'Stars': '499', 'URL': 'https://github.com//gyli/PyWaffle'}
# {'Repository Name': 'reactochart', 'User Name': 'spotify', 'Stars': '498', 'URL': 'https://github.com//spotify/reactochart'}
# {'Repository Name': 'elm-visualization', 'User Name': 'gampleman', 'Stars': '497', 'URL': 'https://github.com//gampleman/elm-visualization'}
# {'Repository Name': 'ggsci', 'User Name': 'nanxstats', 'Stars': '497', 'URL': 'https://github.com//nanxstats/ggsci'}
# {'Repository Name': 'BAP', 'User Name': 'aloctavodia', 'Stars': '487', 'URL': 'https://github.com//aloctavodia/BAP'}
# {'Repository Name': 'chart-race-react', 'User Name': 'bchao1', 'Stars': '492', 'URL': 'https://github.com//bchao1/chart-race-react'}
# {'Repository Name': 'plotly-resampler', 'User Name': 'predict-idlab', 'Stars': '467', 'URL': 'https://github.com//predict-idlab/plotly-resampler'}
# {'Repository Name': 'articles', 'User Name': 'LearnDataSci', 'Stars': '466', 'URL': 'https://github.com//LearnDataSci/articles'}
# {'Repository Name': 'ipyvizzu', 'User Name': 'vizzuhq', 'Stars': '463', 'URL': 'https://github.com//vizzuhq/ipyvizzu'}
# {'Repository Name': 'kedro-viz', 'User Name': 'kedro-org', 'Stars': '462', 'URL': 'https://github.com//kedro-org/kedro-viz'}
# {'Repository Name': 'report-designer', 'User Name': 'xinglie', 'Stars': '461', 'URL': 'https://github.com//xinglie/report-designer'}
# {'Repository Name': 'augur', 'User Name': 'chaoss', 'Stars': '455', 'URL': 'https://github.com//chaoss/augur'}
# {'Repository Name': 'Treeverse', 'User Name': 'paulgb', 'Stars': '460', 'URL': 'https://github.com//paulgb/Treeverse'}
# {'Repository Name': 'traceml', 'User Name': 'polyaxon', 'Stars': '447', 'URL': 'https://github.com//polyaxon/traceml'}
# {'Repository Name': 'pix-plot', 'User Name': 'YaleDHLab', 'Stars': '447', 'URL': 'https://github.com//YaleDHLab/pix-plot'}
# {'Repository Name': 'chaos_genius', 'User Name': 'chaos-genius', 'Stars': '442', 'URL': 'https://github.com//chaos-genius/chaos_genius'}
# {'Repository Name': 'py_d3', 'User Name': 'ResidentMario', 'Stars': '443', 'URL': 'https://github.com//ResidentMario/py_d3'}
# {'Repository Name': 'joypy', 'User Name': 'leotac', 'Stars': '434', 'URL': 'https://github.com//leotac/joypy'}
# {'Repository Name': 'cubesviewer', 'User Name': 'jjmontesl', 'Stars': '430', 'URL': 'https://github.com//jjmontesl/cubesviewer'}
# {'Repository Name': 'percival', 'User Name': 'ekzhang', 'Stars': '426', 'URL': 'https://github.com//ekzhang/percival'}
# {'Repository Name': 'datatile', 'User Name': 'polyaxon', 'Stars': '425', 'URL': 'https://github.com//polyaxon/datatile'}
# {'Repository Name': 'dash-table', 'User Name': 'plotly', 'Stars': '425', 'URL': 'https://github.com//plotly/dash-table'}
# {'Repository Name': 'datav-vue', 'User Name': 'pengxiaotian', 'Stars': '421', 'URL': 'https://github.com//pengxiaotian/datav-vue'}
# {'Repository Name': 'plotlydash-flask-tutorial', 'User Name': 'toddbirchard', 'Stars': '411', 'URL': 'https://github.com//toddbirchard/plotlydash-flask-tutorial'}
# {'Repository Name': 'Dash.jl', 'User Name': 'plotly', 'Stars': '403', 'URL': 'https://github.com//plotly/Dash.jl'}

# %%
import pandas as pd

# %%
df = pd.DataFrame(all_article_lst)

# %%
df[:200]
# Out:
#      Repository Name  User Name  Stars  \
# 0                 d3         d3   102k
# 1            echarts     apache  51.9k
# 2            grafana    grafana  50.2k
# 3           superset     apache  47.3k
# 4             pixijs     pixijs    37k
# ..               ...        ...    ...
# 195  report-designer    xinglie    461
# 196            augur     chaoss    455
# 197        Treeverse     paulgb    460
# 198          traceml   polyaxon    447
# 199         pix-plot  YaleDHLab    447
#
#                                              URL
# 0                      https://github.com//d3/d3
# 1             https://github.com//apache/echarts
# 2            https://github.com//grafana/grafana
# 3            https://github.com//apache/superset
# 4              https://github.com//pixijs/pixijs
# ..                                           ...
# 195  https://github.com//xinglie/report-designer
# 196             https://github.com//chaoss/augur
# 197         https://github.com//paulgb/Treeverse
# 198         https://github.com//polyaxon/traceml
# 199       https://github.com//YaleDHLab/pix-plot
#
# [200 rows x 4 columns]

# %%
df[:200].to_excel('All-data-visualization200-Data.xlsx')
