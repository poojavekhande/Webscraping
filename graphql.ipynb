"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="cf270d56eb4a191958037dd7bdcaded0186e2e2a22c41e9697357a0a1666b62e" data-view-component="true" href="/topics/api-gateway" title="Topic: api-gateway">
#               api-gateway
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":17600,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="f8080ad1410a78a87bbba8cf1cf4e7793ceb5c4da0939616a5e1762399f87b73" data-view-component="true" href="/topics/static" title="Topic: static">
#               static
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":248856,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="2e477edbc0673c86e47a399d222483b9343b05273e93f59ad1a3e2415e6433d6" data-view-component="true" href="/topics/up" title="Topic: up">
#               up
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":324809,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="e5880590e841d0b749bf41d3a3ad7241a34dcf80a80813c54ea4c256ee36e38e" data-view-component="true" href="/topics/deploy-tool" title="Topic: deploy-tool">
#               deploy-tool
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":328460,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="6c05713b8b15ce9c3f6eba077aebb3fcfbd655e23676f6e61f44591443e2039d" data-view-component="true" href="/topics/aws-infrastructure" title="Topic: aws-infrastructure">
#               aws-infrastructure
# </a> </div>
# <div class="p-3">
# <ul class="d-flex f6 list-style-none color-fg-muted">
# <li class="mr-4">
#               Updated
#               <relative-time class="no-wrap" datetime="2022-06-27T03:46:17Z">Jun 27, 2022</relative-time>
# </li>
# <li class="mr-4">
# <span class="f6 my-1 ml-0">
# <span class="repo-language-color" style="background-color: #00ADD8"></span>
# <span itemprop="programmingLanguage">Go</span>
# </span>
# </li>
# </ul>
# </div>
# </div>
# </article>
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="https://github.com/topics/graphql" class="ajax-pagination-form js-ajax-pagination" data-turbo="false" method="get">
# <input name="page" type="hidden" value="2"/>
# <button class="ajax-pagination-btn btn btn-outline color-border-default f6 mt-0 width-full" data-disable-with="Loading more…" type="submit">
#       Load more…
#     </button>
# </form>
# </div>
# <div class="col-md-4 col-lg-3">
# <p class="mb-1">
# <span class="color-fg-muted">Created by</span> Facebook
#     </p>
# <p class="mb-1">
# <span class="color-fg-muted">Released</span> 2015
#     </p>
# <dl class="my-4">
# <dt class="d-none">
#         Organization
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-organization color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.5 14.25c0 .138.112.25.25.25H4v-1.25a.75.75 0 01.75-.75h2.5a.75.75 0 01.75.75v1.25h2.25a.25.25 0 00.25-.25V1.75a.25.25 0 00-.25-.25h-8.5a.25.25 0 00-.25.25v12.5zM1.75 16A1.75 1.75 0 010 14.25V1.75C0 .784.784 0 1.75 0h8.5C11.216 0 12 .784 12 1.75v12.5c0 .085-.006.168-.018.25h2.268a.25.25 0 00.25-.25V8.285a.25.25 0 00-.111-.208l-1.055-.703a.75.75 0 11.832-1.248l1.055.703c.487.325.779.871.779 1.456v5.965A1.75 1.75 0 0114.25 16h-3.5a.75.75 0 01-.197-.026c-.099.017-.2.026-.303.026h-3a.75.75 0 01-.75-.75V14h-1v1.25a.75.75 0 01-.75.75h-3zM3 3.75A.75.75 0 013.75 3h.5a.75.75 0 010 1.5h-.5A.75.75 0 013 3.75zM3.75 6a.75.75 0 000 1.5h.5a.75.75 0 000-1.5h-.5zM3 9.75A.75.75 0 013.75 9h.5a.75.75 0 010 1.5h-.5A.75.75 0 013 9.75zM7.75 9a.75.75 0 000 1.5h.5a.75.75 0 000-1.5h-.5zM7 6.75A.75.75 0 017.75 6h.5a.75.75 0 010 1.5h-.5A.75.75 0 017 6.75zM7.75 3a.75.75 0 000 1.5h.5a.75.75 0 000-1.5h-.5z" fill-rule="evenodd"></path>
# </svg>
# <a data-ga-click="Explore, go to graphql, location:topic page" href="https://github.com/graphql">
# <span class="css-truncate css-truncate-target" title="graphql">
#           graphql
#         </span>
# </a>
# </dd>
# <dt class="d-none">
#       Website
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-link color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M7.775 3.275a.75.75 0 001.06 1.06l1.25-1.25a2 2 0 112.83 2.83l-2.5 2.5a2 2 0 01-2.83 0 .75.75 0 00-1.06 1.06 3.5 3.5 0 004.95 0l2.5-2.5a3.5 3.5 0 00-4.95-4.95l-1.25 1.25zm-4.69 9.64a2 2 0 010-2.83l2.5-2.5a2 2 0 012.83 0 .75.75 0 001.06-1.06 3.5 3.5 0 00-4.95 0l-2.5 2.5a3.5 3.5 0 004.95 4.95l1.25-1.25a.75.75 0 00-1.06-1.06l-1.25 1.25a2 2 0 01-2.83 0z" fill-rule="evenodd"></path>
# </svg>
# <a data-ga-click="Explore, go to external url, location:topic page" href="http://graphql.org/">
# <span class="css-truncate css-truncate-target" title="graphql.org">
#           graphql.org
#         </span>
# </a>
# </dd>
# <dt class="d-none">
#       Wikipedia
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-link color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M7.775 3.275a.75.75 0 001.06 1.06l1.25-1.25a2 2 0 112.83 2.83l-2.5 2.5a2 2 0 01-2.83 0 .75.75 0 00-1.06 1.06 3.5 3.5 0 004.95 0l2.5-2.5a3.5 3.5 0 00-4.95-4.95l-1.25 1.25zm-4.69 9.64a2 2 0 010-2.83l2.5-2.5a2 2 0 012.83 0 .75.75 0 001.06-1.06 3.5 3.5 0 00-4.95 0l-2.5 2.5a3.5 3.5 0 004.95 4.95l1.25-1.25a.75.75 0 00-1.06-1.06l-1.25 1.25a2 2 0 01-2.83 0z" fill-rule="evenodd"></path>
# </svg>
# <a data-ga-click="Explore, go to Wikipedia entry, location:topic page" href="https://en.wikipedia.org/wiki/GraphQL">
# <span class="css-truncate css-truncate-target" title="en.wikipedia.org/wiki/GraphQL">
#           Wikipedia
#         </span>
# </a>
# </dd>
# </dl>
# <h2 class="h4 mb-2">
#     Related Topics
#   </h2>
# <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Explore, go to topic, location:star topics callout;text:api" data-view-component="true" href="/topics/api" title="Topic: api">
#   api
# </a>
# <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Explore, go to topic, location:star topics callout;text:rest" data-view-component="true" href="/topics/rest" title="Topic: rest">
#   rest
# </a>
# </div>
# </div>
# </div>
# </div>
# </main>
# </div>
# <footer class="footer width-full container-lg p-responsive">
# <h2 class="sr-only">Footer</h2>
# <div class="position-relative d-flex flex-items-center pb-2 f6 color-fg-muted border-top color-border-muted flex-column-reverse flex-lg-row flex-wrap flex-lg-nowrap mt-6 pt-6">
# <div class="list-style-none d-flex flex-wrap col-0 col-lg-2 flex-justify-start flex-lg-justify-between mb-2 mb-lg-0">
# <div class="mt-2 mt-lg-0 d-flex flex-items-center">
# <a aria-label="Homepage" class="footer-octicon mr-2" href="https://github.com" title="GitHub">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
# </svg>
# </a> <span>
#         © 2022 GitHub, Inc.
#         </span>
# </div>
# </div>
# <nav aria-label="footer" class="col-12 col-lg-8">
# <h3 class="sr-only" id="sr-footer-heading">Footer navigation</h3>
# <ul aria-labelledby="sr-footer-heading" class="list-style-none d-flex flex-wrap col-12 flex-justify-center flex-lg-justify-between mb-2 mb-lg-0">
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to terms","label":"text:terms"}' href="https://docs.github.com/en/github/site-policy/github-terms-of-service">Terms</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to privacy","label":"text:privacy"}' href="https://docs.github.com/en/github/site-policy/github-privacy-statement">Privacy</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to security","label":"text:security"}' href="https://github.com/security">Security</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to status","label":"text:status"}' href="https://www.githubstatus.com/">Status</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to help, text:Docs" href="https://docs.github.com">Docs</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to contact","label":"text:contact"}' href="https://support.github.com?tags=dotcom-footer">Contact GitHub</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to Pricing","label":"text:Pricing"}' href="https://github.com/pricing">Pricing</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to api","label":"text:api"}' href="https://docs.github.com">API</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to training","label":"text:training"}' href="https://services.github.com">Training</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to blog","label":"text:blog"}' href="https://github.blog">Blog</a></li>
# <li><a data-ga-click="Footer, go to about, text:about" href="https://github.com/about">About</a></li>
# </ul>
# </nav>
# </div>
# <div class="d-flex flex-justify-center pb-6">
# <span class="f6 color-fg-muted"></span>
# </div>
# </footer>
# <div class="ajax-error-message flash flash-error" hidden="" id="ajax-error-message">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <button aria-label="Dismiss error" class="flash-close js-ajax-error-dismiss" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button>
#     You can’t perform that action at this time.
#   </div>
# <div class="js-stale-session-flash flash flash-warn flash-banner" hidden="">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <span class="js-stale-session-flash-signed-in" hidden="">You signed in with another tab or window. <a href="">Reload</a> to refresh your session.</span>
# <span class="js-stale-session-flash-signed-out" hidden="">You signed out in another tab or window. <a href="">Reload</a> to refresh your session.</span>
# </div>
# <template id="site-details-dialog">
# <details class="details-reset details-overlay details-overlay-dark lh-default color-fg-default hx_rsm" open="">
# <summary aria-label="Close dialog" role="button"></summary>
# <details-dialog class="Box Box--overlay d-flex flex-column anim-fade-in fast hx_rsm-dialog hx_rsm-modal">
# <button aria-label="Close dialog" class="Box-btn-octicon m-0 btn-octicon position-absolute right-0 top-0" data-close-dialog="" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button>
# <div class="octocat-spinner my-6 js-details-dialog-spinner"></div>
# </details-dialog>
# </details>
# </template>
# <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;" tabindex="0">
# <div class="Popover-message Popover-message--bottom-left Popover-message--large Box color-shadow-large" style="width:360px;">
# </div>
# </div>
# <template id="snippet-clipboard-copy-button">
# <div class="zeroclipboard-container position-absolute right-0 top-0">
# <clipboard-copy aria-label="Copy" class="ClipboardButton btn js-clipboard-copy m-2 p-0 tooltipped-no-delay" data-copy-feedback="Copied!" data-tooltip-direction="w">
# <svg aria-hidden="true" class="octicon octicon-copy js-clipboard-copy-icon m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M0 6.75C0 5.784.784 5 1.75 5h1.5a.75.75 0 010 1.5h-1.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-1.5a.75.75 0 011.5 0v1.5A1.75 1.75 0 019.25 16h-7.5A1.75 1.75 0 010 14.25v-7.5z" fill-rule="evenodd"></path><path d="M5 1.75C5 .784 5.784 0 6.75 0h7.5C15.216 0 16 .784 16 1.75v7.5A1.75 1.75 0 0114.25 11h-7.5A1.75 1.75 0 015 9.25v-7.5zm1.75-.25a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25h-7.5z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-hidden="true" class="octicon octicon-check js-clipboard-check-icon color-fg-success d-none m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M13.78 4.22a.75.75 0 010 1.06l-7.25 7.25a.75.75 0 01-1.06 0L2.22 9.28a.75.75 0 011.06-1.06L6 10.94l6.72-6.72a.75.75 0 011.06 0z" fill-rule="evenodd"></path>
# </svg>
# </clipboard-copy>
# </div>
# </template>
# </body>
# </html>

# %%
first_article = converted_data.find('article',class_='border rounded color-shadow-small color-bg-subtle my-4')

# %%
first_article
# Out:
# <article class="border rounded color-shadow-small color-bg-subtle my-4">
# <div class="px-3">
# <div class="d-flex flex-justify-between my-3">
# <div class="d-flex flex-auto">
# <span style="margin-top:2px">
# <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# </span>
# <h3 class="f3 color-fg-muted text-normal lh-condensed">
# <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":12551863,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="036a63fabb6c8bc665b0e0c283e366d294c7a84edd8c51ebc83db0daa89fa71c" data-turbo="false" data-view-component="true" href="/gatsbyjs">
#             gatsbyjs
# </a>          /
#           <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":36040894,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="08e597eecb21d5081004fd20c92b4b16e73d50ecd19da3c7324aac52128bb8db" data-turbo="false" data-view-component="true" href="/gatsbyjs/gatsby">
#             gatsby
# </a> </h3>
# </div>
# <div class="d-flex flex-items-center ml-3">
# <div class="BtnGroup d-flex" data-view-component="true">
# <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":36040894,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="727ea155594b050f89ce1fd3c9dad8460f9009c32480dcec35d1d2ed014084df" data-view-component="true" href="/login?return_to=%2Fgatsbyjs%2Fgatsby" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
# </svg><span class="d-inline" data-view-component="true">
#           Star
# </span> <span aria-label="53290 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="53,290">53.3k</span>
# </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
# </svg>
# </button></div>
# </div>
# </div>
# </div>
# <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
# <ul class="tabnav-tabs" data-view-component="true">
# <li class="d-inline-flex" data-view-component="true">
# <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":36040894,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="1de8aea943061b91997a3083ccf7a6a0a3d34e610fee6a11690f8f2e70e4e06e" data-turbo="false" data-view-component="true" href="/gatsbyjs/gatsby" id="code-tab-36040894">
# <svg aria-hidden="true" class="octicon octicon-code color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
# </svg> Code
#
#
# </a></li>
# <li class="d-inline-flex" data-view-component="true">
# <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":36040894,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="06b0a54ba7e3fd575ec4def7c4d94dac210d404ed822f578b06738ed2df72fab" data-turbo="false" data-view-component="true" href="/gatsbyjs/gatsby/issues" id="issues-tab-36040894">
# <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-dark" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
# </a></li>
# <li class="d-inline-flex" data-view-component="true">
# <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":36040894,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="d21d154ce8388907419fa052f1f72795e8efcc9a4e09ac02c428b4b85fa522e9" data-turbo="false" data-view-component="true" href="/gatsbyjs/gatsby/pulls" id="pull-requests-tab-36040894">
# <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
# </svg> Pull requests
#
#
# </a></li>
# <li class="d-inline-flex" data-view-component="true">
# <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository discussions, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_DISCUSSIONS","click_visual_representation":"DISCUSSIONS_TAB","actor_id":null,"record_id":36040894,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="8a48f507c693bfc96a12fec0732967121112a77f2a54bdc47ef2d2bdf909234f" data-turbo="false" data-view-component="true" href="/gatsbyjs/gatsby/discussions" id="discussions-tab-36040894">
# <svg aria-hidden="true" class="octicon octicon-comment-discussion color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.5 2.75a.25.25 0 01.25-.25h8.5a.25.25 0 01.25.25v5.5a.25.25 0 01-.25.25h-3.5a.75.75 0 00-.53.22L3.5 11.44V9.25a.75.75 0 00-.75-.75h-1a.25.25 0 01-.25-.25v-5.5zM1.75 1A1.75 1.75 0 000 2.75v5.5C0 9.216.784 10 1.75 10H2v1.543a1.457 1.457 0 002.487 1.03L7.061 10h3.189A1.75 1.75 0 0012 8.25v-5.5A1.75 1.75 0 0010.25 1h-8.5zM14.5 4.75a.25.25 0 00-.25-.25h-.5a.75.75 0 110-1.5h.5c.966 0 1.75.784 1.75 1.75v5.5A1.75 1.75 0 0114.25 12H14v1.543a1.457 1.457 0 01-2.487 1.03L9.22 12.28a.75.75 0 111.06-1.06l2.22 2.22v-2.19a.75.75 0 01.75-.75h1a.25.25 0 00.25-.25v-5.5z" fill-rule="evenodd"></path>
# </svg> Discussions
#
#
# </a></li>
# </ul>
# </nav>
# <div class="color-bg-default rounded-bottom-2">
# <article class="p-3">
# <div class="d-flex flex-justify-between mb-3">
# <div class="d-flex flex-items-center">
# <span class="State State--open State--small v-align-bottom mr-1" data-view-component="true" title="Status: open">
# <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
# </svg> Open
# </span>
# <h4 class="d-inline flex-auto f3 text-normal ml-1 wb-break-word">
# <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"BIG_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1261934222,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="b1834e83041c8c8dd43babe94560d7c07bce64d93ff5c30505412ff7b1f5dfa1" data-turbo="false" data-view-component="true" href="https://github.com/gatsbyjs/gatsby/issues/35853">
#                 GraphQL Typegen only picking up graphql tag usage from gatsby-node.ts
# </a> </h4>
# </div>
# <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
# <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
# </svg>
#               2
#             </div>
# </div>
# <div class="d-flex">
# <div class="mr-3">
# <img alt="openscript" class="avatar avatar-user avatar-small" height="32" src="https://avatars.githubusercontent.com/u/1105080?v=4" width="32"/>
# </div>
# <div class="flex-auto" style="width: 80%;">
# <div class="Box Box--condensed position-relative timeline-comment--caret">
# <div class="Box-header f6 color-fg-muted">
# <strong class="color-fg-default text-bold">
#                   openscript
#                 </strong>
#
#                   commented
#
#                 <relative-time class="no-wrap" datetime="2022-06-06T14:34:45Z">Jun 6, 2022</relative-time>
# </div>
# <div class="Box-body comment-body markdown-body position-relative overflow-hidden pt-3" style="max-height:200px">
# <h3>Preliminary Checks</h3>
# <ul class="contains-task-list">
# <li class="task-list-item"><input checked="" class="task-list-item-checkbox" disabled="" id="" type="checkbox"/> This issue is not a duplicate. Before opening a new issue, please search existing issues: <a href="https://github.com/gatsbyjs/gatsby/issues">https://github.com/gatsbyjs/gatsby/issues</a></li>
# <li class="task-list-item"><input checked="" class="task-list-item-checkbox" disabled="" id="" type="checkbox"/> This issue is not a question, feature request, RFC, or anything other than a bug report directly related to Gatsby. Please post those things in GitHub Discussions: <a href="https://github.com/gatsbyjs/gatsby/discussions">https://github.com/gatsbyjs/gatsby/discussions</a></li>
# </ul>
# <h3>Description</h3>
# <p>I'v</p>
# <div class="position-absolute right-0 left-0 bottom-0 text-center" style="background: linear-gradient(to top, var(--color-canvas-default), var(--color-canvas-default-transparent));">
# <a class="btn btn-outline btn-sm mx-auto my-3" data-ga-click="Explore, go to issue, location:good first issues;text:read more;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"READ_MORE","actor_id":null,"record_id":1261934222,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="ff443c3da42fcf0494bcad8e410a16b28941c592c08365fc7a70a44e8c4a6c5c" href="https://github.com/gatsbyjs/gatsby/issues/35853">
#                       Read more
# </a> </div>
# </div>
# </div>
# <div class="mt-3">
# <span class="discussion-item-icon border-white-fade ml-0 mr-2">
# <svg aria-hidden="true" class="octicon octicon-tag" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2.5 7.775V2.75a.25.25 0 01.25-.25h5.025a.25.25 0 01.177.073l6.25 6.25a.25.25 0 010 .354l-5.025 5.025a.25.25 0 01-.354 0l-6.25-6.25a.25.25 0 01-.073-.177zm-1.5 0V2.75C1 1.784 1.784 1 2.75 1h5.025c.464 0 .91.184 1.238.513l6.25 6.25a1.75 1.75 0 010 2.474l-5.026 5.026a1.75 1.75 0 01-2.474 0l-6.25-6.25A1.75 1.75 0 011 7.775zM6 5a1 1 0 100 2 1 1 0 000-2z" fill-rule="evenodd"></path>
# </svg>
# </span>
# <div class="wb-break-word">
# <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":214544672,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="69123cc3194626031cf8081cd853990e0b1ca4be0d733dd38ea25a5aead17502" data-name="type: bug" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22type%3A+bug%22" id="label-9fab05" style="--label-r:198;--label-g:76;--label-b:45;--label-h:12;--label-s:62;--label-l:47;">
#                     type: bug
# </a>
# <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-9fab05" hidden="hidden">An issue or pull request relating to a bug in Gatsby</tool-tip>
# <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":214544675,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="3bb92fa8f664db2f037fce8b9cf339732f171726f74cd87577b5d294681c8704" data-name="help wanted" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22help+wanted%22" id="label-797269" style="--label-r:14;--label-g:138;--label-b:22;--label-h:123;--label-s:81;--label-l:29;">
#                     help wanted
# </a>
# <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-797269" hidden="hidden">Issue with a clear description that the community can help with.</tool-tip>
# <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":734600061,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="a05d007911ec9e430c8343bfb798356fa68f545f0eca41650c25d397ef8039e5" data-name="good first issue" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22good+first+issue%22" id="label-0d8ce2" style="--label-r:252;--label-g:191;--label-b:227;--label-h:324;--label-s:91;--label-l:86;">
#                     good first issue
# </a>
# <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-0d8ce2" hidden="hidden">Issue that doesn't require previous experience with Gatsby</tool-tip>
# <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":1038048834,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="469ae4c2bf41899febf19f91e601d6f390b4b9b55603c3ea58c4f7ec042e0997" data-name="status: confirmed" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22status%3A+confirmed%22" id="label-36fd22" style="--label-r:194;--label-g:172;--label-b:239;--label-h:259;--label-s:67;--label-l:80;">
#                     status: confirmed
# </a>
# <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-36fd22" hidden="hidden">Issue with steps to reproduce the bug that’s been verified by at least one reviewer.</tool-tip>
# </div>
# </div>
# </div>
# </div>
# </article>
# <div class="px-3 pb-3">
# <article class="d-flex flex-justify-between mb-2">
# <div class="d-flex flex-items-center">
# <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
# <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
# </svg> Open
# </span>
# <h4 class="d-inline flex-auto h5 ml-1 wb-break-word">
# <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:small;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"LITTLE_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1251983667,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="534976506e6a1bbdc9b8ed3b5f7131336525ffe75f9fa116c07ec660513d0a50" data-turbo="false" data-view-component="true" href="https://github.com/gatsbyjs/gatsby/issues/35771">
#                     Webpack error querying mdx.html in GraphiQL
# </a> </h4>
# </div>
# <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
# <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
# </svg>
#                   5
#                 </div>
# </article>
# <article class="d-flex flex-justify-between mb-2">
# <div class="d-flex flex-items-center">
# <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
# <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
# </svg> Open
# </span>
# <h4 class="d-inline flex-auto h5 ml-1 wb-break-word">
# <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:small;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"LITTLE_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1248866370,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="fc4d842cd77b8a742b1aa3ec57b8eb8d35853be92a2a99718331758851cd57c3" data-turbo="false" data-view-component="true" href="https://github.com/gatsbyjs/gatsby/issues/35756">
#                     [gatsby-transformer-javascript-frontmatter] Frontmatter export breaks HMR
# </a> </h4>
# </div>
# <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
# <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
# </svg>
#                   13
#                 </div>
# </article>
# <div class="mt-3">
# <a class="btn btn-outline btn-sm" data-ga-click="Explore, go to repository contribute, location:good first issues; text:more good first issues;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_CONTRIBUTE_PAGE","click_visual_representation":"CLICK_VISUAL_REPRESENTATION_UNKNOWN","actor_id":null,"record_id":36040894,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="27fc367abb6e8552b60cb8a69a2bb8e3d5daa0ed37e8e53122dd846ea1773219" data-turbo="false" data-view-component="true" href="/gatsbyjs/gatsby/contribute">
#                 Find more good first issues
# </a> </div>
# </div>
# </div>
# </article>

# %%
Repository_name = first_article.find('a',class_='text-bold wb-break-word').text

# %%
Repository_name.strip()
# Out:
# 'gatsby'

# %%
User_name = first_article.find('a',class_='').text

# %%
User_name.strip()
# Out:
# 'gatsbyjs'

# %%
Stars = first_article.find('span',class_='Counter js-social-count').text

# %%
Stars.strip()
# Out:
# '53.3k'

# %%
Url = first_article.find('a',class_='text-bold wb-break-word')['href']

# %%
base_Url = 'https://github.com/'

# %%
print(base_Url+Url)
# Out:
# https://github.com//gatsbyjs/gatsby

# %%
first_article_info={
    'Repository_name': Repository_name.strip(),
    'User_name': User_name.strip(),
    'Stars': Stars,
    'URL': base_Url+Url
}

# %%
first_article_info
# Out:
# {'Repository_name': 'gatsby',
#  'User_name': 'gatsbyjs',
#  'Stars': '53.3k',
#  'URL': 'https://github.com//gatsbyjs/gatsby'}

# %%
all_article = converted_data.find_all('article',class_='border rounded color-shadow-small color-bg-subtle my-4')

# %%
all_article
# Out:
# [<article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":12551863,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="036a63fabb6c8bc665b0e0c283e366d294c7a84edd8c51ebc83db0daa89fa71c" data-turbo="false" data-view-component="true" href="/gatsbyjs">
#              gatsbyjs
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":36040894,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="08e597eecb21d5081004fd20c92b4b16e73d50ecd19da3c7324aac52128bb8db" data-turbo="false" data-view-component="true" href="/gatsbyjs/gatsby">
#              gatsby
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":36040894,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="727ea155594b050f89ce1fd3c9dad8460f9009c32480dcec35d1d2ed014084df" data-view-component="true" href="/login?return_to=%2Fgatsbyjs%2Fgatsby" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="53290 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="53,290">53.3k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":36040894,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="1de8aea943061b91997a3083ccf7a6a0a3d34e610fee6a11690f8f2e70e4e06e" data-turbo="false" data-view-component="true" href="/gatsbyjs/gatsby" id="code-tab-36040894">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":36040894,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="06b0a54ba7e3fd575ec4def7c4d94dac210d404ed822f578b06738ed2df72fab" data-turbo="false" data-view-component="true" href="/gatsbyjs/gatsby/issues" id="issues-tab-36040894">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-dark" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":36040894,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="d21d154ce8388907419fa052f1f72795e8efcc9a4e09ac02c428b4b85fa522e9" data-turbo="false" data-view-component="true" href="/gatsbyjs/gatsby/pulls" id="pull-requests-tab-36040894">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository discussions, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_DISCUSSIONS","click_visual_representation":"DISCUSSIONS_TAB","actor_id":null,"record_id":36040894,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="8a48f507c693bfc96a12fec0732967121112a77f2a54bdc47ef2d2bdf909234f" data-turbo="false" data-view-component="true" href="/gatsbyjs/gatsby/discussions" id="discussions-tab-36040894">
#  <svg aria-hidden="true" class="octicon octicon-comment-discussion color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M1.5 2.75a.25.25 0 01.25-.25h8.5a.25.25 0 01.25.25v5.5a.25.25 0 01-.25.25h-3.5a.75.75 0 00-.53.22L3.5 11.44V9.25a.75.75 0 00-.75-.75h-1a.25.25 0 01-.25-.25v-5.5zM1.75 1A1.75 1.75 0 000 2.75v5.5C0 9.216.784 10 1.75 10H2v1.543a1.457 1.457 0 002.487 1.03L7.061 10h3.189A1.75 1.75 0 0012 8.25v-5.5A1.75 1.75 0 0010.25 1h-8.5zM14.5 4.75a.25.25 0 00-.25-.25h-.5a.75.75 0 110-1.5h.5c.966 0 1.75.784 1.75 1.75v5.5A1.75 1.75 0 0114.25 12H14v1.543a1.457 1.457 0 01-2.487 1.03L9.22 12.28a.75.75 0 111.06-1.06l2.22 2.22v-2.19a.75.75 0 01.75-.75h1a.25.25 0 00.25-.25v-5.5z" fill-rule="evenodd"></path>
#  </svg> Discussions
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <article class="p-3">
#  <div class="d-flex flex-justify-between mb-3">
#  <div class="d-flex flex-items-center">
#  <span class="State State--open State--small v-align-bottom mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto f3 text-normal ml-1 wb-break-word">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"BIG_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1261934222,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="b1834e83041c8c8dd43babe94560d7c07bce64d93ff5c30505412ff7b1f5dfa1" data-turbo="false" data-view-component="true" href="https://github.com/gatsbyjs/gatsby/issues/35853">
#                  GraphQL Typegen only picking up graphql tag usage from gatsby-node.ts
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                2
#              </div>
#  </div>
#  <div class="d-flex">
#  <div class="mr-3">
#  <img alt="openscript" class="avatar avatar-user avatar-small" height="32" src="https://avatars.githubusercontent.com/u/1105080?v=4" width="32"/>
#  </div>
#  <div class="flex-auto" style="width: 80%;">
#  <div class="Box Box--condensed position-relative timeline-comment--caret">
#  <div class="Box-header f6 color-fg-muted">
#  <strong class="color-fg-default text-bold">
#                    openscript
#                  </strong>
#
#                    commented
#
#                  <relative-time class="no-wrap" datetime="2022-06-06T14:34:45Z">Jun 6, 2022</relative-time>
#  </div>
#  <div class="Box-body comment-body markdown-body position-relative overflow-hidden pt-3" style="max-height:200px">
#  <h3>Preliminary Checks</h3>
#  <ul class="contains-task-list">
#  <li class="task-list-item"><input checked="" class="task-list-item-checkbox" disabled="" id="" type="checkbox"/> This issue is not a duplicate. Before opening a new issue, please search existing issues: <a href="https://github.com/gatsbyjs/gatsby/issues">https://github.com/gatsbyjs/gatsby/issues</a></li>
#  <li class="task-list-item"><input checked="" class="task-list-item-checkbox" disabled="" id="" type="checkbox"/> This issue is not a question, feature request, RFC, or anything other than a bug report directly related to Gatsby. Please post those things in GitHub Discussions: <a href="https://github.com/gatsbyjs/gatsby/discussions">https://github.com/gatsbyjs/gatsby/discussions</a></li>
#  </ul>
#  <h3>Description</h3>
#  <p>I'v</p>
#  <div class="position-absolute right-0 left-0 bottom-0 text-center" style="background: linear-gradient(to top, var(--color-canvas-default), var(--color-canvas-default-transparent));">
#  <a class="btn btn-outline btn-sm mx-auto my-3" data-ga-click="Explore, go to issue, location:good first issues;text:read more;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"READ_MORE","actor_id":null,"record_id":1261934222,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="ff443c3da42fcf0494bcad8e410a16b28941c592c08365fc7a70a44e8c4a6c5c" href="https://github.com/gatsbyjs/gatsby/issues/35853">
#                        Read more
#  </a> </div>
#  </div>
#  </div>
#  <div class="mt-3">
#  <span class="discussion-item-icon border-white-fade ml-0 mr-2">
#  <svg aria-hidden="true" class="octicon octicon-tag" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.5 7.775V2.75a.25.25 0 01.25-.25h5.025a.25.25 0 01.177.073l6.25 6.25a.25.25 0 010 .354l-5.025 5.025a.25.25 0 01-.354 0l-6.25-6.25a.25.25 0 01-.073-.177zm-1.5 0V2.75C1 1.784 1.784 1 2.75 1h5.025c.464 0 .91.184 1.238.513l6.25 6.25a1.75 1.75 0 010 2.474l-5.026 5.026a1.75 1.75 0 01-2.474 0l-6.25-6.25A1.75 1.75 0 011 7.775zM6 5a1 1 0 100 2 1 1 0 000-2z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <div class="wb-break-word">
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":214544672,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="69123cc3194626031cf8081cd853990e0b1ca4be0d733dd38ea25a5aead17502" data-name="type: bug" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22type%3A+bug%22" id="label-9fab05" style="--label-r:198;--label-g:76;--label-b:45;--label-h:12;--label-s:62;--label-l:47;">
#                      type: bug
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-9fab05" hidden="hidden">An issue or pull request relating to a bug in Gatsby</tool-tip>
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":214544675,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="3bb92fa8f664db2f037fce8b9cf339732f171726f74cd87577b5d294681c8704" data-name="help wanted" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22help+wanted%22" id="label-797269" style="--label-r:14;--label-g:138;--label-b:22;--label-h:123;--label-s:81;--label-l:29;">
#                      help wanted
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-797269" hidden="hidden">Issue with a clear description that the community can help with.</tool-tip>
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":734600061,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="a05d007911ec9e430c8343bfb798356fa68f545f0eca41650c25d397ef8039e5" data-name="good first issue" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22good+first+issue%22" id="label-0d8ce2" style="--label-r:252;--label-g:191;--label-b:227;--label-h:324;--label-s:91;--label-l:86;">
#                      good first issue
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-0d8ce2" hidden="hidden">Issue that doesn't require previous experience with Gatsby</tool-tip>
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":1038048834,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="469ae4c2bf41899febf19f91e601d6f390b4b9b55603c3ea58c4f7ec042e0997" data-name="status: confirmed" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22status%3A+confirmed%22" id="label-36fd22" style="--label-r:194;--label-g:172;--label-b:239;--label-h:259;--label-s:67;--label-l:80;">
#                      status: confirmed
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-36fd22" hidden="hidden">Issue with steps to reproduce the bug that’s been verified by at least one reviewer.</tool-tip>
#  </div>
#  </div>
#  </div>
#  </div>
#  </article>
#  <div class="px-3 pb-3">
#  <article class="d-flex flex-justify-between mb-2">
#  <div class="d-flex flex-items-center">
#  <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto h5 ml-1 wb-break-word">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:small;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"LITTLE_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1251983667,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="534976506e6a1bbdc9b8ed3b5f7131336525ffe75f9fa116c07ec660513d0a50" data-turbo="false" data-view-component="true" href="https://github.com/gatsbyjs/gatsby/issues/35771">
#                      Webpack error querying mdx.html in GraphiQL
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                    5
#                  </div>
#  </article>
#  <article class="d-flex flex-justify-between mb-2">
#  <div class="d-flex flex-items-center">
#  <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto h5 ml-1 wb-break-word">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:small;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"LITTLE_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1248866370,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="fc4d842cd77b8a742b1aa3ec57b8eb8d35853be92a2a99718331758851cd57c3" data-turbo="false" data-view-component="true" href="https://github.com/gatsbyjs/gatsby/issues/35756">
#                      [gatsby-transformer-javascript-frontmatter] Frontmatter export breaks HMR
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                    13
#                  </div>
#  </article>
#  <div class="mt-3">
#  <a class="btn btn-outline btn-sm" data-ga-click="Explore, go to repository contribute, location:good first issues; text:more good first issues;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_CONTRIBUTE_PAGE","click_visual_representation":"CLICK_VISUAL_REPRESENTATION_UNKNOWN","actor_id":null,"record_id":36040894,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="27fc367abb6e8552b60cb8a69a2bb8e3d5daa0ed37e8e53122dd846ea1773219" data-turbo="false" data-view-component="true" href="/gatsbyjs/gatsby/contribute">
#                  Find more good first issues
#  </a> </div>
#  </div>
#  </div>
#  </article>,
#  <article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <a class="overflow-hidden flex-items-center rounded-top-2 color-border-muted border-bottom d-flex position-relative" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_IMAGE","actor_id":null,"record_id":43441403,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="83e028cebb5e720c22f61ce1ba67f5efc8e8553b2e37ac20174f229ebcc51ac4" data-turbo="false" data-view-component="true" href="/strapi/strapi" style="max-height:275px">
#  <img alt="strapi" class="d-block width-full" loading="lazy" src="https://repository-images.githubusercontent.com/43441403/97069080-d012-11ea-9317-a871d5105486"/>
#  </a>
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":19872173,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="7662027f6d5a8d8ad68d9ffba4f0e227618adde920007903a71c2fa7ed8c81e0" data-turbo="false" data-view-component="true" href="/strapi">
#              strapi
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":43441403,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="2a2ec3f03e8af0ace7a0c179cbcad7658d78f152f02fa636f5af92e701aa70b0" data-turbo="false" data-view-component="true" href="/strapi/strapi">
#              strapi
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":43441403,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="4efe628489648961c80ce70e053415551eb3b112135e99d6b3b45d49625079da" data-view-component="true" href="/login?return_to=%2Fstrapi%2Fstrapi" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="46542 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="46,542">46.5k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":43441403,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="ebe61ea85a7b70c6644685a0e8cb73a041c9204c1ee9f8aedea7a9c8dc41065e" data-turbo="false" data-view-component="true" href="/strapi/strapi" id="code-tab-43441403">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":43441403,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="e910513ed8d56b4c814975e1aa4a52137ab41676d99bacc799a63d3bb500a887" data-turbo="false" data-view-component="true" href="/strapi/strapi/issues" id="issues-tab-43441403">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-dark" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":43441403,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="2852d17f2fe4ba91c90a7528c3a0d84b741061559b71598849e3905c8f88618b" data-turbo="false" data-view-component="true" href="/strapi/strapi/pulls" id="pull-requests-tab-43441403">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <article class="p-3">
#  <div class="d-flex flex-justify-between mb-3">
#  <div class="d-flex flex-items-center">
#  <span class="State State--open State--small v-align-bottom mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto f3 text-normal ml-1 wb-break-word">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"BIG_GOOD_FIRST_ISSUE","actor_id":null,"record_id":627963123,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="b3e8e4b5bc92ebf2652299409ba47a4a97a27511a78f5008261743b0a5a7a97f" data-turbo="false" data-view-component="true" href="https://github.com/strapi/strapi/issues/6475">
#                  Domain name validation
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                6
#              </div>
#  </div>
#  <div class="d-flex">
#  <div class="mr-3">
#  <img alt="sujaydeymountblue" class="avatar avatar-user avatar-small" height="32" src="https://avatars.githubusercontent.com/u/61132218?v=4" width="32"/>
#  </div>
#  <div class="flex-auto" style="width: 80%;">
#  <div class="Box Box--condensed position-relative timeline-comment--caret">
#  <div class="Box-header f6 color-fg-muted">
#  <strong class="color-fg-default text-bold">
#                    sujaydeymountblue
#                  </strong>
#
#                    commented
#
#                  <relative-time class="no-wrap" datetime="2020-05-31T13:25:13Z">May 31, 2020</relative-time>
#  </div>
#  <div class="Box-body comment-body markdown-body position-relative overflow-hidden pt-3" style="max-height:200px">
#  <p>Describe the bug<br/>
#  At the time of registration, email has not been validated correctly <code class="notranslate">http://localhost:1337/admin/auth/register</code></p>
#  <p>Expected behavior<br/>
#  An email should be valid in all aspect like</p>
#  <ul>
#  <li>should check valid domain, well-formed and valid mailbox</li>
#  </ul>
#  <p>Screenshots<br/>
#  invalid email1:<br/>
#  <a href="https://user-images.githubusercontent.com/61132218/83353428-2fb0c500-a370-11ea-8afa-e909a4f3b258.png" rel="noopener noreferrer" target="_blank"><img alt="s1" src="https://user-images.githubusercontent.com/61132218/83353428-2fb0c500-a370-11ea-8afa-e909a4f3b258.png" style="max-width: 100%;"/></a></p>
#  <div class="position-absolute right-0 left-0 bottom-0 text-center" style="background: linear-gradient(to top, var(--color-canvas-default), var(--color-canvas-default-transparent));">
#  <a class="btn btn-outline btn-sm mx-auto my-3" data-ga-click="Explore, go to issue, location:good first issues;text:read more;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"READ_MORE","actor_id":null,"record_id":627963123,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="2c8099ac8d00927244ef9ad3f6a8b6228ea349d792de1b3d47fe7985c9e74864" href="https://github.com/strapi/strapi/issues/6475">
#                        Read more
#  </a> </div>
#  </div>
#  </div>
#  <div class="mt-3">
#  <span class="discussion-item-icon border-white-fade ml-0 mr-2">
#  <svg aria-hidden="true" class="octicon octicon-tag" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.5 7.775V2.75a.25.25 0 01.25-.25h5.025a.25.25 0 01.177.073l6.25 6.25a.25.25 0 010 .354l-5.025 5.025a.25.25 0 01-.354 0l-6.25-6.25a.25.25 0 01-.073-.177zm-1.5 0V2.75C1 1.784 1.784 1 2.75 1h5.025c.464 0 .91.184 1.238.513l6.25 6.25a1.75 1.75 0 010 2.474l-5.026 5.026a1.75 1.75 0 01-2.474 0l-6.25-6.25A1.75 1.75 0 011 7.775zM6 5a1 1 0 100 2 1 1 0 000-2z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <div class="wb-break-word">
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":267208745,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="53b28bcdfe5f209cda308c47b4e1268cc1d2a5bc2a1deb8e95d85e2e5e5e1458" data-name="issue: enhancement" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22issue%3A+enhancement%22" id="label-ca93c9" style="--label-r:132;--label-g:182;--label-b:235;--label-h:210;--label-s:72;--label-l:71;">
#                      issue: enhancement
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-ca93c9" hidden="hidden">Issue suggesting an enhancement to an existing feature</tool-tip>
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":749109179,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="c8c68c5d6cba06b343ffdf739af4ddf9654124d8dd8c5ef822b21bf82b2e30f4" data-name="severity: low" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22severity%3A+low%22" id="label-59d884" style="--label-r:133;--label-g:178;--label-b:112;--label-h:100;--label-s:29;--label-l:56;">
#                      severity: low
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-59d884" hidden="hidden">If the issue only affects a very niche base of users and an easily implemented workaround can solve</tool-tip>
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":758314049,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="350c0afb4ffada0a7ce4156bdba8beed50a7d51bcd500ff971af47d452238cde" data-name="good first issue" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22good+first+issue%22" id="label-e73433" style="--label-r:236;--label-g:236;--label-b:236;--label-h:0;--label-s:0;--label-l:92;">
#                      good first issue
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-e73433" hidden="hidden">Good for newcomers</tool-tip>
#  </div>
#  </div>
#  </div>
#  </div>
#  </article>
#  <div class="px-3 pb-3">
#  <article class="d-flex flex-justify-between mb-2">
#  <div class="d-flex flex-items-center">
#  <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto h5 ml-1 wb-break-word">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:small;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"LITTLE_GOOD_FIRST_ISSUE","actor_id":null,"record_id":610290608,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="815fd70a8aa23baca40746d75fed10d2531bed8ba249f6dd5df8f9c896a4e9cf" data-turbo="false" data-view-component="true" href="https://github.com/strapi/strapi/issues/6014">
#                      Facebook provider stores user's non unique name as strapi unique username
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                    8
#                  </div>
#  </article>
#  <article class="d-flex flex-justify-between mb-2">
#  <div class="d-flex flex-items-center">
#  <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto h5 ml-1 wb-break-word">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:small;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"LITTLE_GOOD_FIRST_ISSUE","actor_id":null,"record_id":602524110,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="e4521d2f294dc028f5d4e0bd838da80e3caca4f96745a503f95066541583e3be" data-turbo="false" data-view-component="true" href="https://github.com/strapi/strapi/issues/5868">
#                      AWS S3 upload access denied ACL public-read
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                    42
#                  </div>
#  </article>
#  <div class="mt-3">
#  <a class="btn btn-outline btn-sm" data-ga-click="Explore, go to repository contribute, location:good first issues; text:more good first issues;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_CONTRIBUTE_PAGE","click_visual_representation":"CLICK_VISUAL_REPRESENTATION_UNKNOWN","actor_id":null,"record_id":43441403,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="05f200b3bbd880850d7cad1a78feb26b47d790bfadec616e43dd9d211229258f" data-turbo="false" data-view-component="true" href="/strapi/strapi/contribute">
#                  Find more good first issues
#  </a> </div>
#  </div>
#  </div>
#  </article>,
#  <article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <a class="overflow-hidden flex-items-center rounded-top-2 color-border-muted border-bottom d-flex position-relative" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_IMAGE","actor_id":null,"record_id":203587744,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="6ad63196893ff5e2d4998130db6123ff48d114dbc345db6e23672238e971176d" data-turbo="false" data-view-component="true" href="/hoppscotch/hoppscotch" style="max-height:275px">
#  <img alt="hoppscotch" class="d-block width-full" loading="lazy" src="https://repository-images.githubusercontent.com/203587744/b3f2e0c0-7d58-4b32-b78e-192a99030b1a"/>
#  </a>
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":56705483,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="d7e690145579a8c40223580895c02349cc749748f8fddf3dc701fd324346a307" data-turbo="false" data-view-component="true" href="/hoppscotch">
#              hoppscotch
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":203587744,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="fda31908537debae5a55d441075c8a299885af3cf99000d4c1753e7f32d8f604" data-turbo="false" data-view-component="true" href="/hoppscotch/hoppscotch">
#              hoppscotch
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <a aria-label="Sponsor @hoppscotch" class="btn btn-sm mr-2" data-hydro-click='{"event_type":"sponsors.button_click","payload":{"button":"TOPIC_PAGE_SPONSOR","sponsorable_login":"hoppscotch","originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="fd8215f13c19184bddccea406b60373fd8c1ac64d89f6340e4871fec0acac150" data-view-component="true" href="/sponsors/hoppscotch">
#  <svg aria-hidden="true" class="octicon octicon-heart icon-sponsor mr-1 v-align-middle color-fg-sponsors anim-pulse-in" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.25 2.5c-1.336 0-2.75 1.164-2.75 3 0 2.15 1.58 4.144 3.365 5.682A20.565 20.565 0 008 13.393a20.561 20.561 0 003.135-2.211C12.92 9.644 14.5 7.65 14.5 5.5c0-1.836-1.414-3-2.75-3-1.373 0-2.609.986-3.029 2.456a.75.75 0 01-1.442 0C6.859 3.486 5.623 2.5 4.25 2.5zM8 14.25l-.345.666-.002-.001-.006-.003-.018-.01a7.643 7.643 0 01-.31-.17 22.075 22.075 0 01-3.434-2.414C2.045 10.731 0 8.35 0 5.5 0 2.836 2.086 1 4.25 1 5.797 1 7.153 1.802 8 3.02 8.847 1.802 10.203 1 11.75 1 13.914 1 16 2.836 16 5.5c0 2.85-2.045 5.231-3.885 6.818a22.08 22.08 0 01-3.744 2.584l-.018.01-.006.003h-.002L8 14.25zm0 0l.345.666a.752.752 0 01-.69 0L8 14.25z" fill-rule="evenodd"></path>
#  </svg>
#  <span class="v-align-middle">Sponsor</span>
#  </a>
#  <div class="BtnGroup d-flex" data-view-component="true">
# ...
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="8582 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="8,582">8.6k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":94949504,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="3ed6b200e73e8cbc7b92b4fca7ed0ba9c745c706790dda091fd8191e4246fab3" data-turbo="false" data-view-component="true" href="/apex/up" id="code-tab-94949504">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-default" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":94949504,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="29780edee62a9a174746acd84b01117c19abb9a2da8a430fd9a68e63ccd13fde" data-turbo="false" data-view-component="true" href="/apex/up/issues" id="issues-tab-94949504">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-light" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":328460,"originating_url":"https://github.com/topics/graphql","user_id":null}}' data-hydro-click-hmac="6c05713b8b15ce9c3f6eba077aebb3fcfbd655e23676f6e61f44591443e2039d" data-view-component="true" href="/topics/aws-infrastructure" title="Topic: aws-infrastructure">
#                aws-infrastructure
#  </a> </div>
#  <div class="p-3">
#  <ul class="d-flex f6 list-style-none color-fg-muted">
#  <li class="mr-4">
#                Updated
#                <relative-time class="no-wrap" datetime="2022-06-27T03:46:17Z">Jun 27, 2022</relative-time>
#  </li>
#  <li class="mr-4">
#  <span class="f6 my-1 ml-0">
#  <span class="repo-language-color" style="background-color: #00ADD8"></span>
#  <span itemprop="programmingLanguage">Go</span>
#  </span>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </article>]

# %%
page_1 = []
for item in all_article:
    Repository_name = item.find('a',class_='text-bold wb-break-word').text
    User_name = item.find('a',class_='').text
    Stars = item.find('span',class_='Counter js-social-count').text
    URL = item.find('a',class_='text-bold wb-break-word')['href']
    User_name = User_name.strip()
    Repository_name = Repository_name.strip()
    URL = URL.strip()
    Stars = Stars.strip()
    page_1_dict = {
        'Repository Name': Repository_name,
        'User Name': User_name,
        'Stars': Stars,
        'URL': base_Url+Url
    }
    
    page_1.append(page_1_dict)

# %%
print(page_1)
# Out:
# [{'Repository Name': 'gatsby', 'User Name': 'gatsbyjs', 'Stars': '53.3k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'strapi', 'User Name': 'strapi', 'Stars': '46.5k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'hoppscotch', 'User Name': 'hoppscotch', 'Stars': '45.3k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'prettier', 'User Name': 'prettier', 'Stars': '43.5k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'supabase', 'User Name': 'supabase', 'Stars': '36k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'query', 'User Name': 'TanStack', 'Stars': '28.9k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'graphql-engine', 'User Name': 'hasura', 'Stars': '27.5k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'insomnia', 'User Name': 'Kong', 'Stars': '21.8k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'react-starter-kit', 'User Name': 'kriasoft', 'Stars': '21.3k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'react-admin', 'User Name': 'marmelab', 'Stars': '20.2k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'parse-server', 'User Name': 'parse-community', 'Stars': '19.7k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'graphql-js', 'User Name': 'graphql', 'Stars': '18.9k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'dgraph', 'User Name': 'dgraph-io', 'Stars': '18.3k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'apollo-client', 'User Name': 'apollographql', 'Stars': '17.9k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'rxdb', 'User Name': 'pubkey', 'Stars': '17.7k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'directus', 'User Name': 'directus', 'Stars': '17.1k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'prisma1', 'User Name': 'prisma', 'Stars': '16.8k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'saleor', 'User Name': 'saleor', 'Stars': '16.5k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'redwood', 'User Name': 'redwoodjs', 'Stars': '14.4k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'graphiql', 'User Name': 'graphql', 'Stars': '13.8k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'awesome-graphql', 'User Name': 'chentsulin', 'Stars': '13.5k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'apollo-server', 'User Name': 'apollographql', 'Stars': '12.8k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'spree', 'User Name': 'spree', 'Stars': '11.9k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'reaction', 'User Name': 'reactioncommerce', 'Stars': '11.8k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'dataloader', 'User Name': 'graphql', 'Stars': '11.6k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'postgraphile', 'User Name': 'graphile', 'Stars': '11.4k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'spectrum', 'User Name': 'withspectrum', 'Stars': '10.6k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'graphql-code-generator', 'User Name': 'dotansimha', 'Stars': '9k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'graphql', 'User Name': 'graphql-go', 'Stars': '8.7k', 'URL': 'https://github.com//gatsbyjs/gatsby'}, {'Repository Name': 'up', 'User Name': 'apex', 'Stars': '8.6k', 'URL': 'https://github.com//gatsbyjs/gatsby'}]

# %%
import pandas as pd

# %%
df = pd.DataFrame(page_1)

# %%
df
# Out:
#            Repository Name         User Name  Stars  \
# 0                   gatsby          gatsbyjs  53.3k
# 1                   strapi            strapi  46.5k
# 2               hoppscotch        hoppscotch  45.3k
# 3                 prettier          prettier  43.5k
# 4                 supabase          supabase    36k
# 5                    query          TanStack  28.9k
# 6           graphql-engine            hasura  27.5k
# 7                 insomnia              Kong  21.8k
# 8        react-starter-kit          kriasoft  21.3k
# 9              react-admin          marmelab  20.2k
# 10            parse-server   parse-community  19.7k
# 11              graphql-js           graphql  18.9k
# 12                  dgraph         dgraph-io  18.3k
# 13           apollo-client     apollographql  17.9k
# 14                    rxdb            pubkey  17.7k
# 15                directus          directus  17.1k
# 16                 prisma1            prisma  16.8k
# 17                  saleor            saleor  16.5k
# 18                 redwood         redwoodjs  14.4k
# 19                graphiql           graphql  13.8k
# 20         awesome-graphql        chentsulin  13.5k
# 21           apollo-server     apollographql  12.8k
# 22                   spree             spree  11.9k
# 23                reaction  reactioncommerce  11.8k
# 24              dataloader           graphql  11.6k
# 25            postgraphile          graphile  11.4k
# 26                spectrum      withspectrum  10.6k
# 27  graphql-code-generator        dotansimha     9k
# 28                 graphql        graphql-go   8.7k
# 29                      up              apex   8.6k
#
#                                     URL
# 0   https://github.com//gatsbyjs/gatsby
# 1   https://github.com//gatsbyjs/gatsby
# 2   https://github.com//gatsbyjs/gatsby
# 3   https://github.com//gatsbyjs/gatsby
# 4   https://github.com//gatsbyjs/gatsby
# 5   https://github.com//gatsbyjs/gatsby
# 6   https://github.com//gatsbyjs/gatsby
# 7   https://github.com//gatsbyjs/gatsby
# 8   https://github.com//gatsbyjs/gatsby
# 9   https://github.com//gatsbyjs/gatsby
# 10  https://github.com//gatsbyjs/gatsby
# 11  https://github.com//gatsbyjs/gatsby
# 12  https://github.com//gatsbyjs/gatsby
# 13  https://github.com//gatsbyjs/gatsby
# 14  https://github.com//gatsbyjs/gatsby
# 15  https://github.com//gatsbyjs/gatsby
# 16  https://github.com//gatsbyjs/gatsby
# 17  https://github.com//gatsbyjs/gatsby
# 18  https://github.com//gatsbyjs/gatsby
# 19  https://github.com//gatsbyjs/gatsby
# 20  https://github.com//gatsbyjs/gatsby
# 21  https://github.com//gatsbyjs/gatsby
# 22  https://github.com//gatsbyjs/gatsby
# 23  https://github.com//gatsbyjs/gatsby
# 24  https://github.com//gatsbyjs/gatsby
# 25  https://github.com//gatsbyjs/gatsby
# 26  https://github.com//gatsbyjs/gatsby
# 27  https://github.com//gatsbyjs/gatsby
# 28  https://github.com//gatsbyjs/gatsby
# 29  https://github.com//gatsbyjs/gatsby

# %%
df.to_excel('Page1.xlsx')

# %%
base_url = 'https://github.com/topics/graphql?page='

# %%
url = []
for num in range(1,8):

    url.append(base_url+str(num))

# %%
(url)
# Out:
# ['https://github.com/topics/graphql?page=1',
#  'https://github.com/topics/graphql?page=2',
#  'https://github.com/topics/graphql?page=3',
#  'https://github.com/topics/graphql?page=4',
#  'https://github.com/topics/graphql?page=5',
#  'https://github.com/topics/graphql?page=6',
#  'https://github.com/topics/graphql?page=7']

# %%
all_article_lst = []
for url_data in url:
    html_data = requests.get(url_data).text
   # print(url_data)
    converted_data = BeautifulSoup(html_data,'lxml')
    all_article = converted_data.find_all('article',class_='border rounded color-shadow-small color-bg-subtle my-4')
   # print(all_article)
    for item in all_article:
        Repository_name = item.find('a',class_='text-bold wb-break-word').text
        Repository_name = Repository_name.strip()
        User_name = item.find('a',class_='').text
        User_name = User_name.strip()
        Stars = item.find('span',class_='Counter js-social-count').text
        URL = item.find('a',class_='text-bold wb-break-word')['href']
        URL = URL.strip()
        
        
        dict2 = {
            'Repository Name': Repository_name,
            'User Name': User_name,
            'Stars': Stars,
            'URL': base_Url +URL
        }
        
        print(dict2)
        
        
        all_article_lst.append(dict2)
# Out:
# {'Repository Name': 'gatsby', 'User Name': 'gatsbyjs', 'Stars': '53.3k', 'URL': 'https://github.com//gatsbyjs/gatsby'}
# {'Repository Name': 'strapi', 'User Name': 'strapi', 'Stars': '46.5k', 'URL': 'https://github.com//strapi/strapi'}
# {'Repository Name': 'hoppscotch', 'User Name': 'hoppscotch', 'Stars': '45.3k', 'URL': 'https://github.com//hoppscotch/hoppscotch'}
# {'Repository Name': 'prettier', 'User Name': 'prettier', 'Stars': '43.5k', 'URL': 'https://github.com//prettier/prettier'}
# {'Repository Name': 'supabase', 'User Name': 'supabase', 'Stars': '36k', 'URL': 'https://github.com//supabase/supabase'}
# {'Repository Name': 'query', 'User Name': 'TanStack', 'Stars': '28.9k', 'URL': 'https://github.com//TanStack/query'}
# {'Repository Name': 'graphql-engine', 'User Name': 'hasura', 'Stars': '27.5k', 'URL': 'https://github.com//hasura/graphql-engine'}
# {'Repository Name': 'insomnia', 'User Name': 'Kong', 'Stars': '21.8k', 'URL': 'https://github.com//Kong/insomnia'}
# {'Repository Name': 'react-starter-kit', 'User Name': 'kriasoft', 'Stars': '21.3k', 'URL': 'https://github.com//kriasoft/react-starter-kit'}
# {'Repository Name': 'react-admin', 'User Name': 'marmelab', 'Stars': '20.2k', 'URL': 'https://github.com//marmelab/react-admin'}
# {'Repository Name': 'parse-server', 'User Name': 'parse-community', 'Stars': '19.7k', 'URL': 'https://github.com//parse-community/parse-server'}
# {'Repository Name': 'graphql-js', 'User Name': 'graphql', 'Stars': '18.9k', 'URL': 'https://github.com//graphql/graphql-js'}
# {'Repository Name': 'dgraph', 'User Name': 'dgraph-io', 'Stars': '18.3k', 'URL': 'https://github.com//dgraph-io/dgraph'}
# {'Repository Name': 'apollo-client', 'User Name': 'apollographql', 'Stars': '17.9k', 'URL': 'https://github.com//apollographql/apollo-client'}
# {'Repository Name': 'rxdb', 'User Name': 'pubkey', 'Stars': '17.7k', 'URL': 'https://github.com//pubkey/rxdb'}
# {'Repository Name': 'directus', 'User Name': 'directus', 'Stars': '17.1k', 'URL': 'https://github.com//directus/directus'}
# {'Repository Name': 'prisma1', 'User Name': 'prisma', 'Stars': '16.8k', 'URL': 'https://github.com//prisma/prisma1'}
# {'Repository Name': 'saleor', 'User Name': 'saleor', 'Stars': '16.5k', 'URL': 'https://github.com//saleor/saleor'}
# {'Repository Name': 'redwood', 'User Name': 'redwoodjs', 'Stars': '14.4k', 'URL': 'https://github.com//redwoodjs/redwood'}
# {'Repository Name': 'graphiql', 'User Name': 'graphql', 'Stars': '13.8k', 'URL': 'https://github.com//graphql/graphiql'}
# {'Repository Name': 'awesome-graphql', 'User Name': 'chentsulin', 'Stars': '13.5k', 'URL': 'https://github.com//chentsulin/awesome-graphql'}
# {'Repository Name': 'apollo-server', 'User Name': 'apollographql', 'Stars': '12.8k', 'URL': 'https://github.com//apollographql/apollo-server'}
# {'Repository Name': 'spree', 'User Name': 'spree', 'Stars': '11.9k', 'URL': 'https://github.com//spree/spree'}
# {'Repository Name': 'reaction', 'User Name': 'reactioncommerce', 'Stars': '11.8k', 'URL': 'https://github.com//reactioncommerce/reaction'}
# {'Repository Name': 'dataloader', 'User Name': 'graphql', 'Stars': '11.6k', 'URL': 'https://github.com//graphql/dataloader'}
# {'Repository Name': 'postgraphile', 'User Name': 'graphile', 'Stars': '11.4k', 'URL': 'https://github.com//graphile/postgraphile'}
# {'Repository Name': 'spectrum', 'User Name': 'withspectrum', 'Stars': '10.6k', 'URL': 'https://github.com//withspectrum/spectrum'}
# {'Repository Name': 'graphql-code-generator', 'User Name': 'dotansimha', 'Stars': '9k', 'URL': 'https://github.com//dotansimha/graphql-code-generator'}
# {'Repository Name': 'graphql', 'User Name': 'graphql-go', 'Stars': '8.7k', 'URL': 'https://github.com//graphql-go/graphql'}
# {'Repository Name': 'up', 'User Name': 'apex', 'Stars': '8.6k', 'URL': 'https://github.com//apex/up'}
# {'Repository Name': 'edgedb', 'User Name': 'edgedb', 'Stars': '8.5k', 'URL': 'https://github.com//edgedb/edgedb'}
# {'Repository Name': 'quicktype', 'User Name': 'quicktype', 'Stars': '8.4k', 'URL': 'https://github.com//quicktype/quicktype'}
# {'Repository Name': 'devhub', 'User Name': 'devhubapp', 'Stars': '8.3k', 'URL': 'https://github.com//devhubapp/devhub'}
# {'Repository Name': 'howtographql', 'User Name': 'howtographql', 'Stars': '8.3k', 'URL': 'https://github.com//howtographql/howtographql'}
# {'Repository Name': 'gridsome', 'User Name': 'gridsome', 'Stars': '8.3k', 'URL': 'https://github.com//gridsome/gridsome'}
# {'Repository Name': 'graphql-playground', 'User Name': 'graphql', 'Stars': '8.1k', 'URL': 'https://github.com//graphql/graphql-playground'}
# {'Repository Name': 'Vulcan', 'User Name': 'VulcanJS', 'Stars': '8k', 'URL': 'https://github.com//VulcanJS/Vulcan'}
# {'Repository Name': 'gqlgen', 'User Name': '99designs', 'Stars': '7.8k', 'URL': 'https://github.com//99designs/gqlgen'}
# {'Repository Name': 'amplication', 'User Name': 'amplication', 'Stars': '7.8k', 'URL': 'https://github.com//amplication/amplication'}
# {'Repository Name': 'tyk', 'User Name': 'TykTechnologies', 'Stars': '7.6k', 'URL': 'https://github.com//TykTechnologies/tyk'}
# {'Repository Name': 'api-platform', 'User Name': 'api-platform', 'Stars': '7.5k', 'URL': 'https://github.com//api-platform/api-platform'}
# {'Repository Name': 'urql', 'User Name': 'FormidableLabs', 'Stars': '7.4k', 'URL': 'https://github.com//FormidableLabs/urql'}
# {'Repository Name': 'type-graphql', 'User Name': 'MichalLytek', 'Stars': '7.3k', 'URL': 'https://github.com//MichalLytek/type-graphql'}
# {'Repository Name': 'graphene', 'User Name': 'graphql-python', 'Stars': '7.3k', 'URL': 'https://github.com//graphql-python/graphene'}
# {'Repository Name': 'starlette', 'User Name': 'encode', 'Stars': '7.2k', 'URL': 'https://github.com//encode/starlette'}
# {'Repository Name': 'graphql-yoga', 'User Name': 'dotansimha', 'Stars': '7.1k', 'URL': 'https://github.com//dotansimha/graphql-yoga'}
# {'Repository Name': 'react-apollo', 'User Name': 'apollographql', 'Stars': '6.9k', 'URL': 'https://github.com//apollographql/react-apollo'}
# {'Repository Name': 'graphql-voyager', 'User Name': 'IvanGoncharov', 'Stars': '6.8k', 'URL': 'https://github.com//IvanGoncharov/graphql-voyager'}
# {'Repository Name': 'keystone', 'User Name': 'keystonejs', 'Stars': '6.7k', 'URL': 'https://github.com//keystonejs/keystone'}
# {'Repository Name': 'express-graphql', 'User Name': 'graphql', 'Stars': '6.3k', 'URL': 'https://github.com//graphql/express-graphql'}
# {'Repository Name': 'payload', 'User Name': 'payloadcms', 'Stars': '6.2k', 'URL': 'https://github.com//payloadcms/payload'}
# {'Repository Name': 'webiny-js', 'User Name': 'webiny', 'Stars': '5.8k', 'URL': 'https://github.com//webiny/webiny-js'}
# {'Repository Name': 'apollo', 'User Name': 'vuejs', 'Stars': '5.7k', 'URL': 'https://github.com//vuejs/apollo'}
# {'Repository Name': 'graphql-editor', 'User Name': 'graphql-editor', 'Stars': '5.7k', 'URL': 'https://github.com//graphql-editor/graphql-editor'}
# {'Repository Name': 'graphql-java', 'User Name': 'graphql-java', 'Stars': '5.6k', 'URL': 'https://github.com//graphql-java/graphql-java'}
# {'Repository Name': 'este', 'User Name': 'este', 'Stars': '5.4k', 'URL': 'https://github.com//este/este'}
# {'Repository Name': 'graphql-dotnet', 'User Name': 'graphql-dotnet', 'Stars': '5.3k', 'URL': 'https://github.com//graphql-dotnet/graphql-dotnet'}
# {'Repository Name': 'learnapollo', 'User Name': 'learnapollo', 'Stars': '5.3k', 'URL': 'https://github.com//learnapollo/learnapollo'}
# {'Repository Name': 'graphql-ruby', 'User Name': 'rmosolgo', 'Stars': '5.1k', 'URL': 'https://github.com//rmosolgo/graphql-ruby'}
# {'Repository Name': 'graphql-tools', 'User Name': 'ardatan', 'Stars': '4.9k', 'URL': 'https://github.com//ardatan/graphql-tools'}
# {'Repository Name': 'graphql-request', 'User Name': 'prisma-labs', 'Stars': '4.7k', 'URL': 'https://github.com//prisma-labs/graphql-request'}
# {'Repository Name': 'juniper', 'User Name': 'graphql-rust', 'Stars': '4.6k', 'URL': 'https://github.com//graphql-rust/juniper'}
# {'Repository Name': 'searchkit', 'User Name': 'searchkit', 'Stars': '4.4k', 'URL': 'https://github.com//searchkit/searchkit'}
# {'Repository Name': 'react-firebase-starter', 'User Name': 'kriasoft', 'Stars': '4.4k', 'URL': 'https://github.com//kriasoft/react-firebase-starter'}
# {'Repository Name': 'Messenger', 'User Name': 'relatedcode', 'Stars': '4.4k', 'URL': 'https://github.com//relatedcode/Messenger'}
# {'Repository Name': 'graphql-php', 'User Name': 'webonyx', 'Stars': '4.4k', 'URL': 'https://github.com//webonyx/graphql-php'}
# {'Repository Name': 'altair', 'User Name': 'altair-graphql', 'Stars': '4.3k', 'URL': 'https://github.com//altair-graphql/altair'}
# {'Repository Name': 'hackernews-react-graphql', 'User Name': 'clintonwoo', 'Stars': '4.3k', 'URL': 'https://github.com//clintonwoo/hackernews-react-graphql'}
# {'Repository Name': 'JSUI', 'User Name': 'kitze', 'Stars': '4.2k', 'URL': 'https://github.com//kitze/JSUI'}
# {'Repository Name': 'graphql-go', 'User Name': 'graph-gophers', 'Stars': '4.2k', 'URL': 'https://github.com//graph-gophers/graphql-go'}
# {'Repository Name': 'reactjs101', 'User Name': 'kdchang', 'Stars': '4.1k', 'URL': 'https://github.com//kdchang/reactjs101'}
# {'Repository Name': 'absinthe', 'User Name': 'absinthe-graphql', 'Stars': '4k', 'URL': 'https://github.com//absinthe-graphql/absinthe'}
# {'Repository Name': 'graphql-apis', 'User Name': 'IvanGoncharov', 'Stars': '3.9k', 'URL': 'https://github.com//IvanGoncharov/graphql-apis'}
# {'Repository Name': 'graphene-django', 'User Name': 'graphql-python', 'Stars': '3.9k', 'URL': 'https://github.com//graphql-python/graphene-django'}
# {'Repository Name': 'prisma-examples', 'User Name': 'prisma', 'Stars': '3.8k', 'URL': 'https://github.com//prisma/prisma-examples'}
# {'Repository Name': 'vscode-restclient', 'User Name': 'Huachao', 'Stars': '3.7k', 'URL': 'https://github.com//Huachao/vscode-restclient'}
# {'Repository Name': 'go-gin-api', 'User Name': 'xinliangnote', 'Stars': '3.7k', 'URL': 'https://github.com//xinliangnote/go-gin-api'}
# {'Repository Name': 'hotchocolate', 'User Name': 'ChilliCream', 'Stars': '3.7k', 'URL': 'https://github.com//ChilliCream/hotchocolate'}
# {'Repository Name': 'vendure', 'User Name': 'vendure-ecommerce', 'Stars': '3.6k', 'URL': 'https://github.com//vendure-ecommerce/vendure'}
# {'Repository Name': 'gqless', 'User Name': 'samdenty', 'Stars': '3.6k', 'URL': 'https://github.com//samdenty/gqless'}
# {'Repository Name': 'parse-dashboard', 'User Name': 'parse-community', 'Stars': '3.6k', 'URL': 'https://github.com//parse-community/parse-dashboard'}
# {'Repository Name': 'transform', 'User Name': 'ritz078', 'Stars': '3.6k', 'URL': 'https://github.com//ritz078/transform'}
# {'Repository Name': 'space-cloud', 'User Name': 'spacecloud-io', 'Stars': '3.6k', 'URL': 'https://github.com//spacecloud-io/space-cloud'}
# {'Repository Name': 'responder', 'User Name': 'taoufik07', 'Stars': '3.6k', 'URL': 'https://github.com//taoufik07/responder'}
# {'Repository Name': 'relay-starter-kit', 'User Name': 'kriasoft', 'Stars': '3.6k', 'URL': 'https://github.com//kriasoft/relay-starter-kit'}
# {'Repository Name': 'rejoiner', 'User Name': 'google', 'Stars': '3.5k', 'URL': 'https://github.com//google/rejoiner'}
# {'Repository Name': 'apollo-ios', 'User Name': 'apollographql', 'Stars': '3.4k', 'URL': 'https://github.com//apollographql/apollo-ios'}
# {'Repository Name': 'nhost', 'User Name': 'nhost', 'Stars': '3.4k', 'URL': 'https://github.com//nhost/nhost'}
# {'Repository Name': 'graphql-shield', 'User Name': 'maticzav', 'Stars': '3.3k', 'URL': 'https://github.com//maticzav/graphql-shield'}
# {'Repository Name': 'vulcain', 'User Name': 'dunglas', 'Stars': '3.3k', 'URL': 'https://github.com//dunglas/vulcain'}
# {'Repository Name': 'taskcafe', 'User Name': 'JordanKnott', 'Stars': '3.3k', 'URL': 'https://github.com//JordanKnott/taskcafe'}
# {'Repository Name': 'wp-graphql', 'User Name': 'wp-graphql', 'Stars': '3.3k', 'URL': 'https://github.com//wp-graphql/wp-graphql'}
# {'Repository Name': 'apollo-kotlin', 'User Name': 'apollographql', 'Stars': '3.2k', 'URL': 'https://github.com//apollographql/apollo-kotlin'}
# {'Repository Name': 'graphqurl', 'User Name': 'hasura', 'Stars': '3.1k', 'URL': 'https://github.com//hasura/graphqurl'}
# {'Repository Name': 'nexus', 'User Name': 'graphql-nexus', 'Stars': '3k', 'URL': 'https://github.com//graphql-nexus/nexus'}
# {'Repository Name': 'Templates', 'User Name': 'Dotnet-Boxed', 'Stars': '3k', 'URL': 'https://github.com//Dotnet-Boxed/Templates'}
# {'Repository Name': 'apollo-tooling', 'User Name': 'apollographql', 'Stars': '3k', 'URL': 'https://github.com//apollographql/apollo-tooling'}
# {'Repository Name': 'pokeapi', 'User Name': 'PokeAPI', 'Stars': '3k', 'URL': 'https://github.com//PokeAPI/pokeapi'}
# {'Repository Name': 'graphql-flutter', 'User Name': 'zino-hofmann', 'Stars': '3k', 'URL': 'https://github.com//zino-hofmann/graphql-flutter'}
# {'Repository Name': 'lighthouse', 'User Name': 'nuwave', 'Stars': '2.9k', 'URL': 'https://github.com//nuwave/lighthouse'}
# {'Repository Name': 'mercure', 'User Name': 'dunglas', 'Stars': '2.9k', 'URL': 'https://github.com//dunglas/mercure'}
# {'Repository Name': 'cms', 'User Name': 'craftcms', 'Stars': '2.9k', 'URL': 'https://github.com//craftcms/cms'}
# {'Repository Name': 'GraphQLite', 'User Name': 'relatedcode', 'Stars': '2.8k', 'URL': 'https://github.com//relatedcode/GraphQLite'}
# {'Repository Name': 'vue-express-mongo-boilerplate', 'User Name': 'icebob', 'Stars': '2.8k', 'URL': 'https://github.com//icebob/vue-express-mongo-boilerplate'}
# {'Repository Name': 'vuesion', 'User Name': 'vuesion', 'Stars': '2.6k', 'URL': 'https://github.com//vuesion/vuesion'}
# {'Repository Name': 'weaviate', 'User Name': 'semi-technologies', 'Stars': '2.6k', 'URL': 'https://github.com//semi-technologies/weaviate'}
# {'Repository Name': 'refine', 'User Name': 'pankod', 'Stars': '2.6k', 'URL': 'https://github.com//pankod/refine'}
# {'Repository Name': 'amplify-cli', 'User Name': 'aws-amplify', 'Stars': '2.6k', 'URL': 'https://github.com//aws-amplify/amplify-cli'}
# {'Repository Name': 'SwiftHub', 'User Name': 'khoren93', 'Stars': '2.5k', 'URL': 'https://github.com//khoren93/SwiftHub'}
# {'Repository Name': 'graphql-mesh', 'User Name': 'Urigo', 'Stars': '2.5k', 'URL': 'https://github.com//Urigo/graphql-mesh'}
# {'Repository Name': 'join-monster', 'User Name': 'join-monster', 'Stars': '2.5k', 'URL': 'https://github.com//join-monster/join-monster'}
# {'Repository Name': 'graphql-faker', 'User Name': 'IvanGoncharov', 'Stars': '2.5k', 'URL': 'https://github.com//IvanGoncharov/graphql-faker'}
# {'Repository Name': 'strawberry', 'User Name': 'strawberry-graphql', 'Stars': '2.5k', 'URL': 'https://github.com//strawberry-graphql/strawberry'}
# {'Repository Name': 'cannercms', 'User Name': 'Canner', 'Stars': '2.5k', 'URL': 'https://github.com//Canner/cannercms'}
# {'Repository Name': 'dgs-framework', 'User Name': 'Netflix', 'Stars': '2.4k', 'URL': 'https://github.com//Netflix/dgs-framework'}
# {'Repository Name': 'async-graphql', 'User Name': 'async-graphql', 'Stars': '2.3k', 'URL': 'https://github.com//async-graphql/async-graphql'}
# {'Repository Name': 'crate', 'User Name': 'atulmy', 'Stars': '2.3k', 'URL': 'https://github.com//atulmy/crate'}
# {'Repository Name': 'create-eth-app', 'User Name': 'paulrberg', 'Stars': '2.3k', 'URL': 'https://github.com//paulrberg/create-eth-app'}
# {'Repository Name': 'graphjin', 'User Name': 'dosco', 'Stars': '2.3k', 'URL': 'https://github.com//dosco/graphjin'}
# {'Repository Name': 'thunder-client-support', 'User Name': 'rangav', 'Stars': '2.2k', 'URL': 'https://github.com//rangav/thunder-client-support'}
# {'Repository Name': 'graphql.js', 'User Name': 'f', 'Stars': '2.2k', 'URL': 'https://github.com//f/graphql.js'}
# {'Repository Name': 'use-http', 'User Name': 'ava', 'Stars': '2.2k', 'URL': 'https://github.com//ava/use-http'}
# {'Repository Name': 'react-imgpro', 'User Name': 'nitin42', 'Stars': '2.2k', 'URL': 'https://github.com//nitin42/react-imgpro'}
# {'Repository Name': 'ran', 'User Name': 'Sly777', 'Stars': '2.2k', 'URL': 'https://github.com//Sly777/ran'}
# {'Repository Name': 'stash', 'User Name': 'stashapp', 'Stars': '2.1k', 'URL': 'https://github.com//stashapp/stash'}
# {'Repository Name': 'core', 'User Name': 'api-platform', 'Stars': '2.1k', 'URL': 'https://github.com//api-platform/core'}
# {'Repository Name': 'graph-node', 'User Name': 'graphprotocol', 'Stars': '2.1k', 'URL': 'https://github.com//graphprotocol/graph-node'}
# {'Repository Name': 'chaskiq', 'User Name': 'chaskiq', 'Stars': '2k', 'URL': 'https://github.com//chaskiq/chaskiq'}
# {'Repository Name': 'graphpack', 'User Name': 'glennreyes', 'Stars': '2k', 'URL': 'https://github.com//glennreyes/graphpack'}
# {'Repository Name': 'cms', 'User Name': 'statamic', 'Stars': '2k', 'URL': 'https://github.com//statamic/cms'}
# {'Repository Name': 'pg_graphql', 'User Name': 'supabase', 'Stars': '2k', 'URL': 'https://github.com//supabase/pg_graphql'}
# {'Repository Name': 'ultimate-backend', 'User Name': 'juicycleff', 'Stars': '1.9k', 'URL': 'https://github.com//juicycleff/ultimate-backend'}
# {'Repository Name': 'sangria', 'User Name': 'sangria-graphql', 'Stars': '1.9k', 'URL': 'https://github.com//sangria-graphql/sangria'}
# {'Repository Name': 'graphql-cli', 'User Name': 'Urigo', 'Stars': '1.9k', 'URL': 'https://github.com//Urigo/graphql-cli'}
# {'Repository Name': 'gatsby-starter-lumen', 'User Name': 'alxshelepenok', 'Stars': '1.9k', 'URL': 'https://github.com//alxshelepenok/gatsby-starter-lumen'}
# {'Repository Name': 'angular-example-app', 'User Name': 'Ismaestro', 'Stars': '1.8k', 'URL': 'https://github.com//Ismaestro/angular-example-app'}
# {'Repository Name': 'reactql', 'User Name': 'leebenson', 'Stars': '1.8k', 'URL': 'https://github.com//leebenson/reactql'}
# {'Repository Name': 'testing-nestjs', 'User Name': 'jmcdo29', 'Stars': '1.8k', 'URL': 'https://github.com//jmcdo29/testing-nestjs'}
# {'Repository Name': 'ariadne', 'User Name': 'mirumee', 'Stars': '1.8k', 'URL': 'https://github.com//mirumee/ariadne'}
# {'Repository Name': 'mercurius', 'User Name': 'mercurius-js', 'Stars': '1.8k', 'URL': 'https://github.com//mercurius-js/mercurius'}
# {'Repository Name': 'laravel-graphql', 'User Name': 'folkloreinc', 'Stars': '1.8k', 'URL': 'https://github.com//folkloreinc/laravel-graphql'}
# {'Repository Name': 'aws-serverless-airline-booking', 'User Name': 'aws-samples', 'Stars': '1.8k', 'URL': 'https://github.com//aws-samples/aws-serverless-airline-booking'}
# {'Repository Name': 'talk', 'User Name': 'coralproject', 'Stars': '1.8k', 'URL': 'https://github.com//coralproject/talk'}
# {'Repository Name': 'serverless', 'User Name': 'cdk-patterns', 'Stars': '1.8k', 'URL': 'https://github.com//cdk-patterns/serverless'}
# {'Repository Name': 'json-graphql-server', 'User Name': 'marmelab', 'Stars': '1.7k', 'URL': 'https://github.com//marmelab/json-graphql-server'}
# {'Repository Name': 'knowledge', 'User Name': 'f2e-awesome', 'Stars': '1.7k', 'URL': 'https://github.com//f2e-awesome/knowledge'}
# {'Repository Name': 'CatchUp', 'User Name': 'ZacSweers', 'Stars': '1.7k', 'URL': 'https://github.com//ZacSweers/CatchUp'}
# {'Repository Name': 'graphql-hooks', 'User Name': 'nearform', 'Stars': '1.7k', 'URL': 'https://github.com//nearform/graphql-hooks'}
# {'Repository Name': 'lacinia', 'User Name': 'walmartlabs', 'Stars': '1.7k', 'URL': 'https://github.com//walmartlabs/lacinia'}
# {'Repository Name': 'prime', 'User Name': 'birkir', 'Stars': '1.7k', 'URL': 'https://github.com//birkir/prime'}
# {'Repository Name': 'automatic-api', 'User Name': 'dbohdan', 'Stars': '1.7k', 'URL': 'https://github.com//dbohdan/automatic-api'}
# {'Repository Name': 'apollo-universal-starter-kit', 'User Name': 'sysgears', 'Stars': '1.7k', 'URL': 'https://github.com//sysgears/apollo-universal-starter-kit'}
# {'Repository Name': 'porn-vault', 'User Name': 'porn-vault', 'Stars': '1.7k', 'URL': 'https://github.com//porn-vault/porn-vault'}
# {'Repository Name': 'graphql-zeus', 'User Name': 'graphql-editor', 'Stars': '1.6k', 'URL': 'https://github.com//graphql-editor/graphql-zeus'}
# {'Repository Name': 'platform-samples', 'User Name': 'github', 'Stars': '1.6k', 'URL': 'https://github.com//github/platform-samples'}
# {'Repository Name': 'best-of-web-python', 'User Name': 'ml-tooling', 'Stars': '1.6k', 'URL': 'https://github.com//ml-tooling/best-of-web-python'}
# {'Repository Name': 'daptin', 'User Name': 'daptin', 'Stars': '1.6k', 'URL': 'https://github.com//daptin/daptin'}
# {'Repository Name': 'react-graphql-github-apollo', 'User Name': 'the-road-to-graphql', 'Stars': '1.6k', 'URL': 'https://github.com//the-road-to-graphql/react-graphql-github-apollo'}
# {'Repository Name': 'graphql-scalars', 'User Name': 'Urigo', 'Stars': '1.5k', 'URL': 'https://github.com//Urigo/graphql-scalars'}
# {'Repository Name': 'graphql-subscriptions', 'User Name': 'apollographql', 'Stars': '1.5k', 'URL': 'https://github.com//apollographql/graphql-subscriptions'}
# {'Repository Name': 'fullstack-graphql-airbnb-clone', 'User Name': 'benawad', 'Stars': '1.5k', 'URL': 'https://github.com//benawad/fullstack-graphql-airbnb-clone'}
# {'Repository Name': 'thunder', 'User Name': 'samsarahq', 'Stars': '1.5k', 'URL': 'https://github.com//samsarahq/thunder'}
# {'Repository Name': 'roapi', 'User Name': 'roapi', 'Stars': '1.5k', 'URL': 'https://github.com//roapi/roapi'}
# {'Repository Name': 'gatsby-simplefolio', 'User Name': 'cobiwave', 'Stars': '1.5k', 'URL': 'https://github.com//cobiwave/gatsby-simplefolio'}
# {'Repository Name': 'parabol', 'User Name': 'ParabolInc', 'Stars': '1.5k', 'URL': 'https://github.com//ParabolInc/parabol'}
# {'Repository Name': 'briOS', 'User Name': 'brianlovin', 'Stars': '1.5k', 'URL': 'https://github.com//brianlovin/briOS'}
# {'Repository Name': 'graphql-kotlin', 'User Name': 'ExpediaGroup', 'Stars': '1.5k', 'URL': 'https://github.com//ExpediaGroup/graphql-kotlin'}
# {'Repository Name': 'typescript-express-starter', 'User Name': 'ljlm0402', 'Stars': '1.5k', 'URL': 'https://github.com//ljlm0402/typescript-express-starter'}
# {'Repository Name': 'graphql-relay-js', 'User Name': 'graphql', 'Stars': '1.5k', 'URL': 'https://github.com//graphql/graphql-relay-js'}
# {'Repository Name': 'graphdoc', 'User Name': '2fd', 'Stars': '1.4k', 'URL': 'https://github.com//2fd/graphdoc'}
# {'Repository Name': 'react-fullstack-graphql', 'User Name': 'graphql-boilerplates', 'Stars': '1.4k', 'URL': 'https://github.com//graphql-boilerplates/react-fullstack-graphql'}
# {'Repository Name': 'apollo-link', 'User Name': 'apollographql', 'Stars': '1.4k', 'URL': 'https://github.com//apollographql/apollo-link'}
# {'Repository Name': 'react-dashboard', 'User Name': 'flatlogic', 'Stars': '1.4k', 'URL': 'https://github.com//flatlogic/react-dashboard'}
# {'Repository Name': 'accounts', 'User Name': 'accounts-js', 'Stars': '1.4k', 'URL': 'https://github.com//accounts-js/accounts'}
# {'Repository Name': 'starter', 'User Name': 'graphile', 'Stars': '1.4k', 'URL': 'https://github.com//graphile/starter'}
# {'Repository Name': 'apollo-upload-client', 'User Name': 'jaydenseric', 'Stars': '1.4k', 'URL': 'https://github.com//jaydenseric/apollo-upload-client'}
# {'Repository Name': 'apollo-client-devtools', 'User Name': 'apollographql', 'Stars': '1.4k', 'URL': 'https://github.com//apollographql/apollo-client-devtools'}
# {'Repository Name': 'clean-ts-api', 'User Name': 'rmanguinho', 'Stars': '1.4k', 'URL': 'https://github.com//rmanguinho/clean-ts-api'}
# {'Repository Name': 'apollo-angular', 'User Name': 'kamilkisiela', 'Stars': '1.4k', 'URL': 'https://github.com//kamilkisiela/apollo-angular'}
# {'Repository Name': 'graphql-inspector', 'User Name': 'kamilkisiela', 'Stars': '1.4k', 'URL': 'https://github.com//kamilkisiela/graphql-inspector'}
# {'Repository Name': 'schemathesis', 'User Name': 'schemathesis', 'Stars': '1.3k', 'URL': 'https://github.com//schemathesis/schemathesis'}
# {'Repository Name': 'openapi-to-graphql', 'User Name': 'IBM', 'Stars': '1.3k', 'URL': 'https://github.com//IBM/openapi-to-graphql'}
# {'Repository Name': 'react-transmit', 'User Name': 'RickWong', 'Stars': '1.3k', 'URL': 'https://github.com//RickWong/react-transmit'}
# {'Repository Name': 'graphql-upload', 'User Name': 'jaydenseric', 'Stars': '1.3k', 'URL': 'https://github.com//jaydenseric/graphql-upload'}
# {'Repository Name': 'graphql-batch', 'User Name': 'Shopify', 'Stars': '1.3k', 'URL': 'https://github.com//Shopify/graphql-batch'}
# {'Repository Name': 'graphql-schema-language-cheat-sheet', 'User Name': 'sogko', 'Stars': '1.3k', 'URL': 'https://github.com//sogko/graphql-schema-language-cheat-sheet'}
# {'Repository Name': 'ever-demand', 'User Name': 'ever-co', 'Stars': '1.3k', 'URL': 'https://github.com//ever-co/ever-demand'}
# {'Repository Name': 'manifold', 'User Name': 'manifold-systems', 'Stars': '1.3k', 'URL': 'https://github.com//manifold-systems/manifold'}
# {'Repository Name': 'flask-graphql', 'User Name': 'graphql-python', 'Stars': '1.3k', 'URL': 'https://github.com//graphql-python/flask-graphql'}
# {'Repository Name': 'apollo-cache-persist', 'User Name': 'apollographql', 'Stars': '1.3k', 'URL': 'https://github.com//apollographql/apollo-cache-persist'}
# {'Repository Name': 'Practical.CleanArchitecture', 'User Name': 'phongnguyend', 'Stars': '1.2k', 'URL': 'https://github.com//phongnguyend/Practical.CleanArchitecture'}
# {'Repository Name': 'spring-graphql', 'User Name': 'spring-projects', 'Stars': '1.2k', 'URL': 'https://github.com//spring-projects/spring-graphql'}
# {'Repository Name': 'fullstack-tutorial', 'User Name': 'apollographql', 'Stars': '1.2k', 'URL': 'https://github.com//apollographql/fullstack-tutorial'}
# {'Repository Name': 'graphql-modules', 'User Name': 'Urigo', 'Stars': '1.2k', 'URL': 'https://github.com//Urigo/graphql-modules'}
# {'Repository Name': 'graphql-ws', 'User Name': 'enisdenjo', 'Stars': '1.2k', 'URL': 'https://github.com//enisdenjo/graphql-ws'}
# {'Repository Name': 'graphql-lodash', 'User Name': 'IvanGoncharov', 'Stars': '1.2k', 'URL': 'https://github.com//IvanGoncharov/graphql-lodash'}
# {'Repository Name': 'nestjs', 'User Name': 'golevelup', 'Stars': '1.2k', 'URL': 'https://github.com//golevelup/nestjs'}
# {'Repository Name': 'rest-layer', 'User Name': 'rs', 'Stars': '1.2k', 'URL': 'https://github.com//rs/rest-layer'}
# {'Repository Name': 'hasura-backend-plus', 'User Name': 'nhost', 'Stars': '1.2k', 'URL': 'https://github.com//nhost/hasura-backend-plus'}
# {'Repository Name': 'graphql-compose', 'User Name': 'graphql-compose', 'Stars': '1.1k', 'URL': 'https://github.com//graphql-compose/graphql-compose'}
# {'Repository Name': 'next-right-now', 'User Name': 'UnlyEd', 'Stars': '1.1k', 'URL': 'https://github.com//UnlyEd/next-right-now'}
# {'Repository Name': 'siler', 'User Name': 'leocavalcante', 'Stars': '1.1k', 'URL': 'https://github.com//leocavalcante/siler'}
# {'Repository Name': 'graphql', 'User Name': 'nestjs', 'Stars': '1.1k', 'URL': 'https://github.com//nestjs/graphql'}
# {'Repository Name': 'fullstack-starterkit', 'User Name': 'karanpratapsingh', 'Stars': '1.1k', 'URL': 'https://github.com//karanpratapsingh/fullstack-starterkit'}
# {'Repository Name': 'bobarr', 'User Name': 'iam4x', 'Stars': '1.1k', 'URL': 'https://github.com//iam4x/bobarr'}
# {'Repository Name': 'gql', 'User Name': 'graphql-python', 'Stars': '1.1k', 'URL': 'https://github.com//graphql-python/gql'}
# {'Repository Name': 'graphql-client', 'User Name': 'github', 'Stars': '1.1k', 'URL': 'https://github.com//github/graphql-client'}
# {'Repository Name': 'Damn-Vulnerable-GraphQL-Application', 'User Name': 'dolevf', 'Stars': '1.1k', 'URL': 'https://github.com//dolevf/Damn-Vulnerable-GraphQL-Application'}
# {'Repository Name': 'graphql-config', 'User Name': 'kamilkisiela', 'Stars': '1k', 'URL': 'https://github.com//kamilkisiela/graphql-config'}
# {'Repository Name': 'fullstack-graphql', 'User Name': 'atulmy', 'Stars': '1k', 'URL': 'https://github.com//atulmy/fullstack-graphql'}

# %%
import pandas as pd

# %%
df = pd.DataFrame(all_article_lst)

# %%
df[:200]
# Out:
#          Repository Name        User Name  Stars  \
# 0                 gatsby         gatsbyjs  53.3k
# 1                 strapi           strapi  46.5k
# 2             hoppscotch       hoppscotch  45.3k
# 3               prettier         prettier  43.5k
# 4               supabase         supabase    36k
# ..                   ...              ...    ...
# 195       graphql-lodash    IvanGoncharov   1.2k
# 196               nestjs        golevelup   1.2k
# 197           rest-layer               rs   1.2k
# 198  hasura-backend-plus            nhost   1.2k
# 199      graphql-compose  graphql-compose   1.1k
#
#                                                    URL
# 0                  https://github.com//gatsbyjs/gatsby
# 1                    https://github.com//strapi/strapi
# 2            https://github.com//hoppscotch/hoppscotch
# 3                https://github.com//prettier/prettier
# 4                https://github.com//supabase/supabase
# ..                                                 ...
# 195   https://github.com//IvanGoncharov/graphql-lodash
# 196               https://github.com//golevelup/nestjs
# 197                  https://github.com//rs/rest-layer
# 198      https://github.com//nhost/hasura-backend-plus
# 199  https://github.com//graphql-compose/graphql-co...
#
# [200 rows x 4 columns]

# %%
df[:200].to_excel('All-Graphql200-Data.xlsx')
